# %%
import os
import warnings
import sys

import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from urllib.parse import urlparse
import mlflow
import mlflow.sklearn

import logging

logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)


def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2

# %%
os.chdir('..')

# %%
df = pd.read_csv('toy_data/toydata.csv')

# %%
df
# Out:
#         t_idx  time_bin          uid        age  temperature  heart_rate  \
# 0           0      3558     uva_1880  63.763062         60.0   60.121516
# 1           1      3559     uva_1880  63.763062         60.0   60.121516
# 2           2      3560     uva_1880  63.763062         60.0   60.121516
# 3           3      3561     uva_1880  63.763062         60.0   60.121516
# 4           4      3562     uva_1880  63.763062         60.0   60.121516
# ...       ...       ...          ...        ...          ...         ...
# 395452    188     25691  mimic_89645  60.000000          NaN   82.000000
# 395453    189     25692  mimic_89645  60.000000          NaN   82.000000
# 395454    190     25693  mimic_89645  60.000000          NaN   82.000000
# 395455    191     25694  mimic_89645  60.000000          NaN   82.000000
# 395456    192     25695  mimic_89645  60.000000          NaN   82.000000
#
#         systolic_blood_pressure  diastolic_blood_pressure  resp_rate  glucose  \
# 0                         100.0                      80.0  23.318647    150.0
# 1                         100.0                      80.0  23.318647    150.0
# 2                         100.0                      80.0  23.318647    150.0
# 3                         100.0                      80.0  23.318647    150.0
# 4                         100.0                      80.0  23.318647    150.0
# ...                         ...                       ...        ...      ...
# 395452                    100.0                      55.0  27.000000    124.0
# 395453                    100.0                      55.0  27.000000    124.0
# 395454                    100.0                      55.0  27.000000    124.0
# 395455                    100.0                      55.0  27.000000    124.0
# 395456                    100.0                      55.0  27.000000    124.0
#
#         ...  paco2  chloride  troponin   ptt  lactate  blood_urea_nitrogen  \
# 0       ...   26.8     117.0      0.07  48.9      0.5                106.0
# 1       ...   26.8     117.0      0.07  48.9      0.5                106.0
# 2       ...   26.8     117.0      0.07  48.9      0.5                106.0
# 3       ...   26.8     117.0      0.07  48.9      0.5                106.0
# 4       ...   26.8     117.0      0.07  48.9      0.5                106.0
# ...     ...    ...       ...       ...   ...      ...                  ...
# 395452  ...    NaN     103.0       NaN   NaN      NaN                 11.0
# 395453  ...    NaN     103.0       NaN   NaN      NaN                 11.0
# 395454  ...    NaN     103.0       NaN   NaN      NaN                 11.0
# 395455  ...    NaN     103.0       NaN   NaN      NaN                 11.0
# 395456  ...    NaN     103.0       NaN   NaN      NaN                 11.0
#
#         magnesium  y  event_relative_time  event_order
# 0             2.0  0                -2865            1
# 1             2.0  0                -2850            1
# 2             2.0  0                -2835            1
# 3             2.0  0                -2820            1
# 4             2.0  0                -2805            1
# ...           ... ..                  ...          ...
# 395452        2.1  0                  -45            6
# 395453        2.1  0                  -30            6
# 395454        2.1  0                  -15            6
# 395455        2.1  0                    0            6
# 395456        2.1  0                   15            6
#
# [395457 rows x 30 columns]

# %%
train = df.groupby('uid').agg(
    {
        'age': 'mean',
        'temperature': 'mean',
        'heart_rate': 'mean',
        'systolic_blood_pressure': 'mean',
        'diastolic_blood_pressure': 'mean',
        'resp_rate': 'mean',
        'y': lambda x: 1 if sum(x) > 0 else 0
    }
)

y_train = train['y']
X_train = train.drop('y', axis=1)

# %%
from sklearn.impute import SimpleImputer

# %%
X_train: np.ndarray = SimpleImputer(strategy='mean').fit_transform(X_train)

# %%
y_train = y_train.to_numpy()

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
regr = LogisticRegressionCV(cv=5)

# %%
regr.fit(X_train, y_train)
# Out:
# LogisticRegressionCV(cv=5)

# %%
eval_metrics(y_train, regr.predict(X_train))
# Out:
# (0.2991669443391063, 0.08950086058519793, -0.09829867674858206)

# %%
regr.score(X_train, y_train)
# Out:
# 0.9104991394148021
