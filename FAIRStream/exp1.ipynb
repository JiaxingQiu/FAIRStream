# %% [markdown]
# # FAIRStream BSI

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

import FAIRStream

# %% [markdown]
# ## experiment 1
#
# * locate pos neg
# * responce pos neg

# %%
csv_pool_path = '/Users/jiaxingqiu/Documents/BSI/code/projects/csv_pool'
work_dir = '/Users/jiaxingqiu/Documents/BSI/code/projects/exp1'

# %%
bsi_stream = FAIRStream.FAIRStream(work_dir)
#bsi_stream.querier.update_variable_dict()
#bsi_stream.querier.update_csv_source_dict()
#bsi_stream.engineer.read_variable_dict()
# Out:
# Success: Querier has initiated a csv source dictionary in:/Users/jiaxingqiu/Documents/BSI/code/projects/exp1/meta_data/csv_source_dict_demo.json
# Success: Querier has initiated a variable dictionary in:/Users/jiaxingqiu/Documents/BSI/code/projects/exp1/meta_data/variable_dict_demo.json
# Unable to read sql source dictionary. Use Querier.update_sql_source_dict() to build one.

# %%
bsi_stream.engineer.csv_source_dict
# Out:
# {'uva': {'vital': {'include': True,
#    'path': '/Users/jiaxingqiu/Documents/BSI/code/DeepDiag/data/bsi_old_deidentified_final.csv',
#    'info': 'Vital signs data from UVA'},
#   'lab': {'include': True,
#    'path': '/Users/jiaxingqiu/Documents/BSI/code/DeepDiag/data/uva_lab.csv',
#    'info': 'Lab results data from UVA'}},
#  'mimic': {'vital': {'path': '/Users/jiaxingqiu/Documents/BSI/code/DeepDiag/data/mimic_patient_data_minutes.csv',
#    'info': 'Vital signs data from MIMIC',
#    'include': True},
#   'lab': {'path': '/Users/jiaxingqiu/Documents/BSI/code/DeepDiag/data/mimic_labs_minutes_combined.csv',
#    'info': 'Lab results data from MIMIC',
#    'include': True}}}

# %%
bsi_stream.engineer.variable_dict
# Out:
# {'__uid': {'src_names': ['id', 'ID', 'subject_id', 'subject_id'],
#   'label': 'unique subject id for current study',
#   'unique_per_sbj': True},
#  '__time': {'src_names': ['tsa', 'tsa', 'timeMinutes', 'timeMinutes'],
#   'label': 'time since admission',
#   'unit': 'minute'},
#  '__anchor': {'src_names': ['True_positive', 'True positive'],
#   'label': 'anchor for an episode',
#   'unique_per_sbj': False,
#   'factor': {'levels': {'__neg': ['0', '0.0'], '__pos': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': '__non'}}},
#  'y': {'output': True,
#   'src_names': ['True_positive', 'True positive'],
#   'label': 'Event outcome result',
#   'unique_per_sbj': False,
#   'factor': {'levels': {'neg': ['0', '0.0'], 'pos': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': 'neg'}}},
#  'age': {'input': True,
#   'src_names': ['age', 'AGE'],
#   'label': 'age at admission',
#   'unique_per_sbj': True,
#   'numeric': {'scaler': 'none',
#    'unit': 'year',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 110},
#    'impute_per_sbj': {'forward': 0, 'backward': 0}}},
#  'gender': {'input': False,
#   'src_names': ['Sex', 'Sex'],
#   'label': 'subject gender',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'Male': ['male', 'Male', '0'],
#     'Female': ['female', 'Female', '1']},
#    'impute_per_sbj': {'nan_level': 'unknown'}}},
#  'race': {'input': False,
#   'src_names': ['Race', 'RACE'],
#   'label': 'subject race',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'Black': 1, 'White': 2},
#    'impute_per_sbj': {'nan_level': 'White'}}},
#  'ethnicity': {'input': False,
#   'src_names': ['ethnicity', 'Ethnicity'],
#   'label': 'subject ethnicity',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'African American': ['aa', 'African american'],
#     'Asian': ['asian', 'Asian'],
#     'Histopian': ['hist', 'histopian', 'Histopian']},
#    'impute_per_sbj': {'nan_level': 'White'}}},
#  'temp': {'input': True,
#   'src_names': ['Temp', 'tempc'],
#   'label': 'subject body temperature',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'minmax',
#    'unit': 'celsius',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 5,
#     'value_max': 60},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'heart_rate': {'input': True,
#   'src_names': ['hr', 'heartrate'],
#   'label': 'subject heart rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'beats per minute',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 10,
#     'value_max': 200},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'systolic_blood_pressure': {'input': True,
#   'src_names': ['SBP', 'sysbp'],
#   'label': 'subject systolic blood pressure',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'mm Hg',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'diastolic_blood_pressure': {'input': True,
#   'src_names': ['DBP', 'diasbp'],
#   'label': 'subject diastolic blood pressure',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'mm Hg',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'resp_rate': {'input': True,
#   'src_names': ['rr', 'resprate'],
#   'label': 'subject respiratory rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 200},
#    'unit': 'mm Hg',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'spo2': {'input': False,
#   'src_names': [],
#   'label': 'SpO2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 79},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'glucose': {'input': True,
#   'src_names': ['GLUCOSE', 'Glucose'],
#   'label': 'Glucose',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 49,
#     'value_max': 460},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'bilirubin': {'input': True,
#   'src_names': ['TOTAL.BILIRUBIN', 'bilirubin'],
#   'label': 'Bilirubin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 50},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'potassium': {'input': True,
#   'src_names': ['POTASSIUM', 'Potassium'],
#   'label': 'Potassium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 2.4,
#     'value_max': 6.6},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'albumin': {'input': True,
#   'src_names': ['Albumin', 'ALBUMIN'],
#   'label': 'Albumin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 5},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'calcium': {'input': True,
#   'src_names': ['CALCIUM', 'Calcium'],
#   'label': 'Calcium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 6.1,
#     'value_max': 12},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'wbc': {'input': True,
#   'src_names': ['WHITE.BLOOD.CELL.COUNT', 'WBC'],
#   'label': 'WBC',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 33.85},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'creatinine': {'input': True,
#   'src_names': ['CREATININE', 'Creatinine'],
#   'label': 'Creatinine',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 10},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'platelet_count': {'input': True,
#   'src_names': ['PLATELET.COUNT', 'plateletcount'],
#   'label': 'PlateletCount',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1001},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'alt': {'input': True,
#   'src_names': ['ALT.GPT', 'ALT'],
#   'label': 'ALT',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1085},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'alp': {'input': True,
#   'src_names': ['ALKALINE.PHOSPHATASE', 'ALP'],
#   'label': 'ALP',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 800},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'ast': {'input': True,
#   'src_names': ['AST.GOT', 'AST'],
#   'label': 'AST',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1203},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'paco2': {'input': True,
#   'src_names': ['PCO2', 'PaCO2'],
#   'label': 'PaCO2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100.5},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'chloride': {'input': True,
#   'src_names': ['CHLORIDE', 'Chloride'],
#   'label': 'Chloride',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 83,
#     'value_max': 132},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'troponin': {'input': True,
#   'src_names': ['TROPONIN.I', 'Troponin'],
#   'label': 'Troponin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 23.5},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'ptt': {'input': True,
#   'src_names': ['PARTIAL.THROMBOPLASTIN.TIME', 'PTT'],
#   'label': 'partial_thromboplastin_time',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 140},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'lactate': {'input': True,
#   'src_names': ['Lactate', 'LACTIC.ACID'],
#   'label': 'Lactate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 19.1},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'bun': {'input': True,
#   'src_names': ['BLOOD.UREA.NITROGEN', 'BUN'],
#   'label': 'BUN',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 143},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'magnesium': {'input': True,
#   'src_names': ['MAGNESIUM', 'Magnesium'],
#   'label': 'Magnesium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 3.4},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}}}

# %%
bsi_stream.engineer.DefineEpisode(input_time_len=2*24*60, output_time_len=1, time_resolution=60, time_lag=0, anchor_gap=7*24*60)
bsi_stream.engineer.BuildMVTS(csv_pool_path, nsbj=100, valid_frac=0, test_frac=0, batch_size=32, impute_input='lalala', impute_output='lalala')
X_train, Y_train, X_valid, Y_valid, X_test, Y_test = bsi_stream.engineer.ExtractXY(shape_type="2d")
bsi_stream.engineer.info()
# Out:
#
# Success! An episode is defined to
# --- use 2880 minute(s) long input variables
# --- predict 1 minute(s) response variables into the future
# --- lag 0 minute(s) between predictors and responses
# --- increase by every 60 minute(s)
# --- last at most 10080 minute(s) long
# Success! Engineer has updated attributes --- episode.
# Sucess!  100 out of 26093 subjects are sampled!
# --- fix upper boundary for age by nan
# --- fix lower boundary for age by nan
# --- minmax scaling temp
# --- fix upper boundary for heart_rate by nan
# --- fix lower boundary for heart_rate by nan
# --- fix upper boundary for systolic_blood_pressure by 100.0
# --- fix lower boundary for systolic_blood_pressure by 36.0
# --- fix upper boundary for diastolic_blood_pressure by 100.0
# --- fix lower boundary for diastolic_blood_pressure by 26.0
# --- fix upper boundary for resp_rate by nan
# --- fix lower boundary for resp_rate by nan
# --- fix upper boundary for glucose by nan
# --- fix lower boundary for glucose by nan
# --- fix upper boundary for bilirubin by nan
# --- fix lower boundary for bilirubin by nan
# --- fix upper boundary for potassium by nan
# --- fix lower boundary for potassium by nan
# --- fix upper boundary for albumin by nan
# --- fix lower boundary for albumin by nan
# --- fix upper boundary for calcium by nan
# --- fix lower boundary for calcium by nan
# --- fix upper boundary for wbc by nan
# --- fix lower boundary for wbc by nan
# --- fix upper boundary for creatinine by nan
# --- fix lower boundary for creatinine by nan
# --- fix upper boundary for platelet_count by nan
# --- fix lower boundary for platelet_count by nan
# --- fix upper boundary for alt by nan
# --- fix lower boundary for alt by nan
# --- fix upper boundary for alp by nan
# --- fix lower boundary for alp by nan
# --- fix upper boundary for ast by nan
# --- fix lower boundary for ast by nan
# --- fix upper boundary for paco2 by nan
# --- fix lower boundary for paco2 by nan
# --- fix upper boundary for chloride by nan
# --- fix lower boundary for chloride by nan
# --- fix upper boundary for troponin by nan
# --- fix lower boundary for troponin by nan
# --- fix upper boundary for ptt by nan
# --- fix lower boundary for ptt by nan
# --- fix upper boundary for lactate by nan
# --- fix lower boundary for lactate by nan
# --- fix upper boundary for bun by nan
# --- fix lower boundary for bun by nan
# --- fix upper boundary for magnesium by nan
# --- fix lower boundary for magnesium by nan
# --- fix upper boundary for age by 110.0
# --- fix lower boundary for age by 18.0
# --- fix upper boundary for age by 110.0
# --- fix lower boundary for age by 18.0
# --- minmax scaling temp
# --- fix upper boundary for heart_rate by nan
# --- fix lower boundary for heart_rate by nan
# --- fix upper boundary for systolic_blood_pressure by nan
# --- fix lower boundary for systolic_blood_pressure by nan
# --- fix upper boundary for diastolic_blood_pressure by nan
# --- fix lower boundary for diastolic_blood_pressure by nan
# --- fix upper boundary for resp_rate by nan
# --- fix lower boundary for resp_rate by nan
# --- fix upper boundary for glucose by 460.0
# --- fix lower boundary for glucose by 49.0
# --- fix upper boundary for bilirubin by nan
# --- fix lower boundary for bilirubin by nan
# --- fix upper boundary for potassium by 6.6
# --- fix lower boundary for potassium by 2.4
# --- fix upper boundary for albumin by nan
# --- fix lower boundary for albumin by nan
# --- fix upper boundary for calcium by nan
# --- fix lower boundary for calcium by nan
# --- fix upper boundary for wbc by 33.85
# --- fix lower boundary for wbc by 0.2
# --- fix upper boundary for creatinine by 10.0
# --- fix lower boundary for creatinine by 0.3
# --- fix upper boundary for platelet_count by nan
# --- fix lower boundary for platelet_count by nan
# --- fix upper boundary for alt by nan
# --- fix lower boundary for alt by nan
# --- fix upper boundary for alp by nan
# --- fix lower boundary for alp by nan
# --- fix upper boundary for ast by nan
# --- fix lower boundary for ast by nan
# --- fix upper boundary for paco2 by nan
# --- fix lower boundary for paco2 by nan
# --- fix upper boundary for chloride by 127.0
# --- fix lower boundary for chloride by 83.0
# --- fix upper boundary for troponin by nan
# --- fix lower boundary for troponin by nan
# --- fix upper boundary for ptt by 140.0
# --- fix lower boundary for ptt by 19.7
# --- fix upper boundary for lactate by nan
# --- fix lower boundary for lactate by nan
# --- fix upper boundary for bun by 143.0
# --- fix lower boundary for bun by 3.0
# --- fix upper boundary for magnesium by nan
# --- fix lower boundary for magnesium by nan
# --- prepare episodes for mimic_46600
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.0
# y___neg    1.0
# dtype: float64
# --- prepare episodes for mimic_76143
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.0
# y___neg    1.0
# dtype: float64
# --- prepare episodes for mimic_17297
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.25
# y___neg    0.75
# dtype: float64
# --- prepare episodes for mimic_1787
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.2
# y___neg    0.8
# dtype: float64
# --- prepare episodes for uva_7576
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.166667
# y___neg    0.833333
# dtype: float64
# --- prepare episodes for mimic_353
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.166667
# y___neg    0.833333
# dtype: float64
# --- prepare episodes for uva_3271
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.153846
# y___neg    0.846154
# dtype: float64
# --- prepare episodes for mimic_17239
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.133333
# y___neg    0.866667
# dtype: float64
# --- prepare episodes for uva_3999
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.117647
# y___neg    0.882353
# dtype: float64
# --- prepare episodes for uva_8827
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.111111
# y___neg    0.888889
# dtype: float64
# --- prepare episodes for uva_9770
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.105263
# y___neg    0.894737
# dtype: float64
# --- prepare episodes for mimic_15386
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.1
# y___neg    0.9
# dtype: float64
# --- prepare episodes for mimic_22532
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.090909
# y___neg    0.909091
# dtype: float64
# --- prepare episodes for mimic_59986
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.083333
# y___neg    0.916667
# dtype: float64
# --- prepare episodes for uva_4493
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.08
# y___neg    0.92
# dtype: float64
# --- prepare episodes for mimic_24030
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.076923
# y___neg    0.923077
# dtype: float64
# --- prepare episodes for mimic_22622
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.071429
# y___neg    0.928571
# dtype: float64
# --- prepare episodes for mimic_770
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.068966
# y___neg    0.931034
# dtype: float64
# --- prepare episodes for uva_6305
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.066667
# y___neg    0.933333
# dtype: float64
# --- prepare episodes for mimic_8253
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.064516
# y___neg    0.935484
# dtype: float64
# --- prepare episodes for mimic_17122
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.085714
# y___neg    0.914286
# dtype: float64
# --- prepare episodes for mimic_25270
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.081081
# y___neg    0.918919
# dtype: float64
# --- prepare episodes for mimic_31319
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.078947
# y___neg    0.921053
# dtype: float64
# --- prepare episodes for uva_6002
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.076923
# y___neg    0.923077
# dtype: float64
# --- prepare episodes for uva_2400
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.075
# y___neg    0.925
# dtype: float64
# --- prepare episodes for mimic_8986
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.073171
# y___neg    0.926829
# dtype: float64
# --- prepare episodes for mimic_12181
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.071429
# y___neg    0.928571
# dtype: float64
# --- prepare episodes for mimic_65962
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.069767
# y___neg    0.930233
# dtype: float64
# --- prepare episodes for mimic_23262
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.068182
# y___neg    0.931818
# dtype: float64
# --- prepare episodes for mimic_88659
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.066667
# y___neg    0.933333
# dtype: float64
# --- prepare episodes for mimic_43782
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.065217
# y___neg    0.934783
# dtype: float64
# --- prepare episodes for uva_3949
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.06383
# y___neg    0.93617
# dtype: float64
# --- prepare episodes for mimic_21962
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.0625
# y___neg    0.9375
# dtype: float64
# --- prepare episodes for mimic_27554
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.058824
# y___neg    0.941176
# dtype: float64
# --- prepare episodes for mimic_44058
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.057692
# y___neg    0.942308
# dtype: float64
# --- prepare episodes for mimic_97409
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.056604
# y___neg    0.943396
# dtype: float64
# --- prepare episodes for mimic_32008
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.055556
# y___neg    0.944444
# dtype: float64
# --- prepare episodes for mimic_68857
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.054545
# y___neg    0.945455
# dtype: float64
# --- prepare episodes for uva_7042
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.052632
# y___neg    0.947368
# dtype: float64
# --- prepare episodes for mimic_12252
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.051724
# y___neg    0.948276
# dtype: float64
# --- prepare episodes for mimic_24080
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.050847
# y___neg    0.949153
# dtype: float64
# --- prepare episodes for mimic_5701
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.05
# y___neg    0.95
# dtype: float64
# --- prepare episodes for mimic_76328
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.04918
# y___neg    0.95082
# dtype: float64
# --- prepare episodes for uva_1371
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.048387
# y___neg    0.951613
# dtype: float64
# --- prepare episodes for mimic_87394
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.047619
# y___neg    0.952381
# dtype: float64
# --- prepare episodes for uva_4548
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.0625
# y___neg    0.9375
# dtype: float64
# --- prepare episodes for mimic_52330
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.060606
# y___neg    0.939394
# dtype: float64
# --- prepare episodes for mimic_27800
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.050633
# y___neg    0.949367
# dtype: float64
# --- prepare episodes for uva_9358
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.0625
# y___neg    0.9375
# dtype: float64
# --- prepare episodes for uva_2773
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.061728
# y___neg    0.938272
# dtype: float64
# --- prepare episodes for mimic_52260
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.060976
# y___neg    0.939024
# dtype: float64
# --- prepare episodes for uva_228
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.060241
# y___neg    0.939759
# dtype: float64
# --- prepare episodes for uva_7937
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.059524
# y___neg    0.940476
# dtype: float64
# --- prepare episodes for mimic_51297
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.058824
# y___neg    0.941176
# dtype: float64
# --- prepare episodes for mimic_28264
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.05814
# y___neg    0.94186
# dtype: float64
# --- prepare episodes for mimic_91096
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.068966
# y___neg    0.931034
# dtype: float64
# --- prepare episodes for mimic_7820
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.068182
# y___neg    0.931818
# dtype: float64
# --- prepare episodes for mimic_47712
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.067416
# y___neg    0.932584
# dtype: float64
# --- prepare episodes for mimic_49750
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.066667
# y___neg    0.933333
# dtype: float64
# --- prepare episodes for mimic_16785
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.065934
# y___neg    0.934066
# dtype: float64
# --- prepare episodes for mimic_6480
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.064516
# y___neg    0.935484
# dtype: float64
# --- prepare episodes for mimic_31482
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.06383
# y___neg    0.93617
# dtype: float64
# --- prepare episodes for uva_9589
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.063158
# y___neg    0.936842
# dtype: float64
# --- prepare episodes for mimic_8453
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.0625
# y___neg    0.9375
# dtype: float64
# --- prepare episodes for mimic_86393
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.061856
# y___neg    0.938144
# dtype: float64
# --- prepare episodes for mimic_19000
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.061224
# y___neg    0.938776
# dtype: float64
# --- prepare episodes for uva_4612
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.060606
# y___neg    0.939394
# dtype: float64
# --- prepare episodes for uva_745
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.06
# y___neg    0.94
# dtype: float64
# --- prepare episodes for uva_9737
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.059406
# y___neg    0.940594
# dtype: float64
# --- prepare episodes for mimic_77586
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.058824
# y___neg    0.941176
# dtype: float64
# --- prepare episodes for mimic_24166
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.058252
# y___neg    0.941748
# dtype: float64
# --- prepare episodes for mimic_59388
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.057692
# y___neg    0.942308
# dtype: float64
# --- prepare episodes for mimic_48044
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.057143
# y___neg    0.942857
# dtype: float64
# --- prepare episodes for mimic_14048
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.056604
# y___neg    0.943396
# dtype: float64
# --- prepare episodes for mimic_9445
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.056075
# y___neg    0.943925
# dtype: float64
# --- prepare episodes for mimic_24147
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.064815
# y___neg    0.935185
# dtype: float64
# --- prepare episodes for mimic_18258
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.063636
# y___neg    0.936364
# dtype: float64
# --- prepare episodes for mimic_12909
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.063063
# y___neg    0.936937
# dtype: float64
# --- prepare episodes for mimic_55591
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.0625
# y___neg    0.9375
# dtype: float64
# --- prepare episodes for mimic_21486
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.061947
# y___neg    0.938053
# dtype: float64
# --- prepare episodes for mimic_10687
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.061404
# y___neg    0.938596
# dtype: float64
# --- prepare episodes for mimic_13957
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.060345
# y___neg    0.939655
# dtype: float64
# --- prepare episodes for mimic_66686
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.059829
# y___neg    0.940171
# dtype: float64
# --- prepare episodes for mimic_63811
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.059322
# y___neg    0.940678
# dtype: float64
# --- prepare episodes for uva_6644
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.058824
# y___neg    0.941176
# dtype: float64
# --- prepare episodes for mimic_25330
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.066667
# y___neg    0.933333
# dtype: float64
# --- prepare episodes for mimic_2603
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.07438
# y___neg    0.92562
# dtype: float64
# --- prepare episodes for mimic_31841
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.07377
# y___neg    0.92623
# dtype: float64
# --- prepare episodes for mimic_1982
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.072581
# y___neg    0.927419
# dtype: float64
# --- prepare episodes for mimic_14398
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.072
# y___neg    0.928
# dtype: float64
# --- prepare episodes for uva_8813
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.071429
# y___neg    0.928571
# dtype: float64
# --- prepare episodes for mimic_30829
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.070312
# y___neg    0.929688
# dtype: float64
# --- prepare episodes for uva_5385
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.069767
# y___neg    0.930233
# dtype: float64
# --- prepare episodes for mimic_19790
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.069231
# y___neg    0.930769
# dtype: float64
# --- prepare episodes for mimic_23243
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.068702
# y___neg    0.931298
# dtype: float64
# --- prepare episodes for mimic_5875
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.068182
# y___neg    0.931818
# dtype: float64
# --- prepare episodes for mimic_41350
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.067164
# y___neg    0.932836
# dtype: float64
# --- prepare episodes for mimic_59833
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.066667
# y___neg    0.933333
# dtype: float64
# --- prepare episodes for mimic_32173
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.066176
# y___neg    0.933824
# dtype: float64
# --- prepare episodes for mimic_55609
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.065693
# y___neg    0.934307
# dtype: float64
# Success! Engineer has updated attributes --- mvts_df, input_vars, output_vars.
# Success! Engineer has updated attributes --- train_df, valid_df and test_df.
# --- Unrecogenized imputation method. original df returned
# --- Unrecogenized imputation method. original df returned
# Success! Engineer has updated attributes --- train_df_imputed, valid_df_imputed and test_df_imputed.
# Success! Engineer has updated attributes --- train_tfds, valid_tfds and test_tfds.
#
# ----------------------------- Engineer Attributes List ------------------------
#
# ['work_dir', 'meta_dir', 'variable_dict', 'csv_source_dict', 'sql_source_dict', 'input_vars', 'output_vars', 'episode', 'sample_info', 'mvts_df', 'mvts_tfds', 'train_df', 'valid_df', 'test_df', 'train_df_imputed', 'valid_df_imputed', 'test_df_imputed', 'train_tfds', 'valid_tfds', 'test_tfds']
#
# ------------------------------------- Inputs  ---------------------------------
#
# ['age___vital', 'age___lab', 'temp___vital', 'heart_rate___vital', 'systolic_blood_pressure___vital', 'diastolic_blood_pressure___vital', 'resp_rate___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'wbc___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'paco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital']
#
# ------------------------------------- Outputs ---------------------------------
#
# ['y___pos', 'y___neg']
#
# ------------------ train_tfds / valid_tfds / test_tfds batch shape --------------
#
# Inputs shape (batch size, time bins, variables): (32, 48, 25)
# Labels shape (batch size, time bins, variables): (32, 1, 2)
#
# ---------------------- train_df / train_df_imputed shape ----------------------
#
# (6713, 32)
#
# ---------------------- valid_df / valid_df_imputed shape ----------------------
#
#
# ------------------------ test_df / test_df_imputed shape ----------------------

# %%
bsi_stream.engineer.DefineEpisode(input_time_len=2*24*60, output_time_len=1, time_resolution=60, time_lag=0, anchor_gap=7*24*60)
bsi_stream.engineer.BuildMVTS(csv_pool_path, nsbj=10000, valid_frac=0, test_frac=0, batch_size=32, impute_input='lalala', impute_output='lalala')
X_train, Y_train, X_valid, Y_valid, X_test, Y_test = bsi_stream.engineer.ExtractXY(shape_type="2d")
bsi_stream.engineer.info()
# Out:
#
# Success! An episode is defined to
# --- use 2880 minute(s) long input variables
# --- predict 1 minute(s) response variables into the future
# --- lag 0 minute(s) between predictors and responses
# --- increase by every 60 minute(s)
# --- last at most 10080 minute(s) long
# Success! Engineer has updated attributes --- episode.
# Sucess!  10000 out of 26093 subjects are sampled!
# --- fix upper boundary for age by 110.0
# --- fix lower boundary for age by 18.0

# %%
bsi_stream.engineer.train_df.to_csv("/Users/jiaxingqiu/Documents/BSI/code/projects/exp1/data.csv",index=False)

# %%
bsi_stream.engineer.train_df.describe()
# Out:
#            age___lab    age___vital   temp___vital  heart_rate___vital  \
# count  287140.000000  356377.000000  124121.000000       107672.000000
# mean       65.044084      63.988416       0.705590           89.134824
# std        18.960498      18.694608       0.050913           18.386160
# min        18.000000      14.101500       0.140299           10.000000
# 25%        53.000000      52.000000       0.669777           76.000000
# 50%        65.000000      64.000000       0.695895           88.000000
# 75%        78.000000      77.000000       0.740672          101.000000
# max       110.000000     110.000000       0.951705          201.000000
#
#        systolic_blood_pressure___vital  diastolic_blood_pressure___vital  \
# count                    126094.000000                     126090.000000
# mean                        123.987619                         63.132666
# std                          23.498026                         14.832932
# min                          11.000000                          6.000000
# 25%                         107.000000                         53.000000
# 50%                         122.000000                         62.000000
# 75%                         139.000000                         72.000000
# max                         304.000000                        298.000000
#
#        resp_rate___vital  glucose___vital  bilirubin___vital  \
# count      106746.000000    206408.000000      105583.000000
# mean           20.444632       143.372338           2.895999
# std             6.026349        77.054729           6.323851
# min             1.000000         0.000000           0.000000
# 25%            16.000000       104.000000           0.400000
# 50%            20.000000       125.000000           0.800000
# 75%            24.000000       158.000000           1.900000
# max            69.000000      2162.000000         116.000000
#
#        potassium___vital  ...  troponin___vital    ptt___vital  \
# count      205537.000000  ...      44691.000000  152464.000000
# mean            4.181872  ...          1.079104      36.653959
# std             0.745896  ...          5.142961      19.788442
# min             1.600000  ...          0.000000      13.700000
# 25%             3.700000  ...          0.030000      26.500000
# 50%             4.100000  ...          0.070000      30.400000
# 75%             4.500000  ...          0.323333      37.900000
# max            20.000000  ...        294.812500     152.000000
#
#        lactate___vital    bun___vital  magnesium___vital        y___pos  \
# count     91836.000000  206154.000000      178616.000000  356377.000000
# mean          2.138941      30.654363           2.012956       0.080847
# std           1.735697      24.043814           0.385605       0.272600
# min           0.300000       1.000000           0.100000       0.000000
# 25%           1.200000      14.000000           1.800000       0.000000
# 50%           1.700000      23.000000           2.000000       0.000000
# 75%           2.400000      39.000000           2.200000       0.000000
# max          34.200000     270.000000           8.700000       1.000000
#
#              y___neg     __time_bin  __ep_relative_time     __ep_order
# count  356377.000000  356377.000000       356377.000000  356377.000000
# mean        0.919153    4430.516981        -1440.000000       1.667675
# std         0.272600   12588.057153          848.529328       1.558247
# min         0.000000  -98883.000000        -2880.000000       1.000000
# 25%         1.000000     -11.000000        -2160.000000       1.000000
# 50%         1.000000     118.000000        -1440.000000       1.000000
# 75%         1.000000     840.000000         -720.000000       2.000000
# max         1.000000   89536.000000            0.000000      24.000000
#
# [8 rows x 30 columns]
