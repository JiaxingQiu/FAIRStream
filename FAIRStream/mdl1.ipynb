# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

import FAIRStream

# %%
csv_pool_path = '/Users/jiaxingqiu/Documents/BSI/code/projects/csv_pool'
work_dir = '/Users/jiaxingqiu/Documents/BSI/code/projects/exp1'

bsi_stream = FAIRStream.FAIRStream(work_dir)
bsi_stream.engineer.variable_dict
# Out:
# Success: Querier has initiated a csv source dictionary in:/Users/jiaxingqiu/Documents/BSI/code/projects/exp1/meta_data/csv_source_dict_demo.json
# Success: Querier has initiated a variable dictionary in:/Users/jiaxingqiu/Documents/BSI/code/projects/exp1/meta_data/variable_dict_demo.json
# Unable to read sql source dictionary. Use Querier.update_sql_source_dict() to build one.
# {'__uid': {'src_names': ['id', 'ID', 'subject_id', 'subject_id'],
#   'label': 'unique subject id for current study',
#   'unique_per_sbj': True},
#  '__time': {'src_names': ['tsa', 'tsa', 'timeMinutes', 'timeMinutes'],
#   'label': 'time since admission',
#   'unit': 'minute'},
#  '__anchor': {'src_names': ['True_positive', 'True positive'],
#   'label': 'anchor for an episode',
#   'unique_per_sbj': False,
#   'factor': {'levels': {'__neg': ['0', '0.0'], '__pos': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': '__non'}}},
#  'y': {'output': True,
#   'src_names': ['True_positive', 'True positive'],
#   'label': 'Event outcome result',
#   'unique_per_sbj': False,
#   'factor': {'levels': {'neg': ['0', '0.0'], 'pos': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': 'neg'}}},
#  'age': {'input': True,
#   'src_names': ['age', 'AGE'],
#   'label': 'age at admission',
#   'unique_per_sbj': True,
#   'numeric': {'scaler': 'none',
#    'unit': 'year',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 110},
#    'impute_per_sbj': {'forward': 0, 'backward': 0}}},
#  'gender': {'input': False,
#   'src_names': ['Sex', 'Sex'],
#   'label': 'subject gender',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'Male': ['male', 'Male', '0'],
#     'Female': ['female', 'Female', '1']},
#    'impute_per_sbj': {'nan_level': 'unknown'}}},
#  'race': {'input': False,
#   'src_names': ['Race', 'RACE'],
#   'label': 'subject race',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'Black': 1, 'White': 2},
#    'impute_per_sbj': {'nan_level': 'White'}}},
#  'ethnicity': {'input': False,
#   'src_names': ['ethnicity', 'Ethnicity'],
#   'label': 'subject ethnicity',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'African American': ['aa', 'African american'],
#     'Asian': ['asian', 'Asian'],
#     'Histopian': ['hist', 'histopian', 'Histopian']},
#    'impute_per_sbj': {'nan_level': 'White'}}},
#  'temp': {'input': True,
#   'src_names': ['Temp', 'tempc'],
#   'label': 'subject body temperature',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'minmax',
#    'unit': 'celsius',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 5,
#     'value_max': 60},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'heart_rate': {'input': True,
#   'src_names': ['hr', 'heartrate'],
#   'label': 'subject heart rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'beats per minute',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 10,
#     'value_max': 200},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'systolic_blood_pressure': {'input': True,
#   'src_names': ['SBP', 'sysbp'],
#   'label': 'subject systolic blood pressure',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'mm Hg',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'diastolic_blood_pressure': {'input': True,
#   'src_names': ['DBP', 'diasbp'],
#   'label': 'subject diastolic blood pressure',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'mm Hg',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'resp_rate': {'input': True,
#   'src_names': ['rr', 'resprate'],
#   'label': 'subject respiratory rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 200},
#    'unit': 'mm Hg',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'spo2': {'input': False,
#   'src_names': [],
#   'label': 'SpO2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 79},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'glucose': {'input': True,
#   'src_names': ['GLUCOSE', 'Glucose'],
#   'label': 'Glucose',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 49,
#     'value_max': 460},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'bilirubin': {'input': True,
#   'src_names': ['TOTAL.BILIRUBIN', 'bilirubin'],
#   'label': 'Bilirubin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 50},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'potassium': {'input': True,
#   'src_names': ['POTASSIUM', 'Potassium'],
#   'label': 'Potassium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 2.4,
#     'value_max': 6.6},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'albumin': {'input': True,
#   'src_names': ['Albumin', 'ALBUMIN'],
#   'label': 'Albumin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 5},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'calcium': {'input': True,
#   'src_names': ['CALCIUM', 'Calcium'],
#   'label': 'Calcium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 6.1,
#     'value_max': 12},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'wbc': {'input': True,
#   'src_names': ['WHITE.BLOOD.CELL.COUNT', 'WBC'],
#   'label': 'WBC',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 33.85},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'creatinine': {'input': True,
#   'src_names': ['CREATININE', 'Creatinine'],
#   'label': 'Creatinine',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 10},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'platelet_count': {'input': True,
#   'src_names': ['PLATELET.COUNT', 'plateletcount'],
#   'label': 'PlateletCount',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1001},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'alt': {'input': True,
#   'src_names': ['ALT.GPT', 'ALT'],
#   'label': 'ALT',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1085},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'alp': {'input': True,
#   'src_names': ['ALKALINE.PHOSPHATASE', 'ALP'],
#   'label': 'ALP',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 800},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'ast': {'input': True,
#   'src_names': ['AST.GOT', 'AST'],
#   'label': 'AST',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1203},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'paco2': {'input': True,
#   'src_names': ['PCO2', 'PaCO2'],
#   'label': 'PaCO2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100.5},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'chloride': {'input': True,
#   'src_names': ['CHLORIDE', 'Chloride'],
#   'label': 'Chloride',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 83,
#     'value_max': 132},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'troponin': {'input': True,
#   'src_names': ['TROPONIN.I', 'Troponin'],
#   'label': 'Troponin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 23.5},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'ptt': {'input': True,
#   'src_names': ['PARTIAL.THROMBOPLASTIN.TIME', 'PTT'],
#   'label': 'partial_thromboplastin_time',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 140},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'lactate': {'input': True,
#   'src_names': ['Lactate', 'LACTIC.ACID'],
#   'label': 'Lactate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 19.1},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'bun': {'input': True,
#   'src_names': ['BLOOD.UREA.NITROGEN', 'BUN'],
#   'label': 'BUN',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 143},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'magnesium': {'input': True,
#   'src_names': ['MAGNESIUM', 'Magnesium'],
#   'label': 'Magnesium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 3.4},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}}}

# %% [markdown]
# ## see! powerful Law of Large Number

# %%
bsi_stream.engineer.DefineEpisode(input_time_len=2*24*60, output_time_len=1, time_resolution=60, time_lag=0, anchor_gap=7*24*60)
bsi_stream.engineer.BuildMVTS(csv_pool_path, nsbj=50, valid_frac=0, test_frac=0, batch_size=32, impute_input='lalala', impute_output='lalala')
X_train, Y_train, X_valid, Y_valid, X_test, Y_test = bsi_stream.engineer.ExtractXY(shape_type="2d")
bsi_stream.engineer.info()
# Out:
#
# Success! An episode is defined to
# --- use 2880 minute(s) long input variables
# --- predict 1 minute(s) response variables into the future
# --- lag 0 minute(s) between predictors and responses
# --- increase by every 60 minute(s)
# --- last at most 10080 minute(s) long
# Success! Engineer has updated attributes --- episode.
# Sucess!  50 out of 26093 subjects are sampled!
# --- fix upper boundary for age by 110.0
# --- fix lower boundary for age by 22.0
# --- minmax scaling temp
# --- fix upper boundary for heart_rate by nan
# --- fix lower boundary for heart_rate by nan
# --- fix upper boundary for systolic_blood_pressure by nan
# --- fix lower boundary for systolic_blood_pressure by nan
# --- fix upper boundary for diastolic_blood_pressure by nan
# --- fix lower boundary for diastolic_blood_pressure by nan
# --- fix upper boundary for resp_rate by nan
# --- fix lower boundary for resp_rate by nan
# --- fix upper boundary for glucose by 460.0
# --- fix lower boundary for glucose by 49.0
# --- fix upper boundary for bilirubin by 50.0
# --- fix lower boundary for bilirubin by 0.1
# --- fix upper boundary for potassium by 6.6
# --- fix lower boundary for potassium by 2.5
# --- fix upper boundary for albumin by nan
# --- fix lower boundary for albumin by nan
# --- fix upper boundary for calcium by 12.0
# --- fix lower boundary for calcium by 6.1
# --- fix upper boundary for wbc by 33.85
# --- fix lower boundary for wbc by 1.4
# --- fix upper boundary for creatinine by 10.0
# --- fix lower boundary for creatinine by 0.4
# --- fix upper boundary for platelet_count by nan
# --- fix lower boundary for platelet_count by nan
# --- fix upper boundary for alt by 748.0
# --- fix lower boundary for alt by 6.0
# --- fix upper boundary for alp by 800.0
# --- fix lower boundary for alp by 19.0
# --- fix upper boundary for ast by 1203.0
# --- fix lower boundary for ast by 8.0
# --- fix upper boundary for paco2 by nan
# --- fix lower boundary for paco2 by nan
# --- fix upper boundary for chloride by 120.0
# --- fix lower boundary for chloride by 83.0
# --- fix upper boundary for troponin by nan
# --- fix lower boundary for troponin by nan
# --- fix upper boundary for ptt by 140.0
# --- fix lower boundary for ptt by 21.7
# --- fix upper boundary for lactate by nan
# --- fix lower boundary for lactate by nan
# --- fix upper boundary for bun by 143.0
# --- fix lower boundary for bun by 2.0
# --- fix upper boundary for magnesium by 3.3
# --- fix lower boundary for magnesium by 1.1
# --- fix upper boundary for age by 110.0
# --- fix lower boundary for age by 22.0
# --- fix upper boundary for age by nan
# --- fix lower boundary for age by nan
# --- minmax scaling temp
# --- fix upper boundary for heart_rate by nan
# --- fix lower boundary for heart_rate by nan
# --- fix upper boundary for systolic_blood_pressure by nan
# --- fix lower boundary for systolic_blood_pressure by nan
# --- fix upper boundary for diastolic_blood_pressure by nan
# --- fix lower boundary for diastolic_blood_pressure by nan
# --- fix upper boundary for resp_rate by nan
# --- fix lower boundary for resp_rate by nan
# --- fix upper boundary for glucose by nan
# --- fix lower boundary for glucose by nan
# --- fix upper boundary for bilirubin by nan
# --- fix lower boundary for bilirubin by nan
# --- fix upper boundary for potassium by nan
# --- fix lower boundary for potassium by nan
# --- fix upper boundary for albumin by nan
# --- fix lower boundary for albumin by nan
# --- fix upper boundary for calcium by nan
# --- fix lower boundary for calcium by nan
# --- fix upper boundary for wbc by 33.85
# --- fix lower boundary for wbc by 2.32
# --- fix upper boundary for creatinine by nan
# --- fix lower boundary for creatinine by nan
# --- fix upper boundary for platelet_count by 1001.0
# --- fix lower boundary for platelet_count by 12.0
# --- fix upper boundary for alt by nan
# --- fix lower boundary for alt by nan
# --- fix upper boundary for alp by nan
# --- fix lower boundary for alp by nan
# --- fix upper boundary for ast by nan
# --- fix lower boundary for ast by nan
# --- fix upper boundary for paco2 by nan
# --- fix lower boundary for paco2 by nan
# --- fix upper boundary for chloride by nan
# --- fix lower boundary for chloride by nan
# --- fix upper boundary for troponin by nan
# --- fix lower boundary for troponin by nan
# --- fix upper boundary for ptt by nan
# --- fix lower boundary for ptt by nan
# --- fix upper boundary for lactate by nan
# --- fix lower boundary for lactate by nan
# --- fix upper boundary for bun by nan
# --- fix lower boundary for bun by nan
# --- fix upper boundary for magnesium by nan
# --- fix lower boundary for magnesium by nan
# --- prepare episodes for uva_8015
# Success! Output/responce variable mean in current sample space  ---
# y___neg    1.0
# y___pos    0.0
# dtype: float64
# --- prepare episodes for mimic_21450
# Success! Output/responce variable mean in current sample space  ---
# y___neg    1.0
# y___pos    0.0
# dtype: float64
# --- prepare episodes for mimic_15098
# Success! Output/responce variable mean in current sample space  ---
# y___neg    1.0
# y___pos    0.0
# dtype: float64
# --- prepare episodes for uva_8795
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.8
# y___pos    0.2
# dtype: float64
# --- prepare episodes for mimic_76034
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.833333
# y___pos    0.166667
# dtype: float64
# --- prepare episodes for mimic_21325
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.714286
# y___pos    0.285714
# dtype: float64
# --- prepare episodes for mimic_48087
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.75
# y___pos    0.25
# dtype: float64
# --- prepare episodes for mimic_20805
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.8
# y___pos    0.2
# dtype: float64
# --- prepare episodes for mimic_9206
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.833333
# y___pos    0.166667
# dtype: float64
# --- prepare episodes for mimic_28296
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.846154
# y___pos    0.153846
# dtype: float64
# --- prepare episodes for mimic_952
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.857143
# y___pos    0.142857
# dtype: float64
# --- prepare episodes for uva_7785
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.866667
# y___pos    0.133333
# dtype: float64
# --- prepare episodes for uva_4594
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.8125
# y___pos    0.1875
# dtype: float64
# --- prepare episodes for mimic_9250
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.823529
# y___pos    0.176471
# dtype: float64
# --- prepare episodes for mimic_83261
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.833333
# y___pos    0.166667
# dtype: float64
# --- prepare episodes for mimic_2700
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.842105
# y___pos    0.157895
# dtype: float64
# --- prepare episodes for mimic_2984
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.875
# y___pos    0.125
# dtype: float64
# --- prepare episodes for mimic_14755
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.88
# y___pos    0.12
# dtype: float64
# --- prepare episodes for mimic_2775
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.866667
# y___pos    0.133333
# dtype: float64
# --- prepare episodes for mimic_28172
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.875
# y___pos    0.125
# dtype: float64
# --- prepare episodes for mimic_66288
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.878788
# y___pos    0.121212
# dtype: float64
# --- prepare episodes for mimic_7233
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.882353
# y___pos    0.117647
# dtype: float64
# --- prepare episodes for mimic_30978
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.885714
# y___pos    0.114286
# dtype: float64
# --- prepare episodes for uva_2101
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.888889
# y___pos    0.111111
# dtype: float64
# --- prepare episodes for mimic_14579
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.9
# y___pos    0.1
# dtype: float64
# --- prepare episodes for mimic_72630
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.902439
# y___pos    0.097561
# dtype: float64
# --- prepare episodes for uva_4378
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.904762
# y___pos    0.095238
# dtype: float64
# --- prepare episodes for mimic_50643
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.883721
# y___pos    0.116279
# dtype: float64
# --- prepare episodes for mimic_54020
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.888889
# y___pos    0.111111
# dtype: float64
# --- prepare episodes for uva_1494
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.893617
# y___pos    0.106383
# dtype: float64
# --- prepare episodes for mimic_16622
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.895833
# y___pos    0.104167
# dtype: float64
# --- prepare episodes for mimic_29325
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.897959
# y___pos    0.102041
# dtype: float64
# --- prepare episodes for uva_3142
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.882353
# y___pos    0.117647
# dtype: float64
# --- prepare episodes for mimic_24804
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.884615
# y___pos    0.115385
# dtype: float64
# --- prepare episodes for uva_2332
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.886792
# y___pos    0.113208
# dtype: float64
# --- prepare episodes for uva_4599
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.888889
# y___pos    0.111111
# dtype: float64
# --- prepare episodes for mimic_55729
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.890909
# y___pos    0.109091
# dtype: float64
# --- prepare episodes for mimic_7766
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.892857
# y___pos    0.107143
# dtype: float64
# --- prepare episodes for uva_7812
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.852459
# y___pos    0.147541
# dtype: float64
# --- prepare episodes for mimic_48556
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.854839
# y___pos    0.145161
# dtype: float64
# --- prepare episodes for mimic_2836
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.857143
# y___pos    0.142857
# dtype: float64
# --- prepare episodes for mimic_8036
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.859375
# y___pos    0.140625
# dtype: float64
# --- prepare episodes for mimic_42451
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.861538
# y___pos    0.138462
# dtype: float64
# --- prepare episodes for mimic_17543
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.863636
# y___pos    0.136364
# dtype: float64
# --- prepare episodes for mimic_20224
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.850746
# y___pos    0.149254
# dtype: float64
# --- prepare episodes for mimic_90040
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.852941
# y___pos    0.147059
# dtype: float64
# --- prepare episodes for uva_228
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.855072
# y___pos    0.144928
# dtype: float64
# --- prepare episodes for mimic_620
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.857143
# y___pos    0.142857
# dtype: float64
# --- prepare episodes for uva_8360
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.859155
# y___pos    0.140845
# dtype: float64
# --- prepare episodes for mimic_29224
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.861111
# y___pos    0.138889
# dtype: float64
# Success! Engineer has updated attributes --- mvts_df, input_vars, output_vars.
# Success! Engineer has updated attributes --- train_df, valid_df and test_df.
# --- Unrecogenized imputation method. original df returned
# --- Unrecogenized imputation method. original df returned
# Success! Engineer has updated attributes --- train_df_imputed, valid_df_imputed and test_df_imputed.
# Success! Engineer has updated attributes --- train_tfds, valid_tfds and test_tfds.
#
# ----------------------------- Engineer Attributes List ------------------------
#
# ['work_dir', 'meta_dir', 'variable_dict', 'csv_source_dict', 'sql_source_dict', 'input_vars', 'output_vars', 'episode', 'sample_info', 'mvts_df', 'mvts_tfds', 'train_df', 'valid_df', 'test_df', 'train_df_imputed', 'valid_df_imputed', 'test_df_imputed', 'train_tfds', 'valid_tfds', 'test_tfds']
#
# ------------------------------------- Inputs  ---------------------------------
#
# ['age___vital', 'age___lab', 'temp___vital', 'heart_rate___vital', 'systolic_blood_pressure___vital', 'diastolic_blood_pressure___vital', 'resp_rate___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'wbc___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'paco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital']
#
# ------------------------------------- Outputs ---------------------------------
#
# ['y___neg', 'y___pos']
#
# ------------------ train_tfds / valid_tfds / test_tfds batch shape --------------
#
# Inputs shape (batch size, time bins, variables): (32, 48, 25)
# Labels shape (batch size, time bins, variables): (32, 1, 2)
#
# ---------------------- train_df / train_df_imputed shape ----------------------
#
# (3528, 32)
#
# ---------------------- valid_df / valid_df_imputed shape ----------------------
#
#
# ------------------------ test_df / test_df_imputed shape ----------------------

# %%
bsi_stream.engineer.DefineEpisode(input_time_len=2*24*60, output_time_len=1, time_resolution=60, time_lag=0, anchor_gap=7*24*60)
bsi_stream.engineer.BuildMVTS(csv_pool_path, nsbj=333, valid_frac=0.2, test_frac=0.1, batch_size=32, impute_input='median', impute_output='median')
X_train, Y_train, X_valid, Y_valid, X_test, Y_test = bsi_stream.engineer.ExtractXY(shape_type="2d")
bsi_stream.engineer.info()
