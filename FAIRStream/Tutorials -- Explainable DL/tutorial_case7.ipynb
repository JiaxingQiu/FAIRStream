# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import scipy
from matplotlib import colors

import FAIRStream

# %%
# csv pool folder directory
csv_pool_path = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/csv_pool'
# current experiment working directory
work_dir = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case_txp'

# %%
# initiate a FAIRStream object instance for BSI project
bsi_stream = FAIRStream.FAIRStream(work_dir)
# take a look at dictionaries in engineer's hands
#bsi_stream.engineer.csv_source_dict
bsi_stream.engineer.variable_dict
# Out:
# Success: Querier has initiated a csv source dictionary in:/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case_txp/meta_data/csv_source_dict_demo.json
# Success: Querier has initiated a variable dictionary in:/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case_txp/meta_data/variable_dict_demo.json
# Unable to read sql source dictionary. Use Querier.update_sql_source_dict() to build one.
# {'__uid': {'src_names': ['id', 'ID', 'subject_id', 'subject_id'],
#   'label': 'unique subject id for current study',
#   'unique_per_sbj': True},
#  '__time': {'src_names': ['tsa', 'tsa', 'timeMinutes', 'timeMinutes'],
#   'label': 'time since admission',
#   'unit': 'minute'},
#  '__anchor': {'src_names': ['True_positive', 'True positive'],
#   'label': 'anchor for an episode',
#   'unique_per_sbj': False,
#   'factor': {'levels': {'__neg_nbc': ['0', '0.0', 'nan'],
#     '__pos': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': '__neg_nbc'}}},
#  'y': {'output': True,
#   'src_names': ['True_positive', 'True positive'],
#   'label': 'Event outcome result',
#   'unique_per_sbj': False,
#   'factor': {'levels': {'nbc': ['nan'],
#     'neg': ['0', '0.0'],
#     'pos': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': 'nbc'}}},
#  'txp': {'input': True,
#   'src_names': ['Confirmed Txp'],
#   'label': 'Transplant recipient',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'no': ['0', '0.0', 'nan'], 'yes': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': 'no'}}},
#  'age': {'input': True,
#   'src_names': ['age', 'AGE'],
#   'label': 'age at admission',
#   'unique_per_sbj': True,
#   'numeric': {'scaler': 'none',
#    'unit': 'year',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 110},
#    'impute_per_sbj': {'forward': 0, 'backward': 0}}},
#  'temp': {'input': True,
#   'src_names': ['Temp', 'tempc'],
#   'label': 'subject body temperature',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'celsius',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 33,
#     'value_max': 50},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'heart_rate': {'input': True,
#   'src_names': ['hr', 'heartrate'],
#   'label': 'subject heart rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'beats per minute',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 10,
#     'value_max': 200},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'resp_rate': {'input': True,
#   'src_names': ['rr', 'resprate'],
#   'label': 'subject respiratory rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 200},
#    'unit': 'mm Hg',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'spo2': {'input': True,
#   'src_names': ['so2'],
#   'label': 'SpO2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 79},
#    'unit': '',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'x_hr_rr': {'input': True,
#   'src_names': ['x.hr.rr'],
#   'label': 'cross correlation between HR and resp_rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -1,
#     'value_max': 1},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'x_hr_spo2': {'input': True,
#   'src_names': ['x.hr.spo2'],
#   'label': 'cross correlation between HR and spo2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -1,
#     'value_max': 1},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'x_rr_spo2': {'input': True,
#   'src_names': ['x.hr.spo2'],
#   'label': 'cross correlation between resp_rate and spo2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -1,
#     'value_max': 1},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  's_hr': {'input': True,
#   'src_names': ['s.hr'],
#   'label': 'HR sd',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -99999,
#     'value_max': 99999},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  's_rr': {'input': True,
#   'src_names': ['s.rr'],
#   'label': 'resp_rate sd',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -99999,
#     'value_max': 99999},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  's_so2': {'input': True,
#   'src_names': ['s.so2'],
#   'label': 'SPO2 sd',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -99999,
#     'value_max': 99999},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'systolic_blood_pressure': {'input': True,
#   'src_names': ['SBP', 'sysbp'],
#   'label': 'subject systolic blood pressure',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'mm Hg',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 40,
#     'value_max': 250},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'diastolic_blood_pressure': {'input': True,
#   'src_names': ['DBP', 'diasbp'],
#   'label': 'subject diastolic blood pressure',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'mm Hg',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 26,
#     'value_max': 150},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'glucose': {'input': True,
#   'src_names': ['GLUCOSE', 'Glucose'],
#   'label': 'Glucose',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 49,
#     'value_max': 460},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'bilirubin': {'input': True,
#   'src_names': ['TOTAL.BILIRUBIN', 'bilirubin'],
#   'label': 'Bilirubin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 50},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'potassium': {'input': True,
#   'src_names': ['POTASSIUM', 'Potassium'],
#   'label': 'Potassium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 2.4,
#     'value_max': 6.6},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'albumin': {'input': True,
#   'src_names': ['Albumin', 'ALBUMIN'],
#   'label': 'Albumin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 5},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'calcium': {'input': True,
#   'src_names': ['CALCIUM', 'Calcium'],
#   'label': 'Calcium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 6.1,
#     'value_max': 12},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'sodium': {'input': True,
#   'src_names': ['SODIUM', 'Sodium'],
#   'label': 'Sodium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 119,
#     'value_max': 172},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'wbc': {'input': True,
#   'src_names': ['WHITE.BLOOD.CELL.COUNT', 'WBC'],
#   'label': 'WBC',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 33.85},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'phosphorus': {'input': True,
#   'src_names': ['PHOSPHORUS'],
#   'label': 'Phosphorus',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 5,
#     'value_max': 8},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'protin_inr': {'input': True,
#   'src_names': ['PROTIME_INR'],
#   'label': 'Protin_inr',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 5},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'creatinine': {'input': True,
#   'src_names': ['CREATININE', 'Creatinine'],
#   'label': 'Creatinine',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 10},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'platelet_count': {'input': True,
#   'src_names': ['PLATELET.COUNT', 'plateletcount'],
#   'label': 'PlateletCount',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1001},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'alt': {'input': True,
#   'src_names': ['ALT.GPT', 'ALT'],
#   'label': 'ALT',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1085},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'alp': {'input': True,
#   'src_names': ['ALKALINE.PHOSPHATASE', 'ALP'],
#   'label': 'ALP',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 800},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'ast': {'input': True,
#   'src_names': ['AST.GOT', 'AST'],
#   'label': 'AST',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1203},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'pco2': {'input': True,
#   'src_names': ['PCO2', 'PaCO2'],
#   'label': 'PCO2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100.5},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'chloride': {'input': True,
#   'src_names': ['CHLORIDE', 'Chloride'],
#   'label': 'Chloride',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 83,
#     'value_max': 132},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'troponin': {'input': True,
#   'src_names': ['TROPONIN.I', 'Troponin'],
#   'label': 'Troponin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 23.5},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'ptt': {'input': True,
#   'src_names': ['PARTIAL.THROMBOPLASTIN.TIME', 'PTT'],
#   'label': 'partial_thromboplastin_time',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 140},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'lactate': {'input': True,
#   'src_names': ['Lactate', 'LACTIC.ACID'],
#   'label': 'Lactate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 19.1},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'bun': {'input': True,
#   'src_names': ['BLOOD.UREA.NITROGEN', 'BUN'],
#   'label': 'BUN',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 143},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'o2sat': {'input': True,
#   'src_names': ['OXYGEN_SATURATION'],
#   'label': 'Oxygen Satuation',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 17.6},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'magnesium': {'input': True,
#   'src_names': ['MAGNESIUM', 'Magnesium'],
#   'label': 'Magnesium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 3.4},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}}}

# %%
# define an episode (notice that the engineer now has new attributes)
bsi_stream.engineer.DefineEpisode(input_time_len=2*24*60, # using vital signs and labs 4 days prior to a culture 
                                  output_time_len=24*60, # predict one time unit into the future
                                  time_resolution=60, # aggregate minutely data to one row per hour 
                                  time_lag=0,  # no time lag between predictors and response
                                  anchor_gap=7*24*60) # the minimum distance between two episodes
# Out:
#
# Success! An episode is defined to
# --- use 2880 minute(s) long input variables
# --- predict 1440 minute(s) response variables into the future
# --- lag 0 minute(s) between predictors and responses
# --- increase by every 60 minute(s)
# --- last at most 10080 minute(s) long
# Success! Engineer has updated attributes --- episode.

# %%
# Build MVTS dataframe or tfds  (notice that the engineer now has new attributes)
bsi_stream.engineer.BuildMVTS(csv_pool_path, 
                              #nsbj = 6000, # number of subjects / patients to sample from the pool 
                              nsbj = 60, # number of subjects / patients to sample from the pool 
                              replace=True, # sample with replacement or not 
                              valid_frac = 0.2, # fraction of number of subjects in validation dataset
                              test_frac = 0, # fraction of number of subjects in left-out test dataset
                              batch_size = 64, # batch size (usually 32,64,128..)
                              impute_input='median', # imputation on predictors
                              impute_output='median' )# imputation on response (no need in BSI project)

# please see the end of console 
# # --- Success! Engineer has updated attributes --- train_df_imputed, valid_df_imputed and test_df_imputed. 
# # --- Success! Engineer has updated attributes --- train_tfds, valid_tfds and test_tfds.
# Out:
# Engineer is sampling with replacement ---
# Success!  60 out of 5671 subjects are sampled from csv pool of size 26093 !
# --- fix upper boundary for age by nan
# --- fix lower boundary for age by nan
# --- fix upper boundary for temp by nan
# --- fix lower boundary for temp by nan
# --- fix upper boundary for heart_rate by nan
# --- fix lower boundary for heart_rate by nan
# --- fix upper boundary for resp_rate by nan
# --- fix lower boundary for resp_rate by nan
# --- fix upper boundary for spo2 by nan
# --- fix lower boundary for spo2 by nan
# --- fix upper boundary for x_hr_rr by nan
# --- fix lower boundary for x_hr_rr by nan
# --- fix upper boundary for s_hr by nan
# --- fix lower boundary for s_hr by nan
# --- fix upper boundary for s_rr by nan
# --- fix lower boundary for s_rr by nan
# --- fix upper boundary for s_so2 by nan
# --- fix lower boundary for s_so2 by nan
# --- fix upper boundary for systolic_blood_pressure by nan
# --- fix lower boundary for systolic_blood_pressure by nan
# --- fix upper boundary for diastolic_blood_pressure by nan
# --- fix lower boundary for diastolic_blood_pressure by nan
# --- fix upper boundary for glucose by nan
# --- fix lower boundary for glucose by nan
# --- fix upper boundary for bilirubin by nan
# --- fix lower boundary for bilirubin by nan
# --- fix upper boundary for potassium by nan
# --- fix lower boundary for potassium by nan
# --- fix upper boundary for albumin by nan
# --- fix lower boundary for albumin by nan
# --- fix upper boundary for calcium by nan
# --- fix lower boundary for calcium by nan
# --- fix upper boundary for sodium by nan
# --- fix lower boundary for sodium by nan
# --- fix upper boundary for wbc by nan
# --- fix lower boundary for wbc by nan
# --- fix upper boundary for phosphorus by nan
# --- fix lower boundary for phosphorus by nan
# --- fix upper boundary for creatinine by nan
# --- fix lower boundary for creatinine by nan
# --- fix upper boundary for platelet_count by nan
# --- fix lower boundary for platelet_count by nan
# --- fix upper boundary for alt by nan
# --- fix lower boundary for alt by nan
# --- fix upper boundary for alp by nan
# --- fix lower boundary for alp by nan
# --- fix upper boundary for ast by nan
# --- fix lower boundary for ast by nan
# --- fix upper boundary for pco2 by nan
# --- fix lower boundary for pco2 by nan
# --- fix upper boundary for chloride by nan
# --- fix lower boundary for chloride by nan
# --- fix upper boundary for troponin by nan
# --- fix lower boundary for troponin by nan
# --- fix upper boundary for ptt by nan
# --- fix lower boundary for ptt by nan
# --- fix upper boundary for lactate by nan
# --- fix lower boundary for lactate by nan
# --- fix upper boundary for bun by nan
# --- fix lower boundary for bun by nan
# --- fix upper boundary for magnesium by nan
# --- fix lower boundary for magnesium by nan
# --- prepare episodes for uva_8359
# Success! Output/responce variable mean in current sample space  ---
# y___pos    1.0
# y___nbc    0.0
# y___neg    0.0
# dtype: float64
# --- prepare episodes for uva_2730
# Success! Output/responce variable mean in current sample space  ---
# y___pos    1.0
# y___nbc    0.0
# y___neg    0.0
# dtype: float64
# --- prepare episodes for uva_263
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.75
# y___nbc    0.25
# y___neg    0.00
# dtype: float64
# --- prepare episodes for uva_247
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.6
# y___nbc    0.2
# y___neg    0.2
# dtype: float64
# --- prepare episodes for uva_1527
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.500000
# y___nbc    0.333333
# y___neg    0.166667
# dtype: float64
# --- prepare episodes for uva_514
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.428571
# y___nbc    0.285714
# y___neg    0.285714
# dtype: float64
# --- prepare episodes for uva_3333
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.375
# y___nbc    0.250
# y___neg    0.375
# dtype: float64
# --- prepare episodes for uva_7115
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.333333
# y___nbc    0.222222
# y___neg    0.444444
# dtype: float64
# --- prepare episodes for uva_8261
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.3
# y___nbc    0.3
# y___neg    0.4
# dtype: float64
# --- prepare episodes for uva_4002
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.272727
# y___nbc    0.272727
# y___neg    0.454545
# dtype: float64
# --- prepare episodes for uva_5076
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.25
# y___nbc    0.25
# y___neg    0.50
# dtype: float64
# --- prepare episodes for uva_1501
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.230769
# y___nbc    0.230769
# y___neg    0.538462
# dtype: float64
# --- prepare episodes for uva_3322
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.214286
# y___nbc    0.285714
# y___neg    0.500000
# dtype: float64
# --- prepare episodes for uva_4846
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.200000
# y___nbc    0.266667
# y___neg    0.533333
# dtype: float64
# --- prepare episodes for uva_9941
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.277778
# y___nbc    0.277778
# y___neg    0.444444
# dtype: float64
# --- prepare episodes for uva_3685
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.263158
# y___nbc    0.263158
# y___neg    0.473684
# dtype: float64
# --- prepare episodes for uva_6145
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.25
# y___nbc    0.25
# y___neg    0.50
# dtype: float64
# --- prepare episodes for uva_6141
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.238095
# y___nbc    0.238095
# y___neg    0.523810
# dtype: float64
# --- prepare episodes for uva_721
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.227273
# y___nbc    0.227273
# y___neg    0.545455
# dtype: float64
# --- prepare episodes for uva_7747
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.217391
# y___nbc    0.217391
# y___neg    0.565217
# dtype: float64
# --- prepare episodes for uva_8300
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.208333
# y___nbc    0.208333
# y___neg    0.583333
# dtype: float64
# --- prepare episodes for uva_5898
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.2
# y___nbc    0.2
# y___neg    0.6
# dtype: float64
# --- prepare episodes for uva_6765
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.192308
# y___nbc    0.192308
# y___neg    0.615385
# dtype: float64
# --- prepare episodes for uva_9791
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.185185
# y___nbc    0.185185
# y___neg    0.629630
# dtype: float64
# --- prepare episodes for uva_9474
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.178571
# y___nbc    0.178571
# y___neg    0.642857
# dtype: float64
# --- prepare episodes for uva_5288
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.172414
# y___nbc    0.172414
# y___neg    0.655172
# dtype: float64
# --- prepare episodes for uva_7317
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.166667
# y___nbc    0.200000
# y___neg    0.633333
# dtype: float64
# --- prepare episodes for uva_5676
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.161290
# y___nbc    0.225806
# y___neg    0.612903
# dtype: float64
# --- prepare episodes for uva_934
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.15625
# y___nbc    0.25000
# y___neg    0.59375
# dtype: float64
# --- prepare episodes for uva_4533
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.151515
# y___nbc    0.242424
# y___neg    0.606061
# dtype: float64
# --- prepare episodes for uva_4609
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.147059
# y___nbc    0.235294
# y___neg    0.617647
# dtype: float64
# --- prepare episodes for uva_7072
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.142857
# y___nbc    0.228571
# y___neg    0.628571
# dtype: float64
# --- prepare episodes for uva_5768
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.162162
# y___nbc    0.243243
# y___neg    0.594595
# dtype: float64
# --- prepare episodes for uva_8082
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.157895
# y___nbc    0.236842
# y___neg    0.605263
# dtype: float64
# --- prepare episodes for uva_5884
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.153846
# y___nbc    0.230769
# y___neg    0.615385
# dtype: float64
# --- prepare episodes for uva_7708
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.15
# y___nbc    0.25
# y___neg    0.60
# dtype: float64
# --- prepare episodes for uva_6095
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.146341
# y___nbc    0.243902
# y___neg    0.609756
# dtype: float64
# --- prepare episodes for uva_3598
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.142857
# y___nbc    0.261905
# y___neg    0.595238
# dtype: float64
# --- prepare episodes for uva_7928
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.139535
# y___nbc    0.279070
# y___neg    0.581395
# dtype: float64
# --- prepare episodes for uva_4814
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.136364
# y___nbc    0.272727
# y___neg    0.590909
# dtype: float64
# --- prepare episodes for uva_7790
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.133333
# y___nbc    0.288889
# y___neg    0.577778
# dtype: float64
# --- prepare episodes for uva_3157
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.130435
# y___nbc    0.304348
# y___neg    0.565217
# dtype: float64
# --- prepare episodes for uva_6319
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.127660
# y___nbc    0.297872
# y___neg    0.574468
# dtype: float64
# --- prepare episodes for uva_5230
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.125000
# y___nbc    0.291667
# y___neg    0.583333
# dtype: float64
# --- prepare episodes for uva_1681
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.122449
# y___nbc    0.285714
# y___neg    0.591837
# dtype: float64
# --- prepare episodes for uva_288
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.12
# y___nbc    0.28
# y___neg    0.60
# dtype: float64
# --- prepare episodes for uva_3562
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.117647
# y___nbc    0.274510
# y___neg    0.607843
# dtype: float64
# --- prepare episodes for uva_3568
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.115385
# y___nbc    0.288462
# y___neg    0.596154
# dtype: float64
# --- prepare episodes for uva_8668
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.113208
# y___nbc    0.283019
# y___neg    0.603774
# dtype: float64
# --- prepare episodes for uva_1414
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.111111
# y___nbc    0.277778
# y___neg    0.611111
# dtype: float64
# --- prepare episodes for uva_1596
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.109091
# y___nbc    0.290909
# y___neg    0.600000
# dtype: float64
# --- prepare episodes for uva_3521
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.120690
# y___nbc    0.310345
# y___neg    0.568966
# dtype: float64
# --- prepare episodes for uva_2933
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.118644
# y___nbc    0.305085
# y___neg    0.576271
# dtype: float64
# --- prepare episodes for uva_3934
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.116667
# y___nbc    0.316667
# y___neg    0.566667
# dtype: float64
# --- prepare episodes for uva_6880
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.114754
# y___nbc    0.311475
# y___neg    0.573770
# dtype: float64
# --- prepare episodes for uva_3319
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.112903
# y___nbc    0.306452
# y___neg    0.580645
# dtype: float64
# --- prepare episodes for uva_7905
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.111111
# y___nbc    0.301587
# y___neg    0.587302
# dtype: float64
# --- prepare episodes for uva_5752
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.121212
# y___nbc    0.287879
# y___neg    0.590909
# dtype: float64
# --- prepare episodes for uva_6410
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.119403
# y___nbc    0.283582
# y___neg    0.597015
# dtype: float64
# --- prepare episodes for uva_5846
# Success! Output/responce variable mean in current sample space  ---
# y___pos    0.117647
# y___nbc    0.279412
# y___neg    0.602941
# dtype: float64
# Success! Engineer has updated attributes --- mvts_df, input_vars, output_vars.
# Success! Engineer has updated attributes --- train_df, valid_df and test_df.
# Success! Engineer has updated attributes --- train_df_imputed, valid_df_imputed and test_df_imputed.
# Success! Engineer has updated attributes --- train_tfds, valid_tfds and test_tfds.

# %%
bsi_stream.engineer.info()
# Out:
# ----------------------------- Engineer Attributes List ------------------------
#
# ['work_dir', 'meta_dir', 'variable_dict', 'csv_source_dict', 'sql_source_dict', 'input_vars', 'output_vars', 'episode', 'sample_info', 'mvts_df', 'mvts_tfds', 'train_df', 'valid_df', 'test_df', 'train_df_imputed', 'valid_df_imputed', 'test_df_imputed', 'train_tfds', 'valid_tfds', 'test_tfds', 'df_csv_fullname_ls']
#
# ------------------------------------- Inputs  ---------------------------------
#
# ['txp___yes', 'txp___no', 'age___vital', 'temp___vital', 'heart_rate___vital', 'resp_rate___vital', 'spo2___vital', 'x_hr_rr___vital', 's_hr___vital', 's_rr___vital', 's_so2___vital', 'systolic_blood_pressure___vital', 'diastolic_blood_pressure___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'sodium___vital', 'wbc___vital', 'phosphorus___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'pco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital']
#
# ------------------------------------- Outputs ---------------------------------
#
# ['y___pos', 'y___nbc', 'y___neg']
#
# ------------------ train_tfds / valid_tfds / test_tfds batch shape --------------
#
# Inputs shape (batch size, time bins, variables): (54, 48, 33)
# Labels shape (batch size, time bins, variables): (54, 24, 3)
#
# ---------------------- train_df / train_df_imputed shape ----------------------
#
# (3888, 41)
#
# ---------------------- valid_df / valid_df_imputed shape ----------------------
#
# (1008, 41)
#
# ------------------------ test_df / test_df_imputed shape ----------------------

# %%
# # save raw dataframe in a csv
# bsi_stream.engineer.train_df.to_csv("./train_df.csv", index=False)
# bsi_stream.engineer.valid_df.to_csv("./valid_df.csv", index=False)
# bsi_stream.engineer.train_df_imputed.to_csv("./train_df_median.csv", index=False)
# bsi_stream.engineer.valid_df_imputed.to_csv("./valid_df_median.csv", index=False)

# %% [markdown]
# ## Model -- Raw scale

# %%
# read datasets
train_df = pd.read_csv("./train_df.csv")
valid_df = pd.read_csv("./valid_df.csv")

# select modeling time window
train_df = train_df.loc[(train_df['__ep_relative_time']/60>=-24) & (train_df['__ep_relative_time']/60<=0) ,:]
valid_df = valid_df.loc[(valid_df['__ep_relative_time']/60>=-24) & (valid_df['__ep_relative_time']/60<=0) ,:]

# median imputation
train_df.fillna(train_df.median(), inplace=True)
valid_df.fillna(train_df.median(), inplace=True)

# input and output variable name lists
input_vars = ['txp___yes', 'age___vital', 'temp___vital', 'heart_rate___vital', 'resp_rate___vital', 'spo2___vital', 'x_hr_rr___vital', 's_hr___vital', 's_rr___vital', 's_so2___vital', 'systolic_blood_pressure___vital', 'diastolic_blood_pressure___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'sodium___vital', 'wbc___vital', 'phosphorus___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'pco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital']
output_var = ['y___pos']

# # standardize inputs
# train_df[input_vars] = (train_df[input_vars] - train_df[input_vars].mean(axis=0))/train_df[input_vars].std(axis=0)
# valid_df[input_vars] = (valid_df[input_vars] - train_df[input_vars].mean(axis=0))/train_df[input_vars].std(axis=0)

# combine to one dataframe
whole_df = pd.concat([train_df, valid_df], axis=0)
whole_df.describe()
# Out:
#            txp___yes       txp___no    age___vital   temp___vital  \
# count  163925.000000  163925.000000  163925.000000  163925.000000
# mean        0.031569       0.959280      59.053610      98.130162
# std         0.174851       0.197641      16.534095       1.284749
# min         0.000000       0.000000      14.101500      60.800000
# 25%         0.000000       1.000000      49.424096      98.100000
# 50%         0.000000       1.000000      60.267953      98.100000
# 75%         0.000000       1.000000      71.116943      98.100000
# max         1.000000       1.000000      90.000000     105.100000
#
#        heart_rate___vital  resp_rate___vital   spo2___vital  x_hr_rr___vital  \
# count       163925.000000      163925.000000  163925.000000    163925.000000
# mean            92.198995          22.233793      97.465885         0.200550
# std              9.032714           3.062896       1.312926         0.087419
# min             39.448590           5.735512      80.141327        -0.630122
# 25%             91.940753          22.072590      97.606914         0.195842
# 50%             91.940753          22.072590      97.606914         0.195842
# 75%             91.940753          22.072590      97.606914         0.195842
# max            168.179487          70.228390     100.000000         0.928040
#
#         s_hr___vital   s_rr___vital  ...    ptt___vital  lactate___vital  \
# count  163925.000000  163925.000000  ...  163925.000000    163925.000000
# mean        3.772581       4.182335  ...      31.718885         2.142800
# std         1.484878       1.399994  ...       9.304526         1.845225
# min         0.000000       0.000000  ...      19.200000         0.200000
# 25%         3.616698       4.083966  ...      27.700000         1.600000
# 50%         3.616698       4.083966  ...      29.700000         1.700000
# 75%         3.616698       4.083966  ...      32.000000         1.900000
# max        47.721125      17.975902  ...     136.000000        34.200000
#
#          bun___vital  magnesium___vital        y___pos        y___neg  \
# count  163925.000000      163925.000000  163925.000000  163925.000000
# mean       28.747296           1.894027       0.133750       0.658685
# std        22.660112           0.340634       0.340385       0.474152
# min         2.000000           0.600000       0.000000       0.000000
# 25%        15.000000           1.800000       0.000000       0.000000
# 50%        22.000000           1.900000       0.000000       1.000000
# 75%        34.000000           2.000000       0.000000       1.000000
# max       246.000000           7.900000       1.000000       1.000000
#
#              y___nbc     __time_bin  __ep_relative_time     __ep_order
# count  163925.000000  163925.000000       163925.000000  163925.000000
# mean        0.207564      73.844136         -720.000000       1.208327
# std         0.405564     444.434054          432.667473       0.672273
# min         0.000000   -4235.000000        -1440.000000       1.000000
# 25%         0.000000     -15.000000        -1080.000000       1.000000
# 50%         0.000000      -7.000000         -720.000000       1.000000
# 75%         0.000000       0.000000         -360.000000       1.000000
# max         1.000000   16454.000000            0.000000      14.000000
#
# [8 rows x 39 columns]

# %%
# reformat inputs to be 2d image and 1 output per image
X_whole = whole_df[input_vars].values
Y_whole = whole_df[output_var].values
X_whole = np.reshape(X_whole, (-1,25,32) )
Y_whole = np.reshape(Y_whole, (-1,25,1) )[:,0,:]
print(X_whole.shape)
print(Y_whole.shape)

# reformat inputs to be 2d image and 1 output per image
X_train = train_df[input_vars].values
Y_train = train_df[output_var].values
X_train = np.reshape(X_train, (-1,25,32) )
Y_train = np.reshape(Y_train, (-1,25,1) )[:,0,:]
print(X_train.shape)
print(Y_train.shape)

# reformat inputs to be 2d image and 1 output per image
X_valid = valid_df[input_vars].values
Y_valid = valid_df[output_var].values
X_valid = np.reshape(X_valid, (-1,25,32) )
Y_valid = np.reshape(Y_valid, (-1,25,1) )[:,0,:]
print(X_valid.shape)
print(Y_valid.shape)
# Out:
# (6557, 25, 32)
# (6557, 1)
# (5226, 25, 32)
# (5226, 1)
# (1331, 25, 32)
# (1331, 1)

# %% [markdown]
# ### Logistic Regression

# %%
myMetrics = [
    keras.metrics.AUC(name='AUROC', curve='ROC'),
    keras.metrics.AUC(name='AUPRC', curve='PR')
]

keras.backend.clear_session()
mdl = keras.models.Sequential([
    keras.layers.Flatten(input_shape=list(X_train.shape)[1:4]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(1, activation='sigmoid')
])
mdl.summary()
mdl.compile(loss="binary_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
callback = EarlyStopping(monitor='val_loss', patience=10)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-4)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-5)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-6)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-7)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 800)               3200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 801
# =================================================================
# Total params: 4,001
# Trainable params: 2,401
# Non-trainable params: 1,600
# _________________________________________________________________
# Epoch 1/50
# 164/164 [==============================] - 1s 3ms/step - loss: 0.5308 - AUROC: 0.6354 - AUPRC: 0.2389 - val_loss: 4.6490 - val_AUROC: 0.6759 - val_AUPRC: 0.2097
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3339 - AUROC: 0.7650 - AUPRC: 0.4094 - val_loss: 0.4820 - val_AUROC: 0.7643 - val_AUPRC: 0.3709
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3182 - AUROC: 0.8011 - AUPRC: 0.4186 - val_loss: 0.3591 - val_AUROC: 0.7710 - val_AUPRC: 0.4006
# Epoch 4/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3121 - AUROC: 0.7936 - AUPRC: 0.4147 - val_loss: 0.3443 - val_AUROC: 0.7854 - val_AUPRC: 0.4231
# Epoch 5/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3266 - AUROC: 0.8096 - AUPRC: 0.4495 - val_loss: 0.3456 - val_AUROC: 0.7868 - val_AUPRC: 0.4253
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3166 - AUROC: 0.8114 - AUPRC: 0.4366 - val_loss: 0.3522 - val_AUROC: 0.7700 - val_AUPRC: 0.4293
# Epoch 7/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3001 - AUROC: 0.8168 - AUPRC: 0.4550 - val_loss: 0.3436 - val_AUROC: 0.7809 - val_AUPRC: 0.4346
# Epoch 8/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3181 - AUROC: 0.8147 - AUPRC: 0.4861 - val_loss: 0.3380 - val_AUROC: 0.7913 - val_AUPRC: 0.4424
# Epoch 9/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3127 - AUROC: 0.8073 - AUPRC: 0.4820 - val_loss: 0.3444 - val_AUROC: 0.7768 - val_AUPRC: 0.4416
# Epoch 10/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2820 - AUROC: 0.8363 - AUPRC: 0.5028 - val_loss: 0.3527 - val_AUROC: 0.7753 - val_AUPRC: 0.4219
# Epoch 11/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3016 - AUROC: 0.8213 - AUPRC: 0.4715 - val_loss: 0.3537 - val_AUROC: 0.7774 - val_AUPRC: 0.4326
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3105 - AUROC: 0.8267 - AUPRC: 0.5187 - val_loss: 0.3508 - val_AUROC: 0.7834 - val_AUPRC: 0.4262
# Epoch 13/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2911 - AUROC: 0.8358 - AUPRC: 0.5215 - val_loss: 0.3471 - val_AUROC: 0.7860 - val_AUPRC: 0.4252
# Epoch 14/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2913 - AUROC: 0.8376 - AUPRC: 0.5194 - val_loss: 0.3494 - val_AUROC: 0.7838 - val_AUPRC: 0.4353
# Epoch 15/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2924 - AUROC: 0.8417 - AUPRC: 0.5289 - val_loss: 0.3504 - val_AUROC: 0.7703 - val_AUPRC: 0.4136
# Epoch 16/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2887 - AUROC: 0.8403 - AUPRC: 0.5064 - val_loss: 0.3407 - val_AUROC: 0.7851 - val_AUPRC: 0.4520
# Epoch 17/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2920 - AUROC: 0.8257 - AUPRC: 0.5147 - val_loss: 0.3562 - val_AUROC: 0.7842 - val_AUPRC: 0.4314
# Epoch 18/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2918 - AUROC: 0.8320 - AUPRC: 0.4981 - val_loss: 0.3442 - val_AUROC: 0.7840 - val_AUPRC: 0.4470
# Epoch 1/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2867 - AUROC: 0.8418 - AUPRC: 0.5365 - val_loss: 0.3420 - val_AUROC: 0.7869 - val_AUPRC: 0.4512
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2888 - AUROC: 0.8398 - AUPRC: 0.5288 - val_loss: 0.3429 - val_AUROC: 0.7872 - val_AUPRC: 0.4458
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2857 - AUROC: 0.8452 - AUPRC: 0.5413 - val_loss: 0.3422 - val_AUROC: 0.7855 - val_AUPRC: 0.4425
# Epoch 4/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2814 - AUROC: 0.8457 - AUPRC: 0.5575 - val_loss: 0.3406 - val_AUROC: 0.7868 - val_AUPRC: 0.4478
# Epoch 5/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2850 - AUROC: 0.8464 - AUPRC: 0.5407 - val_loss: 0.3409 - val_AUROC: 0.7856 - val_AUPRC: 0.4463
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2888 - AUROC: 0.8417 - AUPRC: 0.5270 - val_loss: 0.3413 - val_AUROC: 0.7861 - val_AUPRC: 0.4405
# Epoch 7/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2827 - AUROC: 0.8475 - AUPRC: 0.5507 - val_loss: 0.3412 - val_AUROC: 0.7844 - val_AUPRC: 0.4431
# Epoch 8/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2823 - AUROC: 0.8498 - AUPRC: 0.5517 - val_loss: 0.3416 - val_AUROC: 0.7851 - val_AUPRC: 0.4402
# Epoch 9/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2834 - AUROC: 0.8499 - AUPRC: 0.5410 - val_loss: 0.3440 - val_AUROC: 0.7837 - val_AUPRC: 0.4374
# Epoch 10/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2833 - AUROC: 0.8486 - AUPRC: 0.5474 - val_loss: 0.3430 - val_AUROC: 0.7839 - val_AUPRC: 0.4435
# Epoch 11/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2852 - AUROC: 0.8495 - AUPRC: 0.5373 - val_loss: 0.3410 - val_AUROC: 0.7846 - val_AUPRC: 0.4422
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2809 - AUROC: 0.8515 - AUPRC: 0.5593 - val_loss: 0.3427 - val_AUROC: 0.7870 - val_AUPRC: 0.4407
# Epoch 13/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2849 - AUROC: 0.8466 - AUPRC: 0.5405 - val_loss: 0.3412 - val_AUROC: 0.7850 - val_AUPRC: 0.4446
# Epoch 14/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2809 - AUROC: 0.8497 - AUPRC: 0.5531 - val_loss: 0.3415 - val_AUROC: 0.7860 - val_AUPRC: 0.4430
# Epoch 1/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2812 - AUROC: 0.8499 - AUPRC: 0.5539 - val_loss: 0.3441 - val_AUROC: 0.7847 - val_AUPRC: 0.4411
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2808 - AUROC: 0.8503 - AUPRC: 0.5555 - val_loss: 0.3433 - val_AUROC: 0.7851 - val_AUPRC: 0.4421
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2856 - AUROC: 0.8451 - AUPRC: 0.5367 - val_loss: 0.3433 - val_AUROC: 0.7850 - val_AUPRC: 0.4407
# Epoch 4/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2803 - AUROC: 0.8515 - AUPRC: 0.5566 - val_loss: 0.3437 - val_AUROC: 0.7858 - val_AUPRC: 0.4432
# Epoch 5/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2831 - AUROC: 0.8495 - AUPRC: 0.5437 - val_loss: 0.3412 - val_AUROC: 0.7851 - val_AUPRC: 0.4435
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2840 - AUROC: 0.8477 - AUPRC: 0.5443 - val_loss: 0.3426 - val_AUROC: 0.7851 - val_AUPRC: 0.4430
# Epoch 7/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2813 - AUROC: 0.8489 - AUPRC: 0.5556 - val_loss: 0.3408 - val_AUROC: 0.7849 - val_AUPRC: 0.4440
# Epoch 8/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2805 - AUROC: 0.8535 - AUPRC: 0.5525 - val_loss: 0.3422 - val_AUROC: 0.7846 - val_AUPRC: 0.4412
# Epoch 9/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2792 - AUROC: 0.8533 - AUPRC: 0.5626 - val_loss: 0.3451 - val_AUROC: 0.7848 - val_AUPRC: 0.4376
# Epoch 10/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2830 - AUROC: 0.8507 - AUPRC: 0.5461 - val_loss: 0.3444 - val_AUROC: 0.7843 - val_AUPRC: 0.4374
# Epoch 11/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2826 - AUROC: 0.8487 - AUPRC: 0.5473 - val_loss: 0.3441 - val_AUROC: 0.7838 - val_AUPRC: 0.4392
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2820 - AUROC: 0.8508 - AUPRC: 0.5475 - val_loss: 0.3431 - val_AUROC: 0.7851 - val_AUPRC: 0.4428
# Epoch 13/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2773 - AUROC: 0.8565 - AUPRC: 0.5672 - val_loss: 0.3418 - val_AUROC: 0.7866 - val_AUPRC: 0.4414
# Epoch 14/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2835 - AUROC: 0.8468 - AUPRC: 0.5471 - val_loss: 0.3414 - val_AUROC: 0.7856 - val_AUPRC: 0.4419
# Epoch 15/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2814 - AUROC: 0.8464 - AUPRC: 0.5617 - val_loss: 0.3407 - val_AUROC: 0.7862 - val_AUPRC: 0.4432
# Epoch 16/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2798 - AUROC: 0.8526 - AUPRC: 0.5593 - val_loss: 0.3413 - val_AUROC: 0.7851 - val_AUPRC: 0.4416
# Epoch 17/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2827 - AUROC: 0.8499 - AUPRC: 0.5480 - val_loss: 0.3416 - val_AUROC: 0.7848 - val_AUPRC: 0.4419
# Epoch 18/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2806 - AUROC: 0.8532 - AUPRC: 0.5538 - val_loss: 0.3445 - val_AUROC: 0.7849 - val_AUPRC: 0.4384
# Epoch 19/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2821 - AUROC: 0.8502 - AUPRC: 0.5477 - val_loss: 0.3428 - val_AUROC: 0.7849 - val_AUPRC: 0.4415
# Epoch 20/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2802 - AUROC: 0.8513 - AUPRC: 0.5592 - val_loss: 0.3434 - val_AUROC: 0.7869 - val_AUPRC: 0.4415
# Epoch 21/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2857 - AUROC: 0.8394 - AUPRC: 0.5479 - val_loss: 0.3416 - val_AUROC: 0.7850 - val_AUPRC: 0.4422
# Epoch 22/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2829 - AUROC: 0.8453 - AUPRC: 0.5539 - val_loss: 0.3465 - val_AUROC: 0.7852 - val_AUPRC: 0.4384
# Epoch 23/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2789 - AUROC: 0.8549 - AUPRC: 0.5597 - val_loss: 0.3445 - val_AUROC: 0.7844 - val_AUPRC: 0.4399
# Epoch 24/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2811 - AUROC: 0.8513 - AUPRC: 0.5551 - val_loss: 0.3424 - val_AUROC: 0.7853 - val_AUPRC: 0.4421
# Epoch 25/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2829 - AUROC: 0.8479 - AUPRC: 0.5502 - val_loss: 0.3421 - val_AUROC: 0.7840 - val_AUPRC: 0.4413
# Epoch 1/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2809 - AUROC: 0.8516 - AUPRC: 0.5535 - val_loss: 0.3443 - val_AUROC: 0.7847 - val_AUPRC: 0.4390
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2821 - AUROC: 0.8487 - AUPRC: 0.5477 - val_loss: 0.3422 - val_AUROC: 0.7859 - val_AUPRC: 0.4423
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2801 - AUROC: 0.8531 - AUPRC: 0.5575 - val_loss: 0.3420 - val_AUROC: 0.7861 - val_AUPRC: 0.4432
# Epoch 4/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2841 - AUROC: 0.8462 - AUPRC: 0.5477 - val_loss: 0.3429 - val_AUROC: 0.7847 - val_AUPRC: 0.4427
# Epoch 5/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2821 - AUROC: 0.8498 - AUPRC: 0.5511 - val_loss: 0.3420 - val_AUROC: 0.7846 - val_AUPRC: 0.4422
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2803 - AUROC: 0.8542 - AUPRC: 0.5518 - val_loss: 0.3416 - val_AUROC: 0.7842 - val_AUPRC: 0.4443
# Epoch 7/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2840 - AUROC: 0.8454 - AUPRC: 0.5456 - val_loss: 0.3423 - val_AUROC: 0.7857 - val_AUPRC: 0.4420
# Epoch 8/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2760 - AUROC: 0.8592 - AUPRC: 0.5652 - val_loss: 0.3422 - val_AUROC: 0.7842 - val_AUPRC: 0.4419
# Epoch 9/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2815 - AUROC: 0.8489 - AUPRC: 0.5561 - val_loss: 0.3408 - val_AUROC: 0.7871 - val_AUPRC: 0.4443
# Epoch 10/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2781 - AUROC: 0.8544 - AUPRC: 0.5640 - val_loss: 0.3423 - val_AUROC: 0.7847 - val_AUPRC: 0.4420
# Epoch 11/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2768 - AUROC: 0.8571 - AUPRC: 0.5636 - val_loss: 0.3434 - val_AUROC: 0.7853 - val_AUPRC: 0.4414
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2782 - AUROC: 0.8524 - AUPRC: 0.5684 - val_loss: 0.3417 - val_AUROC: 0.7850 - val_AUPRC: 0.4406
# Epoch 13/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2784 - AUROC: 0.8557 - AUPRC: 0.5577 - val_loss: 0.3419 - val_AUROC: 0.7844 - val_AUPRC: 0.4417
# Epoch 14/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2792 - AUROC: 0.8536 - AUPRC: 0.5593 - val_loss: 0.3415 - val_AUROC: 0.7850 - val_AUPRC: 0.4438
# Epoch 15/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2804 - AUROC: 0.8501 - AUPRC: 0.5592 - val_loss: 0.3429 - val_AUROC: 0.7847 - val_AUPRC: 0.4424
# Epoch 16/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2814 - AUROC: 0.8514 - AUPRC: 0.5522 - val_loss: 0.3433 - val_AUROC: 0.7841 - val_AUPRC: 0.4423
# Epoch 17/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2776 - AUROC: 0.8542 - AUPRC: 0.5690 - val_loss: 0.3436 - val_AUROC: 0.7857 - val_AUPRC: 0.4426
# Epoch 18/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2837 - AUROC: 0.8489 - AUPRC: 0.5433 - val_loss: 0.3428 - val_AUROC: 0.7841 - val_AUPRC: 0.4414
# Epoch 19/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2824 - AUROC: 0.8491 - AUPRC: 0.5496 - val_loss: 0.3462 - val_AUROC: 0.7842 - val_AUPRC: 0.4388
# Epoch 1/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2813 - AUROC: 0.8528 - AUPRC: 0.5478 - val_loss: 0.3442 - val_AUROC: 0.7851 - val_AUPRC: 0.4422
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2836 - AUROC: 0.8459 - AUPRC: 0.5480 - val_loss: 0.3429 - val_AUROC: 0.7849 - val_AUPRC: 0.4409
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2802 - AUROC: 0.8511 - AUPRC: 0.5586 - val_loss: 0.3415 - val_AUROC: 0.7845 - val_AUPRC: 0.4411
# Epoch 4/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2818 - AUROC: 0.8503 - AUPRC: 0.5510 - val_loss: 0.3415 - val_AUROC: 0.7858 - val_AUPRC: 0.4424
# Epoch 5/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2826 - AUROC: 0.8524 - AUPRC: 0.5465 - val_loss: 0.3414 - val_AUROC: 0.7853 - val_AUPRC: 0.4442
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2811 - AUROC: 0.8518 - AUPRC: 0.5558 - val_loss: 0.3418 - val_AUROC: 0.7855 - val_AUPRC: 0.4412
# Epoch 7/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2833 - AUROC: 0.8502 - AUPRC: 0.5430 - val_loss: 0.3426 - val_AUROC: 0.7851 - val_AUPRC: 0.4417
# Epoch 8/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2798 - AUROC: 0.8532 - AUPRC: 0.5576 - val_loss: 0.3419 - val_AUROC: 0.7861 - val_AUPRC: 0.4431
# Epoch 9/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2825 - AUROC: 0.8483 - AUPRC: 0.5510 - val_loss: 0.3412 - val_AUROC: 0.7854 - val_AUPRC: 0.4431
# Epoch 10/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2802 - AUROC: 0.8512 - AUPRC: 0.5581 - val_loss: 0.3434 - val_AUROC: 0.7848 - val_AUPRC: 0.4420
# Epoch 11/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2775 - AUROC: 0.8517 - AUPRC: 0.5719 - val_loss: 0.3416 - val_AUROC: 0.7854 - val_AUPRC: 0.4458
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2804 - AUROC: 0.8523 - AUPRC: 0.5526 - val_loss: 0.3425 - val_AUROC: 0.7854 - val_AUPRC: 0.4434
# Epoch 13/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2788 - AUROC: 0.8539 - AUPRC: 0.5625 - val_loss: 0.3427 - val_AUROC: 0.7859 - val_AUPRC: 0.4433
# Epoch 14/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2798 - AUROC: 0.8515 - AUPRC: 0.5571 - val_loss: 0.3432 - val_AUROC: 0.7852 - val_AUPRC: 0.4425
# Epoch 15/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2814 - AUROC: 0.8488 - AUPRC: 0.5551 - val_loss: 0.3421 - val_AUROC: 0.7853 - val_AUPRC: 0.4417
# Epoch 16/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2780 - AUROC: 0.8557 - AUPRC: 0.5650 - val_loss: 0.3428 - val_AUROC: 0.7861 - val_AUPRC: 0.4412
# Epoch 17/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2803 - AUROC: 0.8525 - AUPRC: 0.5567 - val_loss: 0.3423 - val_AUROC: 0.7855 - val_AUPRC: 0.4413
# Epoch 18/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2835 - AUROC: 0.8513 - AUPRC: 0.5391 - val_loss: 0.3415 - val_AUROC: 0.7862 - val_AUPRC: 0.4433
# Epoch 19/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2865 - AUROC: 0.8430 - AUPRC: 0.5329 - val_loss: 0.3405 - val_AUROC: 0.7856 - val_AUPRC: 0.4454
# Epoch 20/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2793 - AUROC: 0.8522 - AUPRC: 0.5634 - val_loss: 0.3417 - val_AUROC: 0.7851 - val_AUPRC: 0.4433
# Epoch 21/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2789 - AUROC: 0.8519 - AUPRC: 0.5650 - val_loss: 0.3458 - val_AUROC: 0.7846 - val_AUPRC: 0.4399
# Epoch 22/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2822 - AUROC: 0.8511 - AUPRC: 0.5494 - val_loss: 0.3428 - val_AUROC: 0.7851 - val_AUPRC: 0.4425
# Epoch 23/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2809 - AUROC: 0.8511 - AUPRC: 0.5532 - val_loss: 0.3421 - val_AUROC: 0.7852 - val_AUPRC: 0.4414
# Epoch 24/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2795 - AUROC: 0.8535 - AUPRC: 0.5558 - val_loss: 0.3433 - val_AUROC: 0.7858 - val_AUPRC: 0.4421
# Epoch 25/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2800 - AUROC: 0.8504 - AUPRC: 0.5621 - val_loss: 0.3407 - val_AUROC: 0.7864 - val_AUPRC: 0.4447
# Epoch 26/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2776 - AUROC: 0.8520 - AUPRC: 0.5692 - val_loss: 0.3432 - val_AUROC: 0.7846 - val_AUPRC: 0.4416
# Epoch 27/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2797 - AUROC: 0.8549 - AUPRC: 0.5563 - val_loss: 0.3463 - val_AUROC: 0.7840 - val_AUPRC: 0.4386
# Epoch 28/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2813 - AUROC: 0.8498 - AUPRC: 0.5564 - val_loss: 0.3447 - val_AUROC: 0.7854 - val_AUPRC: 0.4382
# Epoch 29/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2846 - AUROC: 0.8464 - AUPRC: 0.5438 - val_loss: 0.3429 - val_AUROC: 0.7861 - val_AUPRC: 0.4421

# %% [markdown]
# ### LSTM

# %%
myMetrics = [
    keras.metrics.AUC(name='AUROC', curve='ROC'),
    keras.metrics.AUC(name='AUPRC', curve='PR')
]

keras.backend.clear_session()
mdl = keras.models.Sequential([
    keras.layers.LSTM(16, return_sequences=True, input_shape=list(X_train.shape)[1:4]),
    keras.layers.BatchNormalization(),
    keras.layers.LSTM(16, return_sequences=False),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(1, activation='sigmoid')
])
mdl.summary()
mdl.compile(loss="binary_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
callback = EarlyStopping(monitor='val_loss', patience=10)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-4)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-5)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-6)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 25, 16)            3136
# _________________________________________________________________
# batch_normalization (BatchNo (None, 25, 16)            64
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 5,393
# Trainable params: 5,329
# Non-trainable params: 64
# _________________________________________________________________
# Epoch 1/50
# 164/164 [==============================] - 6s 18ms/step - loss: 0.7162 - AUROC: 0.5101 - AUPRC: 0.1325 - val_loss: 0.4708 - val_AUROC: 0.5850 - val_AUPRC: 0.1758
# Epoch 2/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.4450 - AUROC: 0.5837 - AUPRC: 0.1749 - val_loss: 0.4100 - val_AUROC: 0.5374 - val_AUPRC: 0.1669
# Epoch 3/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3863 - AUROC: 0.6003 - AUPRC: 0.1824 - val_loss: 0.4042 - val_AUROC: 0.5933 - val_AUPRC: 0.1919
# Epoch 4/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3691 - AUROC: 0.6363 - AUPRC: 0.2141 - val_loss: 0.4027 - val_AUROC: 0.5877 - val_AUPRC: 0.1935
# Epoch 5/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3779 - AUROC: 0.6126 - AUPRC: 0.2088 - val_loss: 0.4039 - val_AUROC: 0.6110 - val_AUPRC: 0.2035
# Epoch 6/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3785 - AUROC: 0.6296 - AUPRC: 0.2151 - val_loss: 0.4010 - val_AUROC: 0.6172 - val_AUPRC: 0.2150
# Epoch 7/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3755 - AUROC: 0.6362 - AUPRC: 0.2013 - val_loss: 0.4009 - val_AUROC: 0.6180 - val_AUPRC: 0.2197
# Epoch 8/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3789 - AUROC: 0.6261 - AUPRC: 0.2068 - val_loss: 0.3992 - val_AUROC: 0.6158 - val_AUPRC: 0.2239
# Epoch 9/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3808 - AUROC: 0.6115 - AUPRC: 0.1967 - val_loss: 0.4100 - val_AUROC: 0.6113 - val_AUPRC: 0.2156
# Epoch 10/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3754 - AUROC: 0.6416 - AUPRC: 0.2069 - val_loss: 0.3996 - val_AUROC: 0.6220 - val_AUPRC: 0.2408
# Epoch 11/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3663 - AUROC: 0.6474 - AUPRC: 0.2186 - val_loss: 0.3956 - val_AUROC: 0.6304 - val_AUPRC: 0.2408
# Epoch 12/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3720 - AUROC: 0.6621 - AUPRC: 0.2570 - val_loss: 0.4026 - val_AUROC: 0.6153 - val_AUPRC: 0.2235
# Epoch 13/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3854 - AUROC: 0.6630 - AUPRC: 0.2335 - val_loss: 0.4042 - val_AUROC: 0.6049 - val_AUPRC: 0.2231
# Epoch 14/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3627 - AUROC: 0.6420 - AUPRC: 0.2165 - val_loss: 0.3985 - val_AUROC: 0.5975 - val_AUPRC: 0.2182
# Epoch 15/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3691 - AUROC: 0.6491 - AUPRC: 0.2192 - val_loss: 0.4013 - val_AUROC: 0.6176 - val_AUPRC: 0.2077
# Epoch 16/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3818 - AUROC: 0.6439 - AUPRC: 0.2350 - val_loss: 0.3958 - val_AUROC: 0.6303 - val_AUPRC: 0.2251
# Epoch 17/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3696 - AUROC: 0.6585 - AUPRC: 0.2237 - val_loss: 0.4063 - val_AUROC: 0.5694 - val_AUPRC: 0.1918
# Epoch 18/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3702 - AUROC: 0.6343 - AUPRC: 0.2129 - val_loss: 0.3998 - val_AUROC: 0.6150 - val_AUPRC: 0.2313
# Epoch 19/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3785 - AUROC: 0.6434 - AUPRC: 0.2448 - val_loss: 0.3876 - val_AUROC: 0.6208 - val_AUPRC: 0.2654
# Epoch 20/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3704 - AUROC: 0.6468 - AUPRC: 0.2493 - val_loss: 0.3893 - val_AUROC: 0.6274 - val_AUPRC: 0.2608
# Epoch 21/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3548 - AUROC: 0.6854 - AUPRC: 0.3312 - val_loss: 0.3888 - val_AUROC: 0.6180 - val_AUPRC: 0.2880
# Epoch 22/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3742 - AUROC: 0.6631 - AUPRC: 0.2807 - val_loss: 0.3853 - val_AUROC: 0.6450 - val_AUPRC: 0.3076
# Epoch 23/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3587 - AUROC: 0.6669 - AUPRC: 0.3039 - val_loss: 0.3878 - val_AUROC: 0.6279 - val_AUPRC: 0.2836
# Epoch 24/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3520 - AUROC: 0.6604 - AUPRC: 0.2905 - val_loss: 0.3822 - val_AUROC: 0.6482 - val_AUPRC: 0.3091
# Epoch 25/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3682 - AUROC: 0.6707 - AUPRC: 0.3087 - val_loss: 0.3865 - val_AUROC: 0.6515 - val_AUPRC: 0.2847
# Epoch 26/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3624 - AUROC: 0.6851 - AUPRC: 0.2948 - val_loss: 0.3819 - val_AUROC: 0.6494 - val_AUPRC: 0.3017
# Epoch 27/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3600 - AUROC: 0.6662 - AUPRC: 0.3449 - val_loss: 0.3846 - val_AUROC: 0.6555 - val_AUPRC: 0.2975
# Epoch 28/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3564 - AUROC: 0.6659 - AUPRC: 0.2655 - val_loss: 0.3954 - val_AUROC: 0.6013 - val_AUPRC: 0.2656
# Epoch 29/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3640 - AUROC: 0.6687 - AUPRC: 0.2741 - val_loss: 0.3884 - val_AUROC: 0.6283 - val_AUPRC: 0.2791
# Epoch 30/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3598 - AUROC: 0.6796 - AUPRC: 0.3268 - val_loss: 0.3856 - val_AUROC: 0.6416 - val_AUPRC: 0.2928
# Epoch 31/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3678 - AUROC: 0.6983 - AUPRC: 0.3234 - val_loss: 0.4123 - val_AUROC: 0.6130 - val_AUPRC: 0.2101
# Epoch 32/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3743 - AUROC: 0.6424 - AUPRC: 0.2411 - val_loss: 0.3895 - val_AUROC: 0.6416 - val_AUPRC: 0.2814
# Epoch 33/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3465 - AUROC: 0.6668 - AUPRC: 0.2570 - val_loss: 0.4206 - val_AUROC: 0.5788 - val_AUPRC: 0.2387
# Epoch 34/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3551 - AUROC: 0.6657 - AUPRC: 0.2704 - val_loss: 0.3766 - val_AUROC: 0.6655 - val_AUPRC: 0.3276
# Epoch 35/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3498 - AUROC: 0.6927 - AUPRC: 0.3149 - val_loss: 0.3876 - val_AUROC: 0.6447 - val_AUPRC: 0.2577
# Epoch 36/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3552 - AUROC: 0.6868 - AUPRC: 0.3069 - val_loss: 0.3928 - val_AUROC: 0.6206 - val_AUPRC: 0.2556
# Epoch 37/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3447 - AUROC: 0.6754 - AUPRC: 0.2705 - val_loss: 0.3734 - val_AUROC: 0.6687 - val_AUPRC: 0.3314
# Epoch 38/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3498 - AUROC: 0.6747 - AUPRC: 0.2821 - val_loss: 0.3707 - val_AUROC: 0.6945 - val_AUPRC: 0.3434
# Epoch 39/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3646 - AUROC: 0.6686 - AUPRC: 0.3188 - val_loss: 0.3723 - val_AUROC: 0.6694 - val_AUPRC: 0.3147
# Epoch 40/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3764 - AUROC: 0.6630 - AUPRC: 0.3101 - val_loss: 0.3745 - val_AUROC: 0.6575 - val_AUPRC: 0.3130
# Epoch 41/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3360 - AUROC: 0.6790 - AUPRC: 0.3121 - val_loss: 0.4885 - val_AUROC: 0.6175 - val_AUPRC: 0.2453
# Epoch 42/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3552 - AUROC: 0.6784 - AUPRC: 0.2702 - val_loss: 0.3709 - val_AUROC: 0.6914 - val_AUPRC: 0.3275
# Epoch 43/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3552 - AUROC: 0.6890 - AUPRC: 0.3334 - val_loss: 0.3661 - val_AUROC: 0.6856 - val_AUPRC: 0.3374
# Epoch 44/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3534 - AUROC: 0.6957 - AUPRC: 0.3182 - val_loss: 0.3693 - val_AUROC: 0.6740 - val_AUPRC: 0.3015
# Epoch 45/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3447 - AUROC: 0.7004 - AUPRC: 0.3317 - val_loss: 0.3704 - val_AUROC: 0.6681 - val_AUPRC: 0.3157
# Epoch 46/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3479 - AUROC: 0.7139 - AUPRC: 0.3262 - val_loss: 0.3726 - val_AUROC: 0.6742 - val_AUPRC: 0.3084
# Epoch 47/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3413 - AUROC: 0.7049 - AUPRC: 0.3216 - val_loss: 0.3778 - val_AUROC: 0.6784 - val_AUPRC: 0.3083
# Epoch 48/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3426 - AUROC: 0.7235 - AUPRC: 0.3445 - val_loss: 0.3782 - val_AUROC: 0.6578 - val_AUPRC: 0.3012
# Epoch 49/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3558 - AUROC: 0.7073 - AUPRC: 0.3016 - val_loss: 0.4586 - val_AUROC: 0.6459 - val_AUPRC: 0.1928
# Epoch 50/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3519 - AUROC: 0.6861 - AUPRC: 0.2698 - val_loss: 0.3865 - val_AUROC: 0.6714 - val_AUPRC: 0.2842
# Epoch 1/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3474 - AUROC: 0.7142 - AUPRC: 0.3210 - val_loss: 0.3724 - val_AUROC: 0.6878 - val_AUPRC: 0.3027
# Epoch 2/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3480 - AUROC: 0.7136 - AUPRC: 0.3226 - val_loss: 0.3706 - val_AUROC: 0.6899 - val_AUPRC: 0.3059
# Epoch 3/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3426 - AUROC: 0.7262 - AUPRC: 0.3407 - val_loss: 0.3742 - val_AUROC: 0.6823 - val_AUPRC: 0.2937
# Epoch 4/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3419 - AUROC: 0.7296 - AUPRC: 0.3462 - val_loss: 0.3712 - val_AUROC: 0.6837 - val_AUPRC: 0.3046
# Epoch 5/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3428 - AUROC: 0.7280 - AUPRC: 0.3438 - val_loss: 0.3730 - val_AUROC: 0.6817 - val_AUPRC: 0.2990
# Epoch 6/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3416 - AUROC: 0.7255 - AUPRC: 0.3411 - val_loss: 0.3739 - val_AUROC: 0.6861 - val_AUPRC: 0.2971
# Epoch 7/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3417 - AUROC: 0.7321 - AUPRC: 0.3414 - val_loss: 0.3719 - val_AUROC: 0.6892 - val_AUPRC: 0.3046
# Epoch 8/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3415 - AUROC: 0.7270 - AUPRC: 0.3448 - val_loss: 0.3729 - val_AUROC: 0.6889 - val_AUPRC: 0.3111
# Epoch 9/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3417 - AUROC: 0.7312 - AUPRC: 0.3396 - val_loss: 0.3757 - val_AUROC: 0.6825 - val_AUPRC: 0.3038
# Epoch 10/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3408 - AUROC: 0.7308 - AUPRC: 0.3394 - val_loss: 0.3747 - val_AUROC: 0.6926 - val_AUPRC: 0.3108
# Epoch 11/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3377 - AUROC: 0.7376 - AUPRC: 0.3626 - val_loss: 0.3731 - val_AUROC: 0.6931 - val_AUPRC: 0.3182
# Epoch 12/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3393 - AUROC: 0.7357 - AUPRC: 0.3531 - val_loss: 0.3695 - val_AUROC: 0.7027 - val_AUPRC: 0.3216
# Epoch 13/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3382 - AUROC: 0.7374 - AUPRC: 0.3556 - val_loss: 0.3698 - val_AUROC: 0.6984 - val_AUPRC: 0.3274
# Epoch 14/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3375 - AUROC: 0.7336 - AUPRC: 0.3589 - val_loss: 0.3701 - val_AUROC: 0.6930 - val_AUPRC: 0.3166
# Epoch 15/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3367 - AUROC: 0.7399 - AUPRC: 0.3659 - val_loss: 0.3711 - val_AUROC: 0.7053 - val_AUPRC: 0.3242
# Epoch 16/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3405 - AUROC: 0.7258 - AUPRC: 0.3496 - val_loss: 0.3701 - val_AUROC: 0.7050 - val_AUPRC: 0.3243
# Epoch 17/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3381 - AUROC: 0.7360 - AUPRC: 0.3612 - val_loss: 0.3695 - val_AUROC: 0.7093 - val_AUPRC: 0.3251
# Epoch 18/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3388 - AUROC: 0.7406 - AUPRC: 0.3397 - val_loss: 0.3684 - val_AUROC: 0.7050 - val_AUPRC: 0.3221
# Epoch 19/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3368 - AUROC: 0.7359 - AUPRC: 0.3740 - val_loss: 0.3713 - val_AUROC: 0.7050 - val_AUPRC: 0.3081
# Epoch 20/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3376 - AUROC: 0.7387 - AUPRC: 0.3617 - val_loss: 0.3719 - val_AUROC: 0.7010 - val_AUPRC: 0.3063
# Epoch 21/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3366 - AUROC: 0.7396 - AUPRC: 0.3680 - val_loss: 0.3749 - val_AUROC: 0.6985 - val_AUPRC: 0.3108
# Epoch 22/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3379 - AUROC: 0.7410 - AUPRC: 0.3508 - val_loss: 0.3736 - val_AUROC: 0.6988 - val_AUPRC: 0.3016
# Epoch 23/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3380 - AUROC: 0.7365 - AUPRC: 0.3511 - val_loss: 0.3746 - val_AUROC: 0.6970 - val_AUPRC: 0.3044
# Epoch 24/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3368 - AUROC: 0.7429 - AUPRC: 0.3566 - val_loss: 0.3757 - val_AUROC: 0.6960 - val_AUPRC: 0.2974
# Epoch 25/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3375 - AUROC: 0.7381 - AUPRC: 0.3648 - val_loss: 0.3699 - val_AUROC: 0.7056 - val_AUPRC: 0.3096
# Epoch 26/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3362 - AUROC: 0.7419 - AUPRC: 0.3601 - val_loss: 0.3728 - val_AUROC: 0.7053 - val_AUPRC: 0.3160
# Epoch 27/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3367 - AUROC: 0.7399 - AUPRC: 0.3662 - val_loss: 0.3763 - val_AUROC: 0.6963 - val_AUPRC: 0.3089
# Epoch 28/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3378 - AUROC: 0.7407 - AUPRC: 0.3476 - val_loss: 0.3748 - val_AUROC: 0.6967 - val_AUPRC: 0.3131
# Epoch 1/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3358 - AUROC: 0.7413 - AUPRC: 0.3647 - val_loss: 0.3759 - val_AUROC: 0.6953 - val_AUPRC: 0.3108
# Epoch 2/50
# 164/164 [==============================] - 2s 13ms/step - loss: 0.3340 - AUROC: 0.7448 - AUPRC: 0.3673 - val_loss: 0.3746 - val_AUROC: 0.6948 - val_AUPRC: 0.3096
# Epoch 3/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3346 - AUROC: 0.7451 - AUPRC: 0.3668 - val_loss: 0.3728 - val_AUROC: 0.6977 - val_AUPRC: 0.3140
# Epoch 4/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3352 - AUROC: 0.7481 - AUPRC: 0.3613 - val_loss: 0.3739 - val_AUROC: 0.7007 - val_AUPRC: 0.3172
# Epoch 5/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3364 - AUROC: 0.7413 - AUPRC: 0.3690 - val_loss: 0.3751 - val_AUROC: 0.6968 - val_AUPRC: 0.3130
# Epoch 6/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3358 - AUROC: 0.7457 - AUPRC: 0.3606 - val_loss: 0.3726 - val_AUROC: 0.7042 - val_AUPRC: 0.3162
# Epoch 7/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3322 - AUROC: 0.7559 - AUPRC: 0.3684 - val_loss: 0.3728 - val_AUROC: 0.7041 - val_AUPRC: 0.3165
# Epoch 8/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3341 - AUROC: 0.7510 - AUPRC: 0.3615 - val_loss: 0.3747 - val_AUROC: 0.7004 - val_AUPRC: 0.3156
# Epoch 9/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3356 - AUROC: 0.7417 - AUPRC: 0.3618 - val_loss: 0.3745 - val_AUROC: 0.6997 - val_AUPRC: 0.3133
# Epoch 10/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3364 - AUROC: 0.7424 - AUPRC: 0.3571 - val_loss: 0.3757 - val_AUROC: 0.6952 - val_AUPRC: 0.3114
# Epoch 11/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3345 - AUROC: 0.7435 - AUPRC: 0.3722 - val_loss: 0.3737 - val_AUROC: 0.6979 - val_AUPRC: 0.3123
# Epoch 12/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3318 - AUROC: 0.7541 - AUPRC: 0.3769 - val_loss: 0.3762 - val_AUROC: 0.6948 - val_AUPRC: 0.3114
# Epoch 13/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3347 - AUROC: 0.7479 - AUPRC: 0.3621 - val_loss: 0.3763 - val_AUROC: 0.6939 - val_AUPRC: 0.3115
# Epoch 14/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3341 - AUROC: 0.7492 - AUPRC: 0.3625 - val_loss: 0.3760 - val_AUROC: 0.6977 - val_AUPRC: 0.3121
# Epoch 15/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3319 - AUROC: 0.7486 - AUPRC: 0.3774 - val_loss: 0.3740 - val_AUROC: 0.6975 - val_AUPRC: 0.3138
# Epoch 16/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3321 - AUROC: 0.7514 - AUPRC: 0.3762 - val_loss: 0.3714 - val_AUROC: 0.6974 - val_AUPRC: 0.3138
# Epoch 17/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3341 - AUROC: 0.7478 - AUPRC: 0.3724 - val_loss: 0.3742 - val_AUROC: 0.6974 - val_AUPRC: 0.3145
# Epoch 18/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3335 - AUROC: 0.7487 - AUPRC: 0.3679 - val_loss: 0.3754 - val_AUROC: 0.6968 - val_AUPRC: 0.3154
# Epoch 19/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3345 - AUROC: 0.7485 - AUPRC: 0.3475 - val_loss: 0.3759 - val_AUROC: 0.6977 - val_AUPRC: 0.3152
# Epoch 20/50
# 164/164 [==============================] - 2s 15ms/step - loss: 0.3346 - AUROC: 0.7445 - AUPRC: 0.3651 - val_loss: 0.3760 - val_AUROC: 0.6974 - val_AUPRC: 0.3118
# Epoch 21/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3322 - AUROC: 0.7549 - AUPRC: 0.3785 - val_loss: 0.3737 - val_AUROC: 0.6973 - val_AUPRC: 0.3113
# Epoch 22/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3349 - AUROC: 0.7450 - AUPRC: 0.3574 - val_loss: 0.3746 - val_AUROC: 0.6963 - val_AUPRC: 0.3113
# Epoch 23/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3336 - AUROC: 0.7491 - AUPRC: 0.3820 - val_loss: 0.3750 - val_AUROC: 0.6980 - val_AUPRC: 0.3148
# Epoch 24/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3325 - AUROC: 0.7513 - AUPRC: 0.3750 - val_loss: 0.3752 - val_AUROC: 0.6978 - val_AUPRC: 0.3168
# Epoch 25/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3325 - AUROC: 0.7477 - AUPRC: 0.3796 - val_loss: 0.3753 - val_AUROC: 0.6992 - val_AUPRC: 0.3144
# Epoch 26/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3333 - AUROC: 0.7523 - AUPRC: 0.3701 - val_loss: 0.3751 - val_AUROC: 0.7003 - val_AUPRC: 0.3143
# Epoch 1/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3313 - AUROC: 0.7521 - AUPRC: 0.3760 - val_loss: 0.3753 - val_AUROC: 0.6987 - val_AUPRC: 0.3134
# Epoch 2/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3312 - AUROC: 0.7542 - AUPRC: 0.3843 - val_loss: 0.3749 - val_AUROC: 0.6986 - val_AUPRC: 0.3137
# Epoch 3/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3332 - AUROC: 0.7512 - AUPRC: 0.3672 - val_loss: 0.3752 - val_AUROC: 0.6973 - val_AUPRC: 0.3130
# Epoch 4/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3361 - AUROC: 0.7400 - AUPRC: 0.3736 - val_loss: 0.3754 - val_AUROC: 0.6966 - val_AUPRC: 0.3134
# Epoch 5/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3345 - AUROC: 0.7486 - AUPRC: 0.3594 - val_loss: 0.3744 - val_AUROC: 0.6977 - val_AUPRC: 0.3126
# Epoch 6/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3355 - AUROC: 0.7477 - AUPRC: 0.3585 - val_loss: 0.3747 - val_AUROC: 0.6990 - val_AUPRC: 0.3129
# Epoch 7/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3350 - AUROC: 0.7405 - AUPRC: 0.3640 - val_loss: 0.3742 - val_AUROC: 0.6979 - val_AUPRC: 0.3132
# Epoch 8/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3343 - AUROC: 0.7462 - AUPRC: 0.3630 - val_loss: 0.3739 - val_AUROC: 0.6992 - val_AUPRC: 0.3131
# Epoch 9/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3317 - AUROC: 0.7523 - AUPRC: 0.3734 - val_loss: 0.3755 - val_AUROC: 0.6976 - val_AUPRC: 0.3130
# Epoch 10/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3314 - AUROC: 0.7509 - AUPRC: 0.3840 - val_loss: 0.3756 - val_AUROC: 0.6986 - val_AUPRC: 0.3144
# Epoch 11/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3324 - AUROC: 0.7562 - AUPRC: 0.3674 - val_loss: 0.3752 - val_AUROC: 0.6988 - val_AUPRC: 0.3140
# Epoch 12/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3323 - AUROC: 0.7503 - AUPRC: 0.3680 - val_loss: 0.3755 - val_AUROC: 0.6986 - val_AUPRC: 0.3134
# Epoch 13/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3314 - AUROC: 0.7543 - AUPRC: 0.3705 - val_loss: 0.3752 - val_AUROC: 0.6974 - val_AUPRC: 0.3134
# Epoch 14/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3334 - AUROC: 0.7519 - AUPRC: 0.3617 - val_loss: 0.3756 - val_AUROC: 0.6999 - val_AUPRC: 0.3137
# Epoch 15/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3319 - AUROC: 0.7531 - AUPRC: 0.3855 - val_loss: 0.3755 - val_AUROC: 0.6979 - val_AUPRC: 0.3138
# Epoch 16/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3337 - AUROC: 0.7493 - AUPRC: 0.3591 - val_loss: 0.3756 - val_AUROC: 0.6971 - val_AUPRC: 0.3134
# Epoch 17/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3315 - AUROC: 0.7502 - AUPRC: 0.3754 - val_loss: 0.3755 - val_AUROC: 0.6974 - val_AUPRC: 0.3147
# Epoch 18/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3327 - AUROC: 0.7543 - AUPRC: 0.3770 - val_loss: 0.3758 - val_AUROC: 0.6998 - val_AUPRC: 0.3143

# %% [markdown]
# ## Model -- scale inputs by percentile

# %%
# input and output variable name lists
input_vars = ['txp___yes', 'age___vital', 'temp___vital', 'heart_rate___vital', 'resp_rate___vital', 'spo2___vital', 'x_hr_rr___vital', 's_hr___vital', 's_rr___vital', 's_so2___vital', 'systolic_blood_pressure___vital', 'diastolic_blood_pressure___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'sodium___vital', 'wbc___vital', 'phosphorus___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'pco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital']
output_var = ['y___pos']

# read datasets
train_df = pd.read_csv("./train_df.csv")
valid_df = pd.read_csv("./valid_df.csv")
whole_df = pd.concat([train_df, valid_df], axis=0)
whole_df.reset_index(drop=True,inplace=True)

# percentile of inputs
whole_df[input_vars] = whole_df[input_vars].rank(pct=True)

whole_df.describe()
# Out:
#            txp___yes       txp___no    age___vital   temp___vital  \
# count  472104.000000  472104.000000  472104.000000  254968.000000
# mean        0.500001       0.959280       0.500001       0.500002
# std         0.087425       0.197641       0.288675       0.288504
# min         0.484216       0.000000       0.000077       0.000004
# 25%         0.484216       1.000000       0.250039       0.258797
# 50%         0.484216       1.000000       0.500077       0.528502
# 75%         0.484216       1.000000       0.749963       0.756846
# max         0.984216       1.000000       0.992376       0.999998
#
#        heart_rate___vital  resp_rate___vital   spo2___vital  x_hr_rr___vital  \
# count       149510.000000      137352.000000  145843.000000    134784.000000
# mean             0.500003           0.500004       0.500003         0.500004
# std              0.288676           0.288676       0.288673         0.288676
# min              0.000007           0.000051       0.000051         0.000085
# 25%              0.250015           0.250005       0.250005         0.250006
# 50%              0.500003           0.500004       0.500003         0.500004
# 75%              0.750003           0.749996       0.750002         0.750002
# max              0.999977           0.999971       0.985858         0.999941
#
#         s_hr___vital   s_rr___vital  ...    ptt___vital  lactate___vital  \
# count  149508.000000  137346.000000  ...  268718.000000    225117.000000
# mean        0.500003       0.500004  ...       0.500002         0.500002
# std         0.288676       0.288668  ...       0.288671         0.288508
# min         0.002351       0.018930  ...       0.000050         0.000124
# 25%         0.249973       0.249989  ...       0.253937         0.246994
# 50%         0.500003       0.499982  ...       0.500724         0.502350
# 75%         0.750002       0.750002  ...       0.749773         0.753057
# max         0.999960       1.000000  ...       0.999994         0.999993
#
#          bun___vital  magnesium___vital        y___pos        y___neg  \
# count  310073.000000      274500.000000  472104.000000  472104.000000
# mean        0.500002           0.500002       0.133750       0.658685
# std         0.288605           0.287753       0.340384       0.474151
# min         0.000771           0.000053       0.000000       0.000000
# 25%         0.266495           0.219876       0.000000       0.000000
# 50%         0.500302           0.541780       0.000000       1.000000
# 75%         0.749106           0.739561       0.000000       1.000000
# max         0.999960           0.999954       1.000000       1.000000
#
#              y___nbc     __time_bin  __ep_relative_time     __ep_order
# count  472104.000000  472104.000000       472104.000000  472104.000000
# mean        0.207564      73.344136         -750.000000       1.208327
# std         0.405564     444.860381         1246.957615       0.672272
# min         0.000000   -4259.000000        -2880.000000       1.000000
# 25%         0.000000     -25.000000        -1815.000000       1.000000
# 50%         0.000000      -4.000000         -750.000000       1.000000
# 75%         0.000000      18.000000          315.000000       1.000000
# max         1.000000   16477.000000         1380.000000      14.000000
#
# [8 rows x 39 columns]

# %%
train_df = whole_df.loc[range(train_df.shape[0]),:].copy()
valid_df = whole_df.loc[range(train_df.shape[0], whole_df.shape[0]),:].copy()

# select modeling time window
train_df = train_df.loc[(train_df['__ep_relative_time']/60>=-24) & (train_df['__ep_relative_time']/60<=0) ,:]
valid_df = valid_df.loc[(valid_df['__ep_relative_time']/60>=-24) & (valid_df['__ep_relative_time']/60<=0) ,:]


# median imputation
train_df.fillna(train_df.median(), inplace=True)
valid_df.fillna(train_df.median(), inplace=True)


# combine to one dataframe
whole_df = pd.concat([train_df, valid_df], axis=0)

# %%
# reformat inputs to be 2d image and 1 output per image
X_whole = whole_df[input_vars].values
Y_whole = whole_df[output_var].values
X_whole = np.reshape(X_whole, (-1,25,32) )
Y_whole = np.reshape(Y_whole, (-1,25,1) )[:,0,:]
print(X_whole.shape)
print(Y_whole.shape)

# reformat inputs to be 2d image and 1 output per image
X_train = train_df[input_vars].values
Y_train = train_df[output_var].values
X_train = np.reshape(X_train, (-1,25,32) )
Y_train = np.reshape(Y_train, (-1,25,1) )[:,0,:]
print(X_train.shape)
print(Y_train.shape)

# reformat inputs to be 2d image and 1 output per image
X_valid = valid_df[input_vars].values
Y_valid = valid_df[output_var].values
X_valid = np.reshape(X_valid, (-1,25,32) )
Y_valid = np.reshape(Y_valid, (-1,25,1) )[:,0,:]
print(X_valid.shape)
print(Y_valid.shape)
# Out:
# (6557, 25, 32)
# (6557, 1)
# (5226, 25, 32)
# (5226, 1)
# (1331, 25, 32)
# (1331, 1)

# %% [markdown]
# ### Logistic Regression

# %%
# myMetrics = [
#     keras.metrics.AUC(name='AUROC', curve='ROC'),
#     keras.metrics.AUC(name='AUPRC', curve='PR')
# ]

# keras.backend.clear_session()
# mdl = keras.models.Sequential([
#     keras.layers.Flatten(input_shape=list(X_train.shape)[1:4]),
#     keras.layers.BatchNormalization(),
#     keras.layers.Dense(1, activation='sigmoid')
# ])
# mdl.summary()
# mdl.compile(loss="binary_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
# callback = EarlyStopping(monitor='val_loss', patience=10)
# his = mdl.fit(X_train, Y_train, 
#               epochs=50, 
#               validation_data=(X_valid,Y_valid), callbacks=[callback])
# keras.backend.set_value(mdl.optimizer.learning_rate, 1e-4)
# his = mdl.fit(X_train, Y_train, 
#               epochs=50, 
#               validation_data=(X_valid,Y_valid), callbacks=[callback])
# keras.backend.set_value(mdl.optimizer.learning_rate, 1e-5)
# his = mdl.fit(X_train, Y_train, 
#               epochs=50, 
#               validation_data=(X_valid,Y_valid), callbacks=[callback])
# keras.backend.set_value(mdl.optimizer.learning_rate, 1e-6)
# his = mdl.fit(X_train, Y_train, 
#               epochs=50, 
#               validation_data=(X_valid,Y_valid), callbacks=[callback])
# keras.backend.set_value(mdl.optimizer.learning_rate, 1e-7)
# his = mdl.fit(X_train, Y_train, 
#               epochs=50, 
#               validation_data=(X_valid,Y_valid), callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 800)               3200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 801
# =================================================================
# Total params: 4,001
# Trainable params: 2,401
# Non-trainable params: 1,600
# _________________________________________________________________
# Epoch 1/50
# 164/164 [==============================] - 1s 3ms/step - loss: 0.5181 - AUROC: 0.6281 - AUPRC: 0.2425 - val_loss: 0.3959 - val_AUROC: 0.7474 - val_AUPRC: 0.3858
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3258 - AUROC: 0.7844 - AUPRC: 0.4127 - val_loss: 0.3511 - val_AUROC: 0.7707 - val_AUPRC: 0.4186
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3295 - AUROC: 0.7968 - AUPRC: 0.4259 - val_loss: 0.3427 - val_AUROC: 0.7799 - val_AUPRC: 0.4227
# Epoch 4/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3113 - AUROC: 0.8037 - AUPRC: 0.4353 - val_loss: 0.3360 - val_AUROC: 0.7922 - val_AUPRC: 0.4442
# Epoch 5/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3081 - AUROC: 0.8237 - AUPRC: 0.4538 - val_loss: 0.3424 - val_AUROC: 0.7798 - val_AUPRC: 0.4365
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3029 - AUROC: 0.8304 - AUPRC: 0.4771 - val_loss: 0.3440 - val_AUROC: 0.7853 - val_AUPRC: 0.4524
# Epoch 7/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3067 - AUROC: 0.8229 - AUPRC: 0.5000 - val_loss: 0.3383 - val_AUROC: 0.7916 - val_AUPRC: 0.4446
# Epoch 8/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3008 - AUROC: 0.8231 - AUPRC: 0.4843 - val_loss: 0.3455 - val_AUROC: 0.7871 - val_AUPRC: 0.4439
# Epoch 9/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3021 - AUROC: 0.8214 - AUPRC: 0.4883 - val_loss: 0.3337 - val_AUROC: 0.7947 - val_AUPRC: 0.4719
# Epoch 10/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3098 - AUROC: 0.8182 - AUPRC: 0.4681 - val_loss: 0.3387 - val_AUROC: 0.7878 - val_AUPRC: 0.4763
# Epoch 11/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2959 - AUROC: 0.8257 - AUPRC: 0.5027 - val_loss: 0.3384 - val_AUROC: 0.7874 - val_AUPRC: 0.4568
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2850 - AUROC: 0.8398 - AUPRC: 0.5446 - val_loss: 0.3414 - val_AUROC: 0.7831 - val_AUPRC: 0.4721
# Epoch 13/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2859 - AUROC: 0.8342 - AUPRC: 0.5355 - val_loss: 0.3400 - val_AUROC: 0.7880 - val_AUPRC: 0.4816
# Epoch 14/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2900 - AUROC: 0.8310 - AUPRC: 0.5441 - val_loss: 0.3393 - val_AUROC: 0.7936 - val_AUPRC: 0.4669
# Epoch 15/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2803 - AUROC: 0.8357 - AUPRC: 0.5411 - val_loss: 0.3336 - val_AUROC: 0.7933 - val_AUPRC: 0.4723
# Epoch 16/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2823 - AUROC: 0.8436 - AUPRC: 0.5698 - val_loss: 0.3437 - val_AUROC: 0.7932 - val_AUPRC: 0.4519
# Epoch 17/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3003 - AUROC: 0.8252 - AUPRC: 0.5166 - val_loss: 0.3385 - val_AUROC: 0.7943 - val_AUPRC: 0.4692
# Epoch 18/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3006 - AUROC: 0.8376 - AUPRC: 0.5104 - val_loss: 0.3454 - val_AUROC: 0.7888 - val_AUPRC: 0.4783
# Epoch 19/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2862 - AUROC: 0.8436 - AUPRC: 0.5656 - val_loss: 0.3439 - val_AUROC: 0.7780 - val_AUPRC: 0.4643
# Epoch 20/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2752 - AUROC: 0.8371 - AUPRC: 0.5226 - val_loss: 0.3372 - val_AUROC: 0.7884 - val_AUPRC: 0.4708
# Epoch 21/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3102 - AUROC: 0.8126 - AUPRC: 0.5147 - val_loss: 0.3419 - val_AUROC: 0.7835 - val_AUPRC: 0.4723
# Epoch 22/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2956 - AUROC: 0.8294 - AUPRC: 0.4889 - val_loss: 0.3426 - val_AUROC: 0.7882 - val_AUPRC: 0.4743
# Epoch 23/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2707 - AUROC: 0.8514 - AUPRC: 0.5959 - val_loss: 0.3407 - val_AUROC: 0.7835 - val_AUPRC: 0.4733
# Epoch 24/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2898 - AUROC: 0.8487 - AUPRC: 0.5382 - val_loss: 0.3436 - val_AUROC: 0.7837 - val_AUPRC: 0.4573
# Epoch 25/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2918 - AUROC: 0.8469 - AUPRC: 0.5618 - val_loss: 0.3448 - val_AUROC: 0.7807 - val_AUPRC: 0.4667
# Epoch 1/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2787 - AUROC: 0.8474 - AUPRC: 0.5717 - val_loss: 0.3411 - val_AUROC: 0.7848 - val_AUPRC: 0.4727
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2730 - AUROC: 0.8561 - AUPRC: 0.5834 - val_loss: 0.3392 - val_AUROC: 0.7872 - val_AUPRC: 0.4757
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2765 - AUROC: 0.8538 - AUPRC: 0.5709 - val_loss: 0.3379 - val_AUROC: 0.7879 - val_AUPRC: 0.4775
# Epoch 4/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2732 - AUROC: 0.8590 - AUPRC: 0.5806 - val_loss: 0.3371 - val_AUROC: 0.7898 - val_AUPRC: 0.4776
# Epoch 5/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2721 - AUROC: 0.8597 - AUPRC: 0.5872 - val_loss: 0.3363 - val_AUROC: 0.7908 - val_AUPRC: 0.4762
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2743 - AUROC: 0.8545 - AUPRC: 0.5849 - val_loss: 0.3370 - val_AUROC: 0.7905 - val_AUPRC: 0.4768
# Epoch 7/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2729 - AUROC: 0.8572 - AUPRC: 0.5819 - val_loss: 0.3358 - val_AUROC: 0.7910 - val_AUPRC: 0.4793
# Epoch 8/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2731 - AUROC: 0.8577 - AUPRC: 0.5814 - val_loss: 0.3362 - val_AUROC: 0.7910 - val_AUPRC: 0.4770
# Epoch 9/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2716 - AUROC: 0.8554 - AUPRC: 0.5933 - val_loss: 0.3367 - val_AUROC: 0.7901 - val_AUPRC: 0.4784
# Epoch 10/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2727 - AUROC: 0.8587 - AUPRC: 0.5845 - val_loss: 0.3358 - val_AUROC: 0.7903 - val_AUPRC: 0.4767
# Epoch 11/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2714 - AUROC: 0.8602 - AUPRC: 0.5878 - val_loss: 0.3361 - val_AUROC: 0.7916 - val_AUPRC: 0.4781
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2727 - AUROC: 0.8558 - AUPRC: 0.5903 - val_loss: 0.3360 - val_AUROC: 0.7915 - val_AUPRC: 0.4786
# Epoch 13/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2729 - AUROC: 0.8586 - AUPRC: 0.5847 - val_loss: 0.3358 - val_AUROC: 0.7924 - val_AUPRC: 0.4776
# Epoch 14/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2729 - AUROC: 0.8592 - AUPRC: 0.5843 - val_loss: 0.3358 - val_AUROC: 0.7927 - val_AUPRC: 0.4769
# Epoch 15/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2754 - AUROC: 0.8548 - AUPRC: 0.5758 - val_loss: 0.3365 - val_AUROC: 0.7906 - val_AUPRC: 0.4775
# Epoch 16/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2726 - AUROC: 0.8574 - AUPRC: 0.5901 - val_loss: 0.3368 - val_AUROC: 0.7911 - val_AUPRC: 0.4769
# Epoch 17/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2728 - AUROC: 0.8559 - AUPRC: 0.5893 - val_loss: 0.3371 - val_AUROC: 0.7907 - val_AUPRC: 0.4773
# Epoch 1/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2713 - AUROC: 0.8605 - AUPRC: 0.5877 - val_loss: 0.3370 - val_AUROC: 0.7904 - val_AUPRC: 0.4770
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2713 - AUROC: 0.8580 - AUPRC: 0.5953 - val_loss: 0.3370 - val_AUROC: 0.7908 - val_AUPRC: 0.4765
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2696 - AUROC: 0.8592 - AUPRC: 0.5985 - val_loss: 0.3370 - val_AUROC: 0.7909 - val_AUPRC: 0.4771
# Epoch 4/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2737 - AUROC: 0.8566 - AUPRC: 0.5799 - val_loss: 0.3368 - val_AUROC: 0.7905 - val_AUPRC: 0.4770
# Epoch 5/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2734 - AUROC: 0.8575 - AUPRC: 0.5851 - val_loss: 0.3368 - val_AUROC: 0.7910 - val_AUPRC: 0.4790
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2707 - AUROC: 0.8627 - AUPRC: 0.5864 - val_loss: 0.3371 - val_AUROC: 0.7906 - val_AUPRC: 0.4774
# Epoch 7/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2716 - AUROC: 0.8605 - AUPRC: 0.5862 - val_loss: 0.3369 - val_AUROC: 0.7904 - val_AUPRC: 0.4775
# Epoch 8/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2716 - AUROC: 0.8607 - AUPRC: 0.5853 - val_loss: 0.3369 - val_AUROC: 0.7912 - val_AUPRC: 0.4772
# Epoch 9/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2728 - AUROC: 0.8577 - AUPRC: 0.5850 - val_loss: 0.3368 - val_AUROC: 0.7910 - val_AUPRC: 0.4774
# Epoch 10/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2690 - AUROC: 0.8634 - AUPRC: 0.5966 - val_loss: 0.3369 - val_AUROC: 0.7901 - val_AUPRC: 0.4780
# Epoch 11/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2686 - AUROC: 0.8635 - AUPRC: 0.5969 - val_loss: 0.3365 - val_AUROC: 0.7908 - val_AUPRC: 0.4770
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2694 - AUROC: 0.8627 - AUPRC: 0.5936 - val_loss: 0.3368 - val_AUROC: 0.7913 - val_AUPRC: 0.4778
# Epoch 13/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2738 - AUROC: 0.8576 - AUPRC: 0.5804 - val_loss: 0.3372 - val_AUROC: 0.7912 - val_AUPRC: 0.4779
# Epoch 14/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2710 - AUROC: 0.8605 - AUPRC: 0.5915 - val_loss: 0.3368 - val_AUROC: 0.7908 - val_AUPRC: 0.4776
# Epoch 15/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2737 - AUROC: 0.8591 - AUPRC: 0.5777 - val_loss: 0.3368 - val_AUROC: 0.7907 - val_AUPRC: 0.4770
# Epoch 16/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2681 - AUROC: 0.8673 - AUPRC: 0.5946 - val_loss: 0.3370 - val_AUROC: 0.7915 - val_AUPRC: 0.4776
# Epoch 17/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2689 - AUROC: 0.8626 - AUPRC: 0.5955 - val_loss: 0.3370 - val_AUROC: 0.7912 - val_AUPRC: 0.4774
# Epoch 18/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2732 - AUROC: 0.8574 - AUPRC: 0.5840 - val_loss: 0.3366 - val_AUROC: 0.7909 - val_AUPRC: 0.4760
# Epoch 19/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2680 - AUROC: 0.8656 - AUPRC: 0.5979 - val_loss: 0.3367 - val_AUROC: 0.7903 - val_AUPRC: 0.4770
# Epoch 20/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2720 - AUROC: 0.8619 - AUPRC: 0.5814 - val_loss: 0.3369 - val_AUROC: 0.7908 - val_AUPRC: 0.4779
# Epoch 21/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2753 - AUROC: 0.8561 - AUPRC: 0.5747 - val_loss: 0.3365 - val_AUROC: 0.7910 - val_AUPRC: 0.4772
# Epoch 1/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2721 - AUROC: 0.8574 - AUPRC: 0.5893 - val_loss: 0.3368 - val_AUROC: 0.7910 - val_AUPRC: 0.4770
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2722 - AUROC: 0.8584 - AUPRC: 0.5844 - val_loss: 0.3363 - val_AUROC: 0.7908 - val_AUPRC: 0.4779
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2697 - AUROC: 0.8627 - AUPRC: 0.5956 - val_loss: 0.3367 - val_AUROC: 0.7914 - val_AUPRC: 0.4775
# Epoch 4/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2701 - AUROC: 0.8623 - AUPRC: 0.5894 - val_loss: 0.3366 - val_AUROC: 0.7908 - val_AUPRC: 0.4766
# Epoch 5/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2704 - AUROC: 0.8624 - AUPRC: 0.5899 - val_loss: 0.3366 - val_AUROC: 0.7908 - val_AUPRC: 0.4764
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2690 - AUROC: 0.8634 - AUPRC: 0.5969 - val_loss: 0.3368 - val_AUROC: 0.7903 - val_AUPRC: 0.4768
# Epoch 7/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2698 - AUROC: 0.8613 - AUPRC: 0.5946 - val_loss: 0.3366 - val_AUROC: 0.7912 - val_AUPRC: 0.4765
# Epoch 8/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2687 - AUROC: 0.8634 - AUPRC: 0.5988 - val_loss: 0.3362 - val_AUROC: 0.7915 - val_AUPRC: 0.4794
# Epoch 9/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2705 - AUROC: 0.8613 - AUPRC: 0.5929 - val_loss: 0.3367 - val_AUROC: 0.7911 - val_AUPRC: 0.4773
# Epoch 10/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2713 - AUROC: 0.8621 - AUPRC: 0.5855 - val_loss: 0.3368 - val_AUROC: 0.7908 - val_AUPRC: 0.4777
# Epoch 11/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2700 - AUROC: 0.8628 - AUPRC: 0.5893 - val_loss: 0.3363 - val_AUROC: 0.7911 - val_AUPRC: 0.4769
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2698 - AUROC: 0.8631 - AUPRC: 0.5944 - val_loss: 0.3372 - val_AUROC: 0.7906 - val_AUPRC: 0.4784
# Epoch 13/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2724 - AUROC: 0.8589 - AUPRC: 0.5853 - val_loss: 0.3368 - val_AUROC: 0.7905 - val_AUPRC: 0.4772
# Epoch 14/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2694 - AUROC: 0.8646 - AUPRC: 0.5895 - val_loss: 0.3366 - val_AUROC: 0.7906 - val_AUPRC: 0.4776
# Epoch 15/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2712 - AUROC: 0.8625 - AUPRC: 0.5866 - val_loss: 0.3368 - val_AUROC: 0.7912 - val_AUPRC: 0.4777
# Epoch 16/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2744 - AUROC: 0.8560 - AUPRC: 0.5806 - val_loss: 0.3363 - val_AUROC: 0.7910 - val_AUPRC: 0.4769
# Epoch 17/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2693 - AUROC: 0.8643 - AUPRC: 0.5920 - val_loss: 0.3366 - val_AUROC: 0.7912 - val_AUPRC: 0.4796
# Epoch 18/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2687 - AUROC: 0.8626 - AUPRC: 0.6008 - val_loss: 0.3363 - val_AUROC: 0.7919 - val_AUPRC: 0.4771
# Epoch 1/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2708 - AUROC: 0.8617 - AUPRC: 0.5884 - val_loss: 0.3365 - val_AUROC: 0.7914 - val_AUPRC: 0.4764
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2736 - AUROC: 0.8589 - AUPRC: 0.5804 - val_loss: 0.3365 - val_AUROC: 0.7916 - val_AUPRC: 0.4775
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2689 - AUROC: 0.8642 - AUPRC: 0.5968 - val_loss: 0.3368 - val_AUROC: 0.7918 - val_AUPRC: 0.4772
# Epoch 4/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2696 - AUROC: 0.8605 - AUPRC: 0.5970 - val_loss: 0.3367 - val_AUROC: 0.7920 - val_AUPRC: 0.4789
# Epoch 5/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2697 - AUROC: 0.8627 - AUPRC: 0.5929 - val_loss: 0.3365 - val_AUROC: 0.7919 - val_AUPRC: 0.4783
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2692 - AUROC: 0.8622 - AUPRC: 0.5952 - val_loss: 0.3366 - val_AUROC: 0.7907 - val_AUPRC: 0.4771
# Epoch 7/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2722 - AUROC: 0.8598 - AUPRC: 0.5859 - val_loss: 0.3364 - val_AUROC: 0.7918 - val_AUPRC: 0.4783
# Epoch 8/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2719 - AUROC: 0.8585 - AUPRC: 0.5888 - val_loss: 0.3366 - val_AUROC: 0.7908 - val_AUPRC: 0.4770
# Epoch 9/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2679 - AUROC: 0.8679 - AUPRC: 0.5952 - val_loss: 0.3368 - val_AUROC: 0.7910 - val_AUPRC: 0.4769
# Epoch 10/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2698 - AUROC: 0.8621 - AUPRC: 0.5948 - val_loss: 0.3366 - val_AUROC: 0.7912 - val_AUPRC: 0.4771
# Epoch 11/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2727 - AUROC: 0.8583 - AUPRC: 0.5840 - val_loss: 0.3364 - val_AUROC: 0.7911 - val_AUPRC: 0.4783
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2702 - AUROC: 0.8652 - AUPRC: 0.5876 - val_loss: 0.3369 - val_AUROC: 0.7908 - val_AUPRC: 0.4770
# Epoch 13/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2695 - AUROC: 0.8631 - AUPRC: 0.5917 - val_loss: 0.3364 - val_AUROC: 0.7916 - val_AUPRC: 0.4781
# Epoch 14/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2724 - AUROC: 0.8573 - AUPRC: 0.5845 - val_loss: 0.3367 - val_AUROC: 0.7917 - val_AUPRC: 0.4778
# Epoch 15/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2700 - AUROC: 0.8622 - AUPRC: 0.5914 - val_loss: 0.3367 - val_AUROC: 0.7910 - val_AUPRC: 0.4773
# Epoch 16/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2713 - AUROC: 0.8601 - AUPRC: 0.5898 - val_loss: 0.3362 - val_AUROC: 0.7910 - val_AUPRC: 0.4784
# Epoch 17/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2700 - AUROC: 0.8605 - AUPRC: 0.5957 - val_loss: 0.3366 - val_AUROC: 0.7908 - val_AUPRC: 0.4777
# Epoch 18/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2711 - AUROC: 0.8600 - AUPRC: 0.5911 - val_loss: 0.3369 - val_AUROC: 0.7909 - val_AUPRC: 0.4774
# Epoch 19/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2710 - AUROC: 0.8614 - AUPRC: 0.5872 - val_loss: 0.3370 - val_AUROC: 0.7908 - val_AUPRC: 0.4775
# Epoch 20/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2693 - AUROC: 0.8616 - AUPRC: 0.5995 - val_loss: 0.3366 - val_AUROC: 0.7910 - val_AUPRC: 0.4778
# Epoch 21/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2675 - AUROC: 0.8659 - AUPRC: 0.6037 - val_loss: 0.3366 - val_AUROC: 0.7911 - val_AUPRC: 0.4775
# Epoch 22/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2742 - AUROC: 0.8565 - AUPRC: 0.5810 - val_loss: 0.3365 - val_AUROC: 0.7912 - val_AUPRC: 0.4769
# Epoch 23/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2726 - AUROC: 0.8601 - AUPRC: 0.5793 - val_loss: 0.3363 - val_AUROC: 0.7915 - val_AUPRC: 0.4763
# Epoch 24/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2708 - AUROC: 0.8601 - AUPRC: 0.5892 - val_loss: 0.3362 - val_AUROC: 0.7907 - val_AUPRC: 0.4777
# Epoch 25/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2697 - AUROC: 0.8644 - AUPRC: 0.5918 - val_loss: 0.3367 - val_AUROC: 0.7914 - val_AUPRC: 0.4779
# Epoch 26/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2705 - AUROC: 0.8600 - AUPRC: 0.5919 - val_loss: 0.3366 - val_AUROC: 0.7918 - val_AUPRC: 0.4777
# Epoch 27/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2707 - AUROC: 0.8621 - AUPRC: 0.5900 - val_loss: 0.3364 - val_AUROC: 0.7916 - val_AUPRC: 0.4776
# Epoch 28/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2699 - AUROC: 0.8609 - AUPRC: 0.5951 - val_loss: 0.3366 - val_AUROC: 0.7909 - val_AUPRC: 0.4774
# Epoch 29/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2707 - AUROC: 0.8614 - AUPRC: 0.5923 - val_loss: 0.3365 - val_AUROC: 0.7910 - val_AUPRC: 0.4782
# Epoch 30/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2735 - AUROC: 0.8563 - AUPRC: 0.5807 - val_loss: 0.3366 - val_AUROC: 0.7918 - val_AUPRC: 0.4774
# Epoch 31/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2716 - AUROC: 0.8594 - AUPRC: 0.5897 - val_loss: 0.3367 - val_AUROC: 0.7917 - val_AUPRC: 0.4789
# Epoch 32/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2727 - AUROC: 0.8574 - AUPRC: 0.5853 - val_loss: 0.3364 - val_AUROC: 0.7914 - val_AUPRC: 0.4778
# Epoch 33/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2719 - AUROC: 0.8603 - AUPRC: 0.5861 - val_loss: 0.3363 - val_AUROC: 0.7908 - val_AUPRC: 0.4788
# Epoch 34/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2698 - AUROC: 0.8598 - AUPRC: 0.5970 - val_loss: 0.3362 - val_AUROC: 0.7921 - val_AUPRC: 0.4780

# %% [markdown]
# ### LSTM

# %%
myMetrics = [
    keras.metrics.AUC(name='AUROC', curve='ROC'),
    keras.metrics.AUC(name='AUPRC', curve='PR')
]

keras.backend.clear_session()
mdl = keras.models.Sequential([
    keras.layers.LSTM(16, return_sequences=True, input_shape=list(X_train.shape)[1:4]),
    keras.layers.BatchNormalization(),
    keras.layers.LSTM(16, return_sequences=False),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(1, activation='sigmoid')
])
mdl.summary()
mdl.compile(loss="binary_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
callback = EarlyStopping(monitor='val_loss', patience=10)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-4)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-5)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-6)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 25, 16)            3136
# _________________________________________________________________
# batch_normalization (BatchNo (None, 25, 16)            64
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 5,393
# Trainable params: 5,329
# Non-trainable params: 64
# _________________________________________________________________
# Epoch 1/50
# 164/164 [==============================] - 6s 19ms/step - loss: 0.7181 - AUROC: 0.5472 - AUPRC: 0.1468 - val_loss: 0.4822 - val_AUROC: 0.6254 - val_AUPRC: 0.2240
# Epoch 2/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.4327 - AUROC: 0.7160 - AUPRC: 0.3077 - val_loss: 0.3913 - val_AUROC: 0.6918 - val_AUPRC: 0.2990
# Epoch 3/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3463 - AUROC: 0.7825 - AUPRC: 0.3679 - val_loss: 0.3741 - val_AUROC: 0.7235 - val_AUPRC: 0.2904
# Epoch 4/50
# 164/164 [==============================] - 2s 14ms/step - loss: 0.3326 - AUROC: 0.7942 - AUPRC: 0.3832 - val_loss: 0.3633 - val_AUROC: 0.7399 - val_AUPRC: 0.3079
# Epoch 5/50
# 164/164 [==============================] - 2s 15ms/step - loss: 0.3182 - AUROC: 0.8095 - AUPRC: 0.4223 - val_loss: 0.3604 - val_AUROC: 0.7557 - val_AUPRC: 0.3439
# Epoch 6/50
# 164/164 [==============================] - 2s 15ms/step - loss: 0.3006 - AUROC: 0.8380 - AUPRC: 0.4671 - val_loss: 0.3708 - val_AUROC: 0.7538 - val_AUPRC: 0.3407
# Epoch 7/50
# 164/164 [==============================] - 2s 15ms/step - loss: 0.2903 - AUROC: 0.8385 - AUPRC: 0.4987 - val_loss: 0.3771 - val_AUROC: 0.7497 - val_AUPRC: 0.3300
# Epoch 8/50
# 164/164 [==============================] - 2s 15ms/step - loss: 0.2919 - AUROC: 0.8506 - AUPRC: 0.5289 - val_loss: 0.3671 - val_AUROC: 0.7598 - val_AUPRC: 0.3542
# Epoch 9/50
# 164/164 [==============================] - 3s 15ms/step - loss: 0.2638 - AUROC: 0.8667 - AUPRC: 0.5325 - val_loss: 0.3876 - val_AUROC: 0.7489 - val_AUPRC: 0.3330
# Epoch 10/50
# 164/164 [==============================] - 3s 15ms/step - loss: 0.2801 - AUROC: 0.8648 - AUPRC: 0.5668 - val_loss: 0.3737 - val_AUROC: 0.7514 - val_AUPRC: 0.3235
# Epoch 11/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2779 - AUROC: 0.8687 - AUPRC: 0.5821 - val_loss: 0.3792 - val_AUROC: 0.7500 - val_AUPRC: 0.3436
# Epoch 12/50
# 164/164 [==============================] - 3s 15ms/step - loss: 0.2697 - AUROC: 0.8729 - AUPRC: 0.5532 - val_loss: 0.3924 - val_AUROC: 0.7407 - val_AUPRC: 0.3305
# Epoch 13/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2712 - AUROC: 0.8720 - AUPRC: 0.5787 - val_loss: 0.3898 - val_AUROC: 0.7524 - val_AUPRC: 0.3469
# Epoch 14/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2498 - AUROC: 0.8926 - AUPRC: 0.6200 - val_loss: 0.3758 - val_AUROC: 0.7558 - val_AUPRC: 0.3380
# Epoch 15/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2559 - AUROC: 0.8914 - AUPRC: 0.6301 - val_loss: 0.3939 - val_AUROC: 0.7250 - val_AUPRC: 0.3243
# Epoch 1/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2392 - AUROC: 0.9019 - AUPRC: 0.6652 - val_loss: 0.3846 - val_AUROC: 0.7487 - val_AUPRC: 0.3431
# Epoch 2/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2306 - AUROC: 0.9105 - AUPRC: 0.6848 - val_loss: 0.3824 - val_AUROC: 0.7532 - val_AUPRC: 0.3468
# Epoch 3/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2338 - AUROC: 0.9079 - AUPRC: 0.6749 - val_loss: 0.3844 - val_AUROC: 0.7496 - val_AUPRC: 0.3455
# Epoch 4/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2298 - AUROC: 0.9123 - AUPRC: 0.6824 - val_loss: 0.3822 - val_AUROC: 0.7528 - val_AUPRC: 0.3507
# Epoch 5/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2272 - AUROC: 0.9144 - AUPRC: 0.6872 - val_loss: 0.3840 - val_AUROC: 0.7510 - val_AUPRC: 0.3486
# Epoch 6/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2312 - AUROC: 0.9106 - AUPRC: 0.6761 - val_loss: 0.3824 - val_AUROC: 0.7513 - val_AUPRC: 0.3517
# Epoch 7/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2297 - AUROC: 0.9127 - AUPRC: 0.6766 - val_loss: 0.3885 - val_AUROC: 0.7471 - val_AUPRC: 0.3455
# Epoch 8/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2279 - AUROC: 0.9132 - AUPRC: 0.6849 - val_loss: 0.3876 - val_AUROC: 0.7484 - val_AUPRC: 0.3483
# Epoch 9/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2263 - AUROC: 0.9149 - AUPRC: 0.6919 - val_loss: 0.3877 - val_AUROC: 0.7495 - val_AUPRC: 0.3487
# Epoch 10/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2211 - AUROC: 0.9189 - AUPRC: 0.7062 - val_loss: 0.3901 - val_AUROC: 0.7494 - val_AUPRC: 0.3496
# Epoch 11/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2253 - AUROC: 0.9150 - AUPRC: 0.6930 - val_loss: 0.3896 - val_AUROC: 0.7491 - val_AUPRC: 0.3485
# Epoch 12/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2255 - AUROC: 0.9153 - AUPRC: 0.6917 - val_loss: 0.3901 - val_AUROC: 0.7482 - val_AUPRC: 0.3475
# Epoch 13/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2217 - AUROC: 0.9181 - AUPRC: 0.7029 - val_loss: 0.3918 - val_AUROC: 0.7463 - val_AUPRC: 0.3462
# Epoch 14/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2212 - AUROC: 0.9177 - AUPRC: 0.7080 - val_loss: 0.3948 - val_AUROC: 0.7467 - val_AUPRC: 0.3444
# Epoch 1/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2190 - AUROC: 0.9198 - AUPRC: 0.7130 - val_loss: 0.3940 - val_AUROC: 0.7457 - val_AUPRC: 0.3458
# Epoch 2/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2199 - AUROC: 0.9204 - AUPRC: 0.7065 - val_loss: 0.3935 - val_AUROC: 0.7466 - val_AUPRC: 0.3472
# Epoch 3/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2197 - AUROC: 0.9209 - AUPRC: 0.7064 - val_loss: 0.3941 - val_AUROC: 0.7462 - val_AUPRC: 0.3464
# Epoch 4/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2153 - AUROC: 0.9250 - AUPRC: 0.7199 - val_loss: 0.3939 - val_AUROC: 0.7465 - val_AUPRC: 0.3461
# Epoch 5/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2170 - AUROC: 0.9233 - AUPRC: 0.7139 - val_loss: 0.3938 - val_AUROC: 0.7461 - val_AUPRC: 0.3463
# Epoch 6/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2236 - AUROC: 0.9169 - AUPRC: 0.6957 - val_loss: 0.3940 - val_AUROC: 0.7452 - val_AUPRC: 0.3461
# Epoch 7/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2189 - AUROC: 0.9220 - AUPRC: 0.7067 - val_loss: 0.3945 - val_AUROC: 0.7463 - val_AUPRC: 0.3462
# Epoch 8/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2203 - AUROC: 0.9188 - AUPRC: 0.7086 - val_loss: 0.3945 - val_AUROC: 0.7470 - val_AUPRC: 0.3468
# Epoch 9/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2155 - AUROC: 0.9237 - AUPRC: 0.7241 - val_loss: 0.3944 - val_AUROC: 0.7466 - val_AUPRC: 0.3476
# Epoch 10/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2164 - AUROC: 0.9244 - AUPRC: 0.7173 - val_loss: 0.3948 - val_AUROC: 0.7465 - val_AUPRC: 0.3473
# Epoch 11/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2203 - AUROC: 0.9196 - AUPRC: 0.7081 - val_loss: 0.3942 - val_AUROC: 0.7459 - val_AUPRC: 0.3464
# Epoch 12/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2213 - AUROC: 0.9194 - AUPRC: 0.7024 - val_loss: 0.3945 - val_AUROC: 0.7467 - val_AUPRC: 0.3462
# Epoch 1/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2154 - AUROC: 0.9262 - AUPRC: 0.7154 - val_loss: 0.3941 - val_AUROC: 0.7469 - val_AUPRC: 0.3465
# Epoch 2/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2202 - AUROC: 0.9188 - AUPRC: 0.7089 - val_loss: 0.3943 - val_AUROC: 0.7467 - val_AUPRC: 0.3470
# Epoch 3/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2175 - AUROC: 0.9199 - AUPRC: 0.7203 - val_loss: 0.3945 - val_AUROC: 0.7473 - val_AUPRC: 0.3473
# Epoch 4/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2173 - AUROC: 0.9230 - AUPRC: 0.7153 - val_loss: 0.3945 - val_AUROC: 0.7473 - val_AUPRC: 0.3472
# Epoch 5/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2173 - AUROC: 0.9219 - AUPRC: 0.7157 - val_loss: 0.3947 - val_AUROC: 0.7471 - val_AUPRC: 0.3472
# Epoch 6/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2166 - AUROC: 0.9224 - AUPRC: 0.7201 - val_loss: 0.3945 - val_AUROC: 0.7471 - val_AUPRC: 0.3474
# Epoch 7/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2166 - AUROC: 0.9222 - AUPRC: 0.7181 - val_loss: 0.3946 - val_AUROC: 0.7479 - val_AUPRC: 0.3471
# Epoch 8/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2191 - AUROC: 0.9201 - AUPRC: 0.7104 - val_loss: 0.3949 - val_AUROC: 0.7475 - val_AUPRC: 0.3467
# Epoch 9/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2130 - AUROC: 0.9269 - AUPRC: 0.7301 - val_loss: 0.3946 - val_AUROC: 0.7476 - val_AUPRC: 0.3468
# Epoch 10/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2159 - AUROC: 0.9236 - AUPRC: 0.7230 - val_loss: 0.3940 - val_AUROC: 0.7468 - val_AUPRC: 0.3467
# Epoch 11/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2203 - AUROC: 0.9184 - AUPRC: 0.7080 - val_loss: 0.3944 - val_AUROC: 0.7472 - val_AUPRC: 0.3468
# Epoch 12/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2184 - AUROC: 0.9220 - AUPRC: 0.7101 - val_loss: 0.3945 - val_AUROC: 0.7465 - val_AUPRC: 0.3467
# Epoch 13/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2190 - AUROC: 0.9198 - AUPRC: 0.7120 - val_loss: 0.3948 - val_AUROC: 0.7473 - val_AUPRC: 0.3472
# Epoch 14/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2182 - AUROC: 0.9198 - AUPRC: 0.7189 - val_loss: 0.3946 - val_AUROC: 0.7464 - val_AUPRC: 0.3466
# Epoch 15/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2179 - AUROC: 0.9216 - AUPRC: 0.7121 - val_loss: 0.3942 - val_AUROC: 0.7470 - val_AUPRC: 0.3472
# Epoch 16/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2178 - AUROC: 0.9217 - AUPRC: 0.7156 - val_loss: 0.3943 - val_AUROC: 0.7476 - val_AUPRC: 0.3474
# Epoch 17/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2126 - AUROC: 0.9259 - AUPRC: 0.7307 - val_loss: 0.3947 - val_AUROC: 0.7470 - val_AUPRC: 0.3465
# Epoch 18/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2182 - AUROC: 0.9228 - AUPRC: 0.7093 - val_loss: 0.3947 - val_AUROC: 0.7476 - val_AUPRC: 0.3469
# Epoch 19/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2131 - AUROC: 0.9268 - AUPRC: 0.7258 - val_loss: 0.3948 - val_AUROC: 0.7474 - val_AUPRC: 0.3473
# Epoch 20/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.2147 - AUROC: 0.9276 - AUPRC: 0.7149 - val_loss: 0.3946 - val_AUROC: 0.7469 - val_AUPRC: 0.3471

# %% [markdown]
# ## Post-training Interpretability
# ### Relative risk as a function of time to infection

# %%
# input and output variable name lists
input_vars = ['txp___yes', 'age___vital', 'temp___vital', 'heart_rate___vital', 'resp_rate___vital', 'spo2___vital', 'x_hr_rr___vital', 's_hr___vital', 's_rr___vital', 's_so2___vital', 'systolic_blood_pressure___vital', 'diastolic_blood_pressure___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'sodium___vital', 'wbc___vital', 'phosphorus___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'pco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital']
output_var = ['y___pos']


# reformat inputs to be 2d image and 1 output per image
X_whole = whole_df[input_vars].values
Y_whole = whole_df[output_var].values
X_whole = np.reshape(X_whole, (-1,25,32) )
Y_whole = np.reshape(Y_whole, (-1,25,1) )[:,0,:]
print(X_whole.shape)
print(Y_whole.shape)

pos_index = np.where(Y_whole[:,0]==1.0)[0]
neg_index = np.where(Y_whole[:,0]==0.0)[0]

x = X_whole[pos_index,0,:]
X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
y_pos = mdl.predict(X_new)
x = X_whole[neg_index,0,:]
X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
y_neg = mdl.predict(X_new)

for i in range(1,X_whole.shape[1]):
    print("-------------------")
    x = X_whole[pos_index,i,:]
    X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
    y = mdl.predict(X_new)
    print(np.mean(y))
    y_pos = np.column_stack((y_pos,y))
    x = X_whole[neg_index,i,:]
    X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
    y = mdl.predict(X_new)
    print(np.mean(y))
    y_neg = np.column_stack((y_neg,y))
# Out:
# (6557, 25, 32)
# (6557, 1)
# -------------------
# 0.25520402
# 0.0619351
# -------------------
# 0.25919375
# 0.065849505
# -------------------
# 0.27226505
# 0.069770224
# -------------------
# 0.27837446
# 0.0756981
# -------------------
# 0.3090216
# 0.09114449
# -------------------
# 0.3335108
# 0.099651806
# -------------------
# 0.33719125
# 0.10192312
# -------------------
# 0.34098274
# 0.10313981
# -------------------
# 0.34738672
# 0.104268186
# -------------------
# 0.34936947
# 0.10447181
# -------------------
# 0.35649452
# 0.105039164
# -------------------
# 0.36106172
# 0.11489521
# -------------------
# 0.36958054
# 0.11708517
# -------------------
# 0.3777348
# 0.11906173
# -------------------
# 0.39900693
# 0.12419629
# -------------------
# 0.4479423
# 0.14205685
# -------------------
# 0.45828035
# 0.1453549
# -------------------
# 0.4611266
# 0.14578333
# -------------------
# 0.45462143
# 0.14752606
# -------------------
# 0.46498406
# 0.1467642
# -------------------
# 0.46816188
# 0.14702985
# -------------------
# 0.46728447
# 0.14734402
# -------------------
# 0.4630048
# 0.14765547
# -------------------
# 0.46040708
# 0.14979462

# %%
df_pos = pd.DataFrame(data={'y_prob': y_pos.reshape([-1]), 'time': list(range(-24,1))*y_pos.shape[0]})
df_pos['y_true'] = 'event'
print(df_pos.head(5))
print(df_pos.shape)
df_neg = pd.DataFrame(data={'y_prob': y_neg.reshape([-1]), 'time': list(range(-24,1))*y_neg.shape[0]})
df_neg['y_true'] = 'control'
print(df_neg.head(5))
print(df_neg.shape)
df_res = pd.concat([df_pos,df_neg], axis=0)
basemean = np.mean(Y_whole)
print(basemean)
df_res['risk'] = df_res['y_prob']/basemean
plt.figure(figsize=(10,3))
sns.lineplot(data=df_res, x="time", y="risk", hue="y_true", palette=['orange', 'blue']);
# Out:
#      y_prob  time y_true
# 0  0.044433   -24  event
# 1  0.044433   -23  event
# 2  0.044433   -22  event
# 3  0.044433   -21  event
# 4  0.044433   -20  event
# (21925, 3)
#     y_prob  time   y_true
# 0  0.04458   -24  control
# 1  0.04458   -23  control
# 2  0.04458   -22  control
# 3  0.04458   -21  control
# 4  0.04458   -20  control
# (142000, 3)
# 0.13375019063596158

# %%
# input and output variable name lists
input_vars = ['txp___yes', 'age___vital', 'temp___vital', 'heart_rate___vital', 'resp_rate___vital', 'spo2___vital', 'x_hr_rr___vital', 's_hr___vital', 's_rr___vital', 's_so2___vital', 'systolic_blood_pressure___vital', 'diastolic_blood_pressure___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'sodium___vital', 'wbc___vital', 'phosphorus___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'pco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital']
output_var = ['y___pos','y___neg','y___nbc']


# reformat inputs to be 2d image and 1 output per image
X_whole = whole_df[input_vars].values
Y_whole = whole_df[output_var].values
X_whole = np.reshape(X_whole, (-1,25,32) )
Y_whole = np.reshape(Y_whole, (-1,25,3) )[:,0,:]
print(X_whole.shape)
print(Y_whole.shape)


pos_index = np.where(Y_whole[:,0]==1.0)[0]
neg_index = np.where(Y_whole[:,1]==1.0)[0]
nbc_index = np.where(Y_whole[:,2]==1.0)[0]

x = X_whole[pos_index,0,:]
X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
y_pos = mdl.predict(X_new)
x = X_whole[neg_index,0,:]
X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
y_neg = mdl.predict(X_new)
x = X_whole[nbc_index,0,:]
X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
y_nbc = mdl.predict(X_new)

for i in range(1,X_whole.shape[1]):
    print("-------------------")
    # postive
    x = X_whole[pos_index,i,:]
    X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
    y = mdl.predict(X_new)
    basemean = np.mean(Y_whole[:,0])
    print("predicted mean {}, basemean {}, relative risk {}".format(np.mean(y), basemean, np.mean(y)/basemean))
    y_pos = np.column_stack((y_pos,y))
    # negative
    x = X_whole[neg_index,i,:]
    X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
    y = mdl.predict(X_new)
    basemean = np.mean(Y_whole[:,0])
    print("predicted mean {}, basemean {}, relative risk {}".format(np.mean(1-y), basemean, np.mean(y)/basemean))
    y_neg = np.column_stack((y_neg,y))
    # no blood culture
    x = X_whole[nbc_index,i,:]
    X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
    y = mdl.predict(X_new)
    basemean = np.mean(Y_whole[:,0])
    print("predicted mean {}, basemean {}, relative risk {}".format(np.mean(1-y), basemean, np.mean(y)/basemean))
    y_nbc = np.column_stack((y_nbc,y))
# Out:
# (6557, 25, 32)
# (6557, 3)
# -------------------
# predicted mean 0.2552040219306946, basemean 0.13375019063596158, relative risk 1.9080647340930037
# predicted mean 0.9396901726722717, basemean 0.13375019063596158, relative risk 0.45091364776955634
# predicted mean 0.9329070448875427, basemean 0.13375019063596158, relative risk 0.501628298902865
# -------------------
# predicted mean 0.2591937482357025, basemean 0.13375019063596158, relative risk 1.9378944209595226
# predicted mean 0.9358178973197937, basemean 0.13375019063596158, relative risk 0.4798653371878469
# predicted mean 0.9288589954376221, basemean 0.13375019063596158, relative risk 0.5318943245703844
# -------------------
# predicted mean 0.2722650468349457, basemean 0.13375019063596158, relative risk 2.035623616986019
# predicted mean 0.9310778975486755, basemean 0.13375019063596158, relative risk 0.5153049272373573
# predicted mean 0.9275383949279785, basemean 0.13375019063596158, relative risk 0.5417682376935516
# -------------------
# predicted mean 0.27837446331977844, basemean 0.13375019063596158, relative risk 2.0813014321411485
# predicted mean 0.9234752655029297, basemean 0.13375019063596158, relative risk 0.572146676446788
# predicted mean 0.926925003528595, basemean 0.13375019063596158, relative risk 0.5463537223203832
# -------------------
# predicted mean 0.30902159214019775, basemean 0.13375019063596158, relative risk 2.310438517289939
# predicted mean 0.9033300280570984, basemean 0.13375019063596158, relative risk 0.7227652823146827
# predicted mean 0.9263901710510254, basemean 0.13375019063596158, relative risk 0.5503529654635263
# -------------------
# predicted mean 0.33351078629493713, basemean 0.13375019063596158, relative risk 2.4935350350466394
# predicted mean 0.8920448422431946, basemean 0.13375019063596158, relative risk 0.8071402159764801
# predicted mean 0.9266980886459351, basemean 0.13375019063596158, relative risk 0.5480512824661375
# -------------------
# predicted mean 0.33719125390052795, basemean 0.13375019063596158, relative risk 2.521052510633708
# predicted mean 0.8892230987548828, basemean 0.13375019063596158, relative risk 0.8282371106618078
# predicted mean 0.9261733889579773, basemean 0.13375019063596158, relative risk 0.5519738195542598
# -------------------
# predicted mean 0.34098273515701294, basemean 0.13375019063596158, relative risk 2.5493999936425698
# predicted mean 0.8882688283920288, basemean 0.13375019063596158, relative risk 0.835371999293056
# predicted mean 0.9241241216659546, basemean 0.13375019063596158, relative risk 0.5672960907917474
# -------------------
# predicted mean 0.3473867177963257, basemean 0.13375019063596158, relative risk 2.597280169430453
# predicted mean 0.8867869973182678, basemean 0.13375019063596158, relative risk 0.8464510943337068
# predicted mean 0.9241172671318054, basemean 0.13375019063596158, relative risk 0.5673464482890159
# -------------------
# predicted mean 0.34936946630477905, basemean 0.13375019063596158, relative risk 2.612104436214864
# predicted mean 0.8863256573677063, basemean 0.13375019063596158, relative risk 0.8499005828966028
# predicted mean 0.9247316718101501, basemean 0.13375019063596158, relative risk 0.5627536662814961
# -------------------
# predicted mean 0.3564945161342621, basemean 0.13375019063596158, relative risk 2.66537576088068
# predicted mean 0.8859866261482239, basemean 0.13375019063596158, relative risk 0.852435447844839
# predicted mean 0.9234397411346436, basemean 0.13375019063596158, relative risk 0.5724125016425463
# -------------------
# predicted mean 0.3610617220401764, basemean 0.13375019063596158, relative risk 2.6995230460860165
# predicted mean 0.8770669102668762, basemean 0.13375019063596158, relative risk 0.9191244830937042
# predicted mean 0.910612165927887, basemean 0.13375019063596158, relative risk 0.6683196364100193
# -------------------
# predicted mean 0.36958053708076477, basemean 0.13375019063596158, relative risk 2.763215030374657
# predicted mean 0.8746359944343567, basemean 0.13375019063596158, relative risk 0.9373000858854947
# predicted mean 0.9091871380805969, basemean 0.13375019063596158, relative risk 0.6789740907408491
# -------------------
# predicted mean 0.37773481011390686, basemean 0.13375019063596158, relative risk 2.8241814708288335
# predicted mean 0.8714399337768555, basemean 0.13375019063596158, relative risk 0.9611954982121694
# predicted mean 0.9110804200172424, basemean 0.13375019063596158, relative risk 0.6648186762459329
# -------------------
# predicted mean 0.3990069329738617, basemean 0.13375019063596158, relative risk 2.9832251533746987
# predicted mean 0.8652447462081909, basemean 0.13375019063596158, relative risk 1.0075150372262962
# predicted mean 0.909311830997467, basemean 0.13375019063596158, relative risk 0.67804191998942
# -------------------
# predicted mean 0.4479422867298126, basemean 0.13375019063596158, relative risk 3.349096435675463
# predicted mean 0.8421770930290222, basemean 0.13375019063596158, relative risk 1.17998300356835
# predicted mean 0.9079753160476685, basemean 0.13375019063596158, relative risk 0.6880339281283055
# -------------------
# predicted mean 0.4582803547382355, basemean 0.13375019063596158, relative risk 3.4263902919254385
# predicted mean 0.8381281495094299, basemean 0.13375019063596158, relative risk 1.2102548782814595
# predicted mean 0.907059907913208, basemean 0.13375019063596158, relative risk 0.694877812815161
# -------------------
# predicted mean 0.4611265957355499, basemean 0.13375019063596158, relative risk 3.4476705681163065
# predicted mean 0.8380393981933594, basemean 0.13375019063596158, relative risk 1.2109183271669335
# predicted mean 0.9055534601211548, basemean 0.13375019063596158, relative risk 0.7061414034652737
# -------------------
# predicted mean 0.45462143421173096, basemean 0.13375019063596158, relative risk 3.399033915765473
# predicted mean 0.8358232975006104, basemean 0.13375019063596158, relative risk 1.227487726334563
# predicted mean 0.90531325340271, basemean 0.13375019063596158, relative risk 0.7079375618081135
# -------------------
# predicted mean 0.46498405933380127, basemean 0.13375019063596158, relative risk 3.4765113763417728
# predicted mean 0.8373083472251892, basemean 0.13375019063596158, relative risk 1.2163847894699842
# predicted mean 0.9037800431251526, basemean 0.13375019063596158, relative risk 0.7193999643030841
# -------------------
# predicted mean 0.4681618809700012, basemean 0.13375019063596158, relative risk 3.500270756579587
# predicted mean 0.8365758657455444, basemean 0.13375019063596158, relative risk 1.2218607216563708
# predicted mean 0.904995858669281, basemean 0.13375019063596158, relative risk 0.7103108816876786
# -------------------
# predicted mean 0.4672844707965851, basemean 0.13375019063596158, relative risk 3.4937106898668278
# predicted mean 0.8367958664894104, basemean 0.13375019063596158, relative risk 1.2202160814469052
# predicted mean 0.9029864072799683, basemean 0.13375019063596158, relative risk 0.725334127432536
# -------------------
# predicted mean 0.46300479769706726, basemean 0.13375019063596158, relative risk 3.461713179589133
# predicted mean 0.8366574048995972, basemean 0.13375019063596158, relative risk 1.2212510839903232
# predicted mean 0.9021259546279907, basemean 0.13375019063596158, relative risk 0.7317673534137901
# -------------------
# predicted mean 0.4604070782661438, basemean 0.13375019063596158, relative risk 3.4422910059191616
# predicted mean 0.834806501865387, basemean 0.13375019063596158, relative risk 1.2350901486766241
# predicted mean 0.8990723490715027, basemean 0.13375019063596158, relative risk 0.754598685084686

# %%
df_pos = pd.DataFrame(data={'y_prob': y_pos.reshape([-1]), 'time': list(range(-24,1))*y_pos.shape[0]})
df_pos['y_true'] = 'positive'
df_pos['risk'] = df_pos['y_prob']/np.mean(Y_whole[:,0])
print(df_pos.head(5))
print(df_pos.shape)
df_neg = pd.DataFrame(data={'y_prob': y_neg.reshape([-1]), 'time': list(range(-24,1))*y_neg.shape[0]})
df_neg['y_true'] = 'negative'
df_neg['risk'] = df_neg['y_prob']/np.mean(Y_whole[:,0])
print(df_neg.head(5))
print(df_neg.shape)
df_nbc = pd.DataFrame(data={'y_prob': y_nbc.reshape([-1]), 'time': list(range(-24,1))*y_nbc.shape[0]})
df_nbc['y_true'] = 'baseline'
df_nbc['risk'] = df_nbc['y_prob']/np.mean(Y_whole[:,0])
print(df_nbc.head(5))
print(df_nbc.shape)
df_res = pd.concat([df_pos,df_neg,df_nbc], axis=0)
plt.figure(figsize=(10,3))
sns.lineplot(data=df_res, x="time", y="risk", hue="y_true", palette=['red','orange', 'blue']);
# Out:
#      y_prob  time    y_true      risk
# 0  0.044433   -24  positive  0.332208
# 1  0.044433   -23  positive  0.332208
# 2  0.044433   -22  positive  0.332208
# 3  0.044433   -21  positive  0.332208
# 4  0.044433   -20  positive  0.332208
# (21925, 4)
#      y_prob  time    y_true      risk
# 0  0.043763   -24  negative  0.327196
# 1  0.043763   -23  negative  0.327196
# 2  0.043763   -22  negative  0.327196
# 3  0.043763   -21  negative  0.327196
# 4  0.202912   -20  negative  1.517099
# (107975, 4)
#     y_prob  time    y_true      risk
# 0  0.04458   -24  baseline  0.333308
# 1  0.04458   -23  baseline  0.333308
# 2  0.04458   -22  baseline  0.333308
# 3  0.04458   -21  baseline  0.333308
# 4  0.04458   -20  baseline  0.333308
# (34025, 4)

# %% [markdown]
# ### Model performance (AUC) over time

# %%
import sklearn

score_list = list()
y_true = Y_whole[:,0]
x = X_whole[:,0,:]
X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
y_pred = mdl.predict(X_new)
score = sklearn.metrics.roc_auc_score(y_true, y_pred)
score_list.append(score)

for i in range(1,X_whole.shape[1]):
    x = X_whole[:,i,:]
    X_new = np.repeat(x[:, np.newaxis, :], 25, axis=1)
    y_pred = mdl.predict(X_new)
    score=sklearn.metrics.roc_auc_score(y_true, y_pred)
    score_list.append(score)

df_score = pd.DataFrame({'AUC':score_list,'Time':range(-24,1)})
plt.figure(figsize=(10,3))
sns.lineplot(data=df_score, x="Time", y="AUC");

# %% [markdown]
# ## Feature permutation importance

# %%
import random
import sklearn
X_whole_org = np.reshape(whole_df[input_vars].values, (-1,25,32) )
y_prob = mdl.predict(X_whole_org)
y_true = Y_whole
base_score = sklearn.metrics.roc_auc_score(y_true, y_prob)
base_score
# Out:
# 0.912137247659274

# %%
# score_arr = np.empty(shape=(X_whole_org.shape[1]-3, X_whole_org.shape[2]))
# # permutation at each time point in each variable
# for i in range(3,X_whole_org.shape[1]): # time 
#     for j in range(X_whole_org.shape[2]): # variable
#         X_whole = X_whole_org.copy()
#         values = X_whole[:,range(i-3,i),j].reshape(-1)
#         np.random.shuffle(values)
#         X_whole[:,range(i-3,i),j] = values.reshape(X_whole[:,range(i-3,i),j].shape)
#         score_arr[i-3,j] = sklearn.metrics.roc_auc_score(y_true, mdl.predict(X_whole))
        
# np.save("./score_permuate_lstm_pctl_ma.npy",score_arr)

# %%
base_score = 0.912137247659274
score_arr = np.load("./score_permuate_lstm_pctl_ma.npy")
score_delta = base_score - score_arr
score_delta_T = score_delta.T
score_delta_T = (score_delta_T - np.min(score_delta_T))/(np.max(score_delta_T)-np.min(score_delta_T))

input_vars = ['txp', 'age', 'temperature', 'heart_rate', 'resp_rate', 'spo2', 'x_hr_rr', 's_hr', 's_rr', 
              's_so2', 'systolic_blood_pressure', 'diastolic_blood_pressure', 'glucose', 'bilirubin', 
              'potassium', 'albumin', 'calcium', 'sodium', 'wbc', 'phosphorus', 'creatinine', 'platelet_count',
              'alt', 'alp', 'ast', 'pco2', 'chloride', 'troponin', 'ptt', 'lactate', 'bun', 'magnesium']
output_var = ['y___pos']
score_delta_T_df = pd.DataFrame(score_delta_T, index=input_vars, columns=range(-22,0))
sns.set(font_scale = 1.6)
sns.clustermap(score_delta_T_df, row_cluster=1, col_cluster=0, #metric="correlation",
               figsize=(9,15),
               cbar_pos=(1, .2, .03, .4))

# %%
base_score = 0.912137247659274
score_arr = np.load("./score_permuate_lstm_pctl_ma.npy")
score_delta = base_score - score_arr
score_delta_T = score_delta.T
score_pct = np.array(pd.DataFrame(score_delta_T.reshape(-1)).rank(pct=True))
score_delta_T = score_pct.reshape((score_delta_T.shape[0], score_delta_T.shape[1]))

input_vars = ['txp', 'age', 'temperature', 'heart_rate', 'resp_rate', 'spo2', 'x_hr_rr', 's_hr', 's_rr', 
              's_so2', 'systolic_blood_pressure', 'diastolic_blood_pressure', 'glucose', 'bilirubin', 
              'potassium', 'albumin', 'calcium', 'sodium', 'wbc', 'phosphorus', 'creatinine', 'platelet_count',
              'alt', 'alp', 'ast', 'pco2', 'chloride', 'troponin', 'ptt', 'lactate', 'bun', 'magnesium']
output_var = ['y___pos']
score_delta_T_df = pd.DataFrame(score_delta_T, index=input_vars, columns=range(-22,0))
sns.set(font_scale = 1.6)
sns.clustermap(score_delta_T_df, row_cluster=1, col_cluster=0, #metric="correlation",
               figsize=(9,15),
               cbar_pos=(1, .2, .03, .4))
