# %% [markdown]
# # Case txp
#
# > In this case study, we are exploring deep learning interpretability on BSI prognosis, before, during and after training a CNN model on multi-variate time series medical record.
#
# > we use hourly aggregated physiological data and lab results from 10,000 ICU patients. 1824 positive events and 31496 control group events are generated from the population.
#
# > we use 25 features selected by domain knowledge, 96 hours prior to the blood culture acquisition to classify positive test results from the control group -- negative test results and 4 days of randomly sliced baseline patient data.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', 500)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

import FAIRStream

# %%
# csv pool folder directory
csv_pool_path = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/csv_pool'
# current experiment working directory
work_dir = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case_fwd'

# initiate dataframe to return
all_df=None
# initiate a FAIRStream object instance for BSI project
bsi_stream = FAIRStream.FAIRStream(work_dir)
# take a look at dictionaries in engineer's hands
#bsi_stream.engineer.csv_source_dict
print(bsi_stream.engineer.variable_dict)
print(bsi_stream.engineer.csv_source_dict)
# Out:
# Success: Querier has initiated a csv source dictionary in:/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case_fwd/meta_data/csv_source_dict_demo.json
# Success: Querier has initiated a variable dictionary in:/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case_fwd/meta_data/variable_dict_demo.json
# Unable to read sql source dictionary. Use Querier.update_sql_source_dict() to build one.
# {'__uid': {'src_names': ['id', 'ID', 'subject_id', 'subject_id', 'oldid'], 'label': 'subject id', 'unique_per_sbj': True}, '__time': {'src_names': ['tsa', 'timeMinutes'], 'label': 'Time since admission', 'unit': 'minute'}, '__anchor': {'src_names': ['True_positive', 'True positive', 'label'], 'label': 'episode anchor', 'unique_per_sbj': False, 'shuffle': ['__nbc'], 'factor': {'levels': {'__nbc': ['nan'], '__ctm': ['contaminant'], '__neg': ['0', '0.0', 'negative'], '__pos': ['1', '1.0', 'true_positive']}, 'impute_per_sbj': {'nan_level': '__nbc'}}}, 'y': {'output': True, 'src_names': ['True_positive', 'True positive', 'label'], 'label': 'Blood culture result', 'unique_per_sbj': False, 'factor': {'levels': {'nbc': ['nan'], 'ctm': ['contaminant'], 'neg': ['0', '0.0', 'negative'], 'pos': ['1', '1.0', 'true_positive']}, 'impute_per_sbj': {'nan_level': 'nbc'}}}, 'age': {'input': True, 'src_names': ['age', 'AGE'], 'label': 'Age', 'unique_per_sbj': True, 'numeric': {'scaler': 'none', 'unit': 'year', 'cutoff': {'quantile_min': 0.0, 'quantile_max': 1, 'value_min': 0, 'value_max': 110}, 'impute_per_sbj': {'forward': 5760, 'backward': 0}}}, 'albumin': {'input': True, 'src_names': ['Albumin', 'ALBUMIN', 'albumin'], 'label': 'Albumin', 'unique_per_sbj': False, 'numeric': {'scaler': 'none', 'cutoff': {'quantile_min': 0.0, 'quantile_max': 1, 'value_min': 0, 'value_max': 5}, 'unit': '', 'impute_per_sbj': {'forward': 5760, 'backward': 0}}}, 'alp': {'input': True, 'src_names': ['ALKALINE.PHOSPHATASE', 'ALP', 'alp'], 'label': 'ALP', 'unique_per_sbj': False, 'numeric': {'scaler': 'none', 'cutoff': {'quantile_min': 0.0, 'quantile_max': 1, 'value_min': 0, 'value_max': 1000}, 'unit': '', 'impute_per_sbj': {'forward': 5760, 'backward': 0}}}, 'alt': {'input': True, 'src_names': ['ALT.GPT', 'ALT', 'alt'], 'label': 'ALT', 'unique_per_sbj': False, 'numeric': {'scaler': 'none', 'cutoff': {'quantile_min': 0.0, 'quantile_max': 1, 'value_min': 0, 'value_max': 2500}, 'unit': '', 'impute_per_sbj': {'forward': 5760, 'backward': 0}}}, 'ast': {'input': True, 'src_names': ['AST.GOT', 'AST', 'ast'], 'label': 'AST', 'unique_per_sbj': False, 'numeric': {'scaler': 'none', 'cutoff': {'quantile_min': 0.0, 'quantile_max': 1, 'value_min': 0, 'value_max': 2500}, 'unit': '', 'impute_per_sbj': {'forward': 5760, 'backward': 0}}}, 'bicarbonate': {'input': True, 'src_names': ['bicarbonate', 'BICARBONATE'], 'label': 'Bicarbonate', 'unique_per_sbj': False, 'numeric': {'scaler': 'none', 'cutoff': {'quantile_min': 0.0, 'quantile_max': 1, 'value_min': 0, 'value_max': 60}, 'unit': '', 'impute_per_sbj': {'forward': 5760, 'backward': 0}}}, 'bun': {'input': True, 'src_names': ['BLOOD.UREA.NITROGEN', 'BUN', 'bun'], 'label': 'BUN', 'unique_per_sbj': False, 'numeric': {'scaler': 'none', 'cutoff': {'quantile_min': 0.0, 'quantile_max': 1, 'value_min': 0, 'value_max': 150}, 'unit': '', 'impute_per_sbj': {'forward': 5760, 'backward': 0}}}, 'calcium': {'input': True, 'src_names': ['CALCIUM', 'Calcium', 'calcium'], 'label': 'Calcium', 'unique_per_sbj': False, 'numeric': {'scaler': 'none', 'cutoff': {'quantile_min': 0.0, 'quantile_max': 1, 'value_min': 4, 'value_max': 15}, 'unit': '', 'impute_per_sbj': {'forward': 5760, 'backward': 0}}}, 'chloride': {'input': True, 'src_names': ['CHLORIDE', 'Chloride', 'chloride'], 'label': 'Chloride', 'unique_per_sbj': False, 'numeric': {'scaler': 'none', 'cutoff': {'quantile_min': 0.0, 'quantile_max': 1, 'value_min': 50, 'value_max': 140}, 'unit': '', 'impute_per_sbj': {'forward': 5760, 'backward': 0}}}, 'co2': {'input': True, 'src_names': ['CO2', 'co2'], 'label': 'CO2', 'unique_per_sbj': False, 'numeric': {'scaler': 'none', 'cutoff': {'quantile_min': 0.0, 'quantile_max': 1, 'value_min': 0, 'value_max': 45}, 'unit': '', 'impute_per_sbj': {'forward': 5760, 'backward': 0}}}, 'creatinine': {'input': True, 'src_names': ['CREATININE', 'Creatinine', 'creatinine'], 'label': 'Creatinine', 'unique_per_sbj': False, 'numeric': {'scaler': 'none', 'cutoff': {'quantile_min': 0 ...
# {'uva': {'vital': {'include': False, 'path': '/Users/jiaxingqiu/Documents/BSI/code/DeepDiag/data/bsi_old_deidentified_final.csv', 'info': 'Vital signs data from UVA'}, 'lab': {'include': False, 'path': '/Users/jiaxingqiu/Documents/BSI/code/DeepDiag/data/uva_lab.csv', 'info': 'Lab results data from UVA'}}, 'uvaold': {'all': {'include': True, 'path': '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/2011_2015/data_ml/bsi_old_final.csv', 'info': 'Data from UVA 2011 - 2015 '}}, 'uvanewbc': {'all': {'include': False, 'path': '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/2016_2021/data_ml/bsi_new_deidentified_bc.csv', 'info': 'Data from UVA 2017 - 2021 (cohort who have at least one blood culture )'}}, 'uvanewnbc': {'all': {'include': False, 'path': '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/2016_2021/data_ml/bsi_new_deidentified_nbc.csv', 'info': 'Data from UVA 2017 - 2021 (cohort who have non blood culture)'}}, 'mimic': {'vital': {'include': False, 'path': '/Users/jiaxingqiu/Documents/BSI/code/DeepDiag/data/mimic_patient_data_minutes.csv', 'info': 'Vital signs data from MIMIC'}, 'lab': {'include': False, 'path': '/Users/jiaxingqiu/Documents/BSI/code/DeepDiag/data/mimic_labs_minutes_combined.csv', 'info': 'Lab results data from MIMIC'}}}

# %%
# bsi_stream.querier.create_csv_pool(csv_pool_dir = csv_pool_path,
#                                   source_key="uvanewbc",
#                                   file_key="all",
#                                   sep="_")

# %%
# bsi_stream.querier.create_csv_pool(csv_pool_dir = csv_pool_path,
#                                   source_key="uvanewnbc",
#                                   file_key="all",
#                                   sep="_")

# %%
## nbc (baseline) group 
# # define an episode (notice that the engineer now has new attributes)
# bsi_stream.engineer.DefineEpisode(input_time_len=1*60, # using vital signs and labs 4 days prior to a culture 
#                                   output_time_len=(4*24-1)*60, # predict one time unit into the future
#                                   time_resolution=60, # aggregate minutely data to one row per hour 
#                                   time_lag=0,  # no time lag between predictors and response
#                                   anchor_gap=4*24*60) # the minimum distance between two episodes

# %%
# bc group 
bsi_stream.engineer.DefineEpisode(input_time_len=2*24*60, # using vital signs and labs 4 days prior to a culture 
                                  output_time_len=2*24*60, # predict one time unit into the future
                                  time_resolution=60, # aggregate minutely data to one row per hour 
                                  time_lag=0,  # no time lag between predictors and response
                                  anchor_gap=7*24*60) # the minimum distance between two episodes
# Out:
# Success! Engineer has updated attributes --- episode.

# %%
df_bc = pd.read_csv("/Users/jiaxingqiu/Documents/CAMA_projects/BSI/2016_2021/data_ml/bsi_new_deidentified_bc.csv")

# %%
id_list = list(df_bc['id'].unique())[6000:len(list(df_bc['id'].unique()))]
df_bc_now = df_bc.loc[df_bc.id.isin(id_list),:]
df_bc_now.shape
# Out:
# (1716253, 66)

# %%
# Build MVTS dataframe or tfds from external table object!!!
bsi_stream.engineer.BuildMVTS(csv_pool_path, 
                              nsbj = 50, # number of subjects / patients to sample from the pool 
                              replace = False, # sample with replacement or not 
                              valid_frac = 0.2, # fraction of number of subjects in validation dataset
                              test_frac = 0.1, # fraction of number of subjects in left-out test dataset
                              batch_size = 64, # batch size (usually 32,64,128..)
                              impute_input='none', # imputation on predictors
                              impute_output='none',# imputation on response (no need in BSI project)
                              sep="_", 
                              return_episode=True,
                              df_raw=df_bc_now)
# Out:
# Engineer is sampling without replacement ---
# Just kidding :) Engineer is using external tabular data you input!
# -- __time fixed
# -- __anchor fixed
# -- y fixed
# --- fix upper boundary for age by 90.0
# --- fix lower boundary for age by 18.04
# -- age fixed
# --- fix upper boundary for albumin by 4.9
# --- fix lower boundary for albumin by 1.2
# -- albumin fixed
# --- fix upper boundary for alp by 1000.0
# --- fix lower boundary for alp by 18.0
# -- alp fixed
# --- fix upper boundary for alt by 2500.0
# --- fix lower boundary for alt by 6.0
# -- alt fixed
# --- fix upper boundary for ast by 2500.0
# --- fix lower boundary for ast by 8.0
# -- ast fixed
# --- fix upper boundary for bicarbonate by 58.2576
# --- fix lower boundary for bicarbonate by 5.8
# -- bicarbonate fixed
# --- fix upper boundary for bun by 150.0
# --- fix lower boundary for bun by 2.0
# -- bun fixed
# --- fix upper boundary for calcium by 13.89455
# --- fix lower boundary for calcium by 5.2
# -- calcium fixed
# --- fix upper boundary for chloride by 137.0
# --- fix lower boundary for chloride by 74.0
# -- chloride fixed
# --- fix upper boundary for co2 by 45.0
# --- fix lower boundary for co2 by 7.0
# -- co2 fixed
# --- fix upper boundary for creatinine by 10.0
# --- fix lower boundary for creatinine by 0.2
# -- creatinine fixed
# --- fix upper boundary for dbp by 150.0
# --- fix lower boundary for dbp by 26.0
# -- dbp fixed
# --- fix upper boundary for fio2_pct by 100.0
# --- fix lower boundary for fio2_pct by 21.0
# -- fio2_pct fixed
# --- fix upper boundary for glucose by 500.0
# --- fix lower boundary for glucose by 41.0
# -- glucose fixed
# --- fix upper boundary for hematocrit by 58.0
# --- fix lower boundary for hematocrit by 14.0
# -- hematocrit fixed
# --- fix upper boundary for hemoglobin by 19.2
# --- fix lower boundary for hemoglobin by 4.5
# -- hemoglobin fixed
# --- fix upper boundary for heart_rate by 200.0
# --- fix lower boundary for heart_rate by 30.0
# -- heart_rate fixed
# --- fix upper boundary for lactic_acid by 19.1
# --- fix lower boundary for lactic_acid by 0.3
# -- lactic_acid fixed
# --- fix upper boundary for magnesium by 5.0
# --- fix lower boundary for magnesium by 0.9
# -- magnesium fixed
# --- fix upper boundary for o2_flow by 80.0
# --- fix lower boundary for o2_flow by 0.0
# -- o2_flow fixed
# --- fix upper boundary for pco2 by 110.0
# --- fix lower boundary for pco2 by 16.3
# -- pco2 fixed
# --- fix upper boundary for peep by 40.0
# --- fix lower boundary for peep by 0.0
# -- peep fixed
# --- fix upper boundary for ph_arterial by 7.628824000000001
# --- fix lower boundary for ph_arterial by 6.922175999999999
# -- ph_arterial fixed
# --- fix upper boundary for phosphorus by 10.0
# --- fix lower boundary for phosphorus by 1.0
# -- phosphorus fixed
# --- fix upper boundary for po2 by 565.528
# --- fix lower boundary for po2 by 19.4
# -- po2 fixed
# --- fix upper boundary for potassium by 7.3
# --- fix lower boundary for potassium by 2.16286
# -- potassium fixed
# --- fix upper boundary for protime_inr by 6.0
# --- fix lower boundary for protime_inr by 0.8
# -- protime_inr fixed
# --- fix upper boundary for ptt by 150.0
# --- fix lower boundary for ptt by 20.1
# -- ptt fixed
# --- fix upper boundary for platelet_count by 1000.0
# --- fix lower boundary for platelet_count by 3.0
# -- platelet_count fixed
# --- fix upper boundary for resp_rate by 70.0
# --- fix lower boundary for resp_rate by 5.5
# -- resp_rate fixed
# --- fix upper boundary for sbp by 250.0
# --- fix lower boundary for sbp by 40.0
# -- sbp fixed
# --- fix upper boundary for sodium by 168.0
# --- fix lower boundary for sodium by 112.0
# -- sodium fixed
# --- fix upper boundary for spo2 by 100.0
# --- fix lower boundary for spo2 by 79.0
# -- spo2 fixed
# --- fix upper boundary for temp by 104.0
# --- fix lower boundary for temp by 80.0
# -- temp fixed
# --- fix upper boundary for total_bilirubin by 49.2
# --- fix lower boundary for total_bilirubin by 0.1
# -- total_bilirubin fixed
# --- fix upper boundary for total_protein by 9.1456
# --- fix lower boundary for total_protein by 2.2
# -- total_protein fixed
# -- txp fixed
# --- fix upper boundary for troponin by 50.0
# --- fix lower boundary for troponin by 0.02
# -- troponin fixed
# --- fix upper boundary for wbc by 60.0
# --- fix lower boundary for wbc by 0.01
# -- wbc fixed
# --- fix out-of-dictionry level/orders ['nan'] with ['no']
# -- gram_positive fixed
# --- fix out-of-dictionry level/orders ['nan'] with ['no']
# -- gram_negative fixed
# --- fix out-of-dictionry level/orders ['nan'] with ['no']
# -- fungus fixed
# --- fix out-of-dictionry level/orders ['nan'] with ['no']
# -- mycobacterial fixed
# --- prepare episodes for external_7841292.0
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.0
# y___neg    1.0
# y___ctm    0.0
# y___pos    0.0
# dtype: float64
# --- prepare episodes for external_9515352.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.0
# y___neg    1.0
# y___ctm    0.0
# y___pos    0.0
# dtype: float64
# --- prepare episodes for external_9413199.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.058824
# y___neg    0.823529
# y___ctm    0.000000
# y___pos    0.117647
# dtype: float64
# --- prepare episodes for external_8359806.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.105263
# y___neg    0.789474
# y___ctm    0.000000
# y___pos    0.105263
# dtype: float64
# --- prepare episodes for external_7849911.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.095238
# y___neg    0.809524
# y___ctm    0.000000
# y___pos    0.095238
# dtype: float64
# --- prepare episodes for external_7853553.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.090909
# y___neg    0.772727
# y___ctm    0.000000
# y___pos    0.136364
# dtype: float64
# --- prepare episodes for external_7943958.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.125
# y___neg    0.750
# y___ctm    0.000
# y___pos    0.125
# dtype: float64
# --- prepare episodes for external_8125002.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.12
# y___neg    0.76
# y___ctm    0.00
# y___pos    0.12
# dtype: float64
# --- prepare episodes for external_7985025.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.115385
# y___neg    0.769231
# y___ctm    0.000000
# y___pos    0.115385
# dtype: float64
# --- prepare episodes for external_7864557.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.111111
# y___neg    0.777778
# y___ctm    0.000000
# y___pos    0.111111
# dtype: float64
# --- prepare episodes for external_7999236.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.18750
# y___neg    0.71875
# y___ctm    0.00000
# y___pos    0.09375
# dtype: float64
# --- prepare episodes for external_8468292.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.181818
# y___neg    0.727273
# y___ctm    0.000000
# y___pos    0.090909
# dtype: float64
# --- prepare episodes for external_7751817.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.176471
# y___neg    0.735294
# y___ctm    0.000000
# y___pos    0.088235
# dtype: float64
# --- prepare episodes for external_7764846.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.333333
# y___neg    0.611111
# y___ctm    0.000000
# y___pos    0.055556
# dtype: float64
# --- prepare episodes for external_7920663.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.333333
# y___neg    0.616667
# y___ctm    0.000000
# y___pos    0.050000
# dtype: float64
# --- prepare episodes for external_8113452.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.372093
# y___neg    0.569767
# y___ctm    0.000000
# y___pos    0.058140
# dtype: float64
# --- prepare episodes for external_8777676.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363636
# y___neg    0.579545
# y___ctm    0.000000
# y___pos    0.056818
# dtype: float64
# --- prepare episodes for external_7814811.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.373626
# y___neg    0.571429
# y___ctm    0.000000
# y___pos    0.054945
# dtype: float64
# --- prepare episodes for external_8446998.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.378947
# y___neg    0.568421
# y___ctm    0.000000
# y___pos    0.052632
# dtype: float64
# --- prepare episodes for external_7684605.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.375000
# y___neg    0.572917
# y___ctm    0.000000
# y___pos    0.052083
# dtype: float64
# --- prepare episodes for external_7824252.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.37
# y___neg    0.55
# y___ctm    0.00
# y___pos    0.08
# dtype: float64
# --- prepare episodes for external_8847435.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.372549
# y___neg    0.549020
# y___ctm    0.000000
# y___pos    0.078431
# dtype: float64
# --- prepare episodes for external_9520131.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.368932
# y___neg    0.553398
# y___ctm    0.000000
# y___pos    0.077670
# dtype: float64
# --- prepare episodes for external_27111837.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.371429
# y___neg    0.542857
# y___ctm    0.000000
# y___pos    0.085714
# dtype: float64
# --- prepare episodes for external_8679177.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.367925
# y___neg    0.547170
# y___ctm    0.000000
# y___pos    0.084906
# dtype: float64
# --- prepare episodes for external_9411849.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.366972
# y___neg    0.550459
# y___ctm    0.000000
# y___pos    0.082569
# dtype: float64
# --- prepare episodes for external_7863576.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363636
# y___neg    0.554545
# y___ctm    0.000000
# y___pos    0.081818
# dtype: float64
# --- prepare episodes for external_8057553.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.357143
# y___neg    0.562500
# y___ctm    0.000000
# y___pos    0.080357
# dtype: float64
# --- prepare episodes for external_9036213.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.347458
# y___neg    0.576271
# y___ctm    0.000000
# y___pos    0.076271
# dtype: float64
# --- prepare episodes for external_8017599.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.341667
# y___neg    0.583333
# y___ctm    0.000000
# y___pos    0.075000
# dtype: float64
# --- prepare episodes for external_8483103.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.341463
# y___neg    0.585366
# y___ctm    0.000000
# y___pos    0.073171
# dtype: float64
# --- prepare episodes for external_27030345.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.346457
# y___neg    0.582677
# y___ctm    0.000000
# y___pos    0.070866
# dtype: float64
# --- prepare episodes for external_7799637.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.343750
# y___neg    0.585938
# y___ctm    0.000000
# y___pos    0.070312
# dtype: float64
# --- prepare episodes for external_7784454.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.338462
# y___neg    0.584615
# y___ctm    0.000000
# y___pos    0.076923
# dtype: float64
# --- prepare episodes for external_8820639.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.348148
# y___neg    0.577778
# y___ctm    0.000000
# y___pos    0.074074
# dtype: float64
# --- prepare episodes for external_8860293.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.345588
# y___neg    0.580882
# y___ctm    0.000000
# y___pos    0.073529
# dtype: float64
# --- prepare episodes for external_24008640.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.345324
# y___neg    0.582734
# y___ctm    0.000000
# y___pos    0.071942
# dtype: float64
# --- prepare episodes for external_8122374.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.347518
# y___neg    0.581560
# y___ctm    0.000000
# y___pos    0.070922
# dtype: float64
# --- prepare episodes for external_7744410.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.345070
# y___neg    0.584507
# y___ctm    0.000000
# y___pos    0.070423
# dtype: float64
# --- prepare episodes for external_8177877.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.342657
# y___neg    0.580420
# y___ctm    0.006993
# y___pos    0.069930
# dtype: float64
# --- prepare episodes for external_9680181.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.333333
# y___neg    0.591837
# y___ctm    0.006803
# y___pos    0.068027
# dtype: float64
# --- prepare episodes for external_7841277.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.337662
# y___neg    0.584416
# y___ctm    0.006494
# y___pos    0.071429
# dtype: float64
# --- prepare episodes for external_9150417.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.335484
# y___neg    0.587097
# y___ctm    0.006452
# y___pos    0.070968
# dtype: float64
# --- prepare episodes for external_8794533.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.361963
# y___neg    0.564417
# y___ctm    0.006135
# y___pos    0.067485
# dtype: float64
# --- prepare episodes for external_8940654.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364706
# y___neg    0.564706
# y___ctm    0.005882
# y___pos    0.064706
# dtype: float64
# --- prepare episodes for external_7701288.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.362573
# y___neg    0.567251
# y___ctm    0.005848
# y___pos    0.064327
# dtype: float64
# --- prepare episodes for external_9686979.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359116
# y___neg    0.569061
# y___ctm    0.005525
# y___pos    0.066298
# dtype: float64
# --- prepare episodes for external_8495472.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360656
# y___neg    0.568306
# y___ctm    0.005464
# y___pos    0.065574
# dtype: float64
# --- prepare episodes for external_9115386.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358696
# y___neg    0.570652
# y___ctm    0.005435
# y___pos    0.065217
# dtype: float64
# --- prepare episodes for external_9146154.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360215
# y___neg    0.569892
# y___ctm    0.005376
# y___pos    0.064516
# dtype: float64
# --- prepare episodes for external_7835190.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358289
# y___neg    0.572193
# y___ctm    0.005348
# y___pos    0.064171
# dtype: float64
# --- prepare episodes for external_9144756.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.356383
# y___neg    0.569149
# y___ctm    0.010638
# y___pos    0.063830
# dtype: float64
# --- prepare episodes for external_7840896.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.354497
# y___neg    0.571429
# y___ctm    0.010582
# y___pos    0.063492
# dtype: float64
# --- prepare episodes for external_7735473.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.352632
# y___neg    0.573684
# y___ctm    0.010526
# y___pos    0.063158
# dtype: float64
# --- prepare episodes for external_8340696.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.368687
# y___neg    0.560606
# y___ctm    0.010101
# y___pos    0.060606
# dtype: float64
# --- prepare episodes for external_9084465.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.371287
# y___neg    0.549505
# y___ctm    0.009901
# y___pos    0.069307
# dtype: float64
# --- prepare episodes for external_8185671.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.370732
# y___neg    0.551220
# y___ctm    0.009756
# y___pos    0.068293
# dtype: float64
# --- prepare episodes for external_9430863.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.371429
# y___neg    0.552381
# y___ctm    0.009524
# y___pos    0.066667
# dtype: float64
# --- prepare episodes for external_9314259.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.367925
# y___neg    0.556604
# y___ctm    0.009434
# y___pos    0.066038
# dtype: float64
# --- prepare episodes for external_8178009.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.365741
# y___neg    0.555556
# y___ctm    0.009259
# y___pos    0.069444
# dtype: float64
# --- prepare episodes for external_8397069.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360731
# y___neg    0.561644
# y___ctm    0.009132
# y___pos    0.068493
# dtype: float64
# --- prepare episodes for external_8713215.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.361607
# y___neg    0.562500
# y___ctm    0.008929
# y___pos    0.066964
# dtype: float64
# --- prepare episodes for external_9243471.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360000
# y___neg    0.564444
# y___ctm    0.008889
# y___pos    0.066667
# dtype: float64
# --- prepare episodes for external_8637606.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.356828
# y___neg    0.568282
# y___ctm    0.008811
# y___pos    0.066079
# dtype: float64
# --- prepare episodes for external_8183046.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.356522
# y___neg    0.569565
# y___ctm    0.008696
# y___pos    0.065217
# dtype: float64
# --- prepare episodes for external_7855659.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.357759
# y___neg    0.568966
# y___ctm    0.008621
# y___pos    0.064655
# dtype: float64
# --- prepare episodes for external_8397462.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.356223
# y___neg    0.570815
# y___ctm    0.008584
# y___pos    0.064378
# dtype: float64
# --- prepare episodes for external_9080859.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.354701
# y___neg    0.572650
# y___ctm    0.008547
# y___pos    0.064103
# dtype: float64
# --- prepare episodes for external_9408747.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358333
# y___neg    0.570833
# y___ctm    0.008333
# y___pos    0.062500
# dtype: float64
# --- prepare episodes for external_27111063.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363265
# y___neg    0.567347
# y___ctm    0.008163
# y___pos    0.061224
# dtype: float64
# --- prepare episodes for external_7943439.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364372
# y___neg    0.566802
# y___ctm    0.008097
# y___pos    0.060729
# dtype: float64
# --- prepare episodes for external_8172069.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.361446
# y___neg    0.570281
# y___ctm    0.008032
# y___pos    0.060241
# dtype: float64
# --- prepare episodes for external_27107700.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.361111
# y___neg    0.571429
# y___ctm    0.007937
# y___pos    0.059524
# dtype: float64
# --- prepare episodes for external_8807424.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359684
# y___neg    0.573123
# y___ctm    0.007905
# y___pos    0.059289
# dtype: float64
# --- prepare episodes for external_9314583.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358268
# y___neg    0.574803
# y___ctm    0.007874
# y___pos    0.059055
# dtype: float64
# --- prepare episodes for external_9370155.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.355469
# y___neg    0.578125
# y___ctm    0.007812
# y___pos    0.058594
# dtype: float64
# --- prepare episodes for external_9146277.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.350000
# y___neg    0.584615
# y___ctm    0.007692
# y___pos    0.057692
# dtype: float64
# --- prepare episodes for external_8262480.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358209
# y___neg    0.578358
# y___ctm    0.007463
# y___pos    0.055970
# dtype: float64
# --- prepare episodes for external_7995744.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364621
# y___neg    0.566787
# y___ctm    0.007220
# y___pos    0.061372
# dtype: float64
# --- prepare episodes for external_8222235.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.375439
# y___neg    0.557895
# y___ctm    0.007018
# y___pos    0.059649
# dtype: float64
# --- prepare episodes for external_8913249.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.374126
# y___neg    0.559441
# y___ctm    0.006993
# y___pos    0.059441
# dtype: float64
# --- prepare episodes for external_9717660.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.382253
# y___neg    0.552901
# y___ctm    0.006826
# y___pos    0.058020
# dtype: float64
# --- prepare episodes for external_9154710.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.380952
# y___neg    0.554422
# y___ctm    0.006803
# y___pos    0.057823
# dtype: float64
# --- prepare episodes for external_8001294.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.378378
# y___neg    0.557432
# y___ctm    0.006757
# y___pos    0.057432
# dtype: float64
# --- prepare episodes for external_8082189.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.375839
# y___neg    0.557047
# y___ctm    0.006711
# y___pos    0.060403
# dtype: float64
# --- prepare episodes for external_9513654.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.370492
# y___neg    0.563934
# y___ctm    0.006557
# y___pos    0.059016
# dtype: float64
# --- prepare episodes for external_8036226.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.369281
# y___neg    0.565359
# y___ctm    0.006536
# y___pos    0.058824
# dtype: float64
# --- prepare episodes for external_7801656.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.368932
# y___neg    0.566343
# y___ctm    0.006472
# y___pos    0.058252
# dtype: float64
# --- prepare episodes for external_8795355.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.372611
# y___neg    0.563694
# y___ctm    0.006369
# y___pos    0.057325
# dtype: float64
# --- prepare episodes for external_8713119.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.374214
# y___neg    0.562893
# y___ctm    0.006289
# y___pos    0.056604
# dtype: float64
# --- prepare episodes for external_7825344.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.373041
# y___neg    0.564263
# y___ctm    0.006270
# y___pos    0.056426
# dtype: float64
# --- prepare episodes for external_8098500.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.372308
# y___neg    0.560000
# y___ctm    0.006154
# y___pos    0.061538
# dtype: float64
# --- prepare episodes for external_7973481.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.370031
# y___neg    0.562691
# y___ctm    0.006116
# y___pos    0.061162
# dtype: float64
# --- prepare episodes for external_9145713.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.371601
# y___neg    0.561934
# y___ctm    0.006042
# y___pos    0.060423
# dtype: float64
# --- prepare episodes for external_8009343.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.369369
# y___neg    0.564565
# y___ctm    0.006006
# y___pos    0.060060
# dtype: float64
# --- prepare episodes for external_7793688.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.367164
# y___neg    0.567164
# y___ctm    0.005970
# y___pos    0.059701
# dtype: float64
# --- prepare episodes for external_8224410.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.366071
# y___neg    0.568452
# y___ctm    0.005952
# y___pos    0.059524
# dtype: float64
# --- prepare episodes for external_9507936.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.366864
# y___neg    0.568047
# y___ctm    0.005917
# y___pos    0.059172
# dtype: float64
# --- prepare episodes for external_8351169.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.372832
# y___neg    0.560694
# y___ctm    0.005780
# y___pos    0.060694
# dtype: float64
# --- prepare episodes for external_7939569.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.372493
# y___neg    0.561605
# y___ctm    0.005731
# y___pos    0.060172
# dtype: float64
# --- prepare episodes for external_8913876.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.371429
# y___neg    0.562857
# y___ctm    0.005714
# y___pos    0.060000
# dtype: float64
# --- prepare episodes for external_8053953.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.370370
# y___neg    0.564103
# y___ctm    0.005698
# y___pos    0.059829
# dtype: float64
# --- prepare episodes for external_7862559.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.365922
# y___neg    0.567039
# y___ctm    0.005587
# y___pos    0.061453
# dtype: float64
# --- prepare episodes for external_8901468.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364903
# y___neg    0.568245
# y___ctm    0.005571
# y___pos    0.061281
# dtype: float64
# --- prepare episodes for external_9129663.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.366391
# y___neg    0.567493
# y___ctm    0.005510
# y___pos    0.060606
# dtype: float64
# --- prepare episodes for external_9342825.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.365385
# y___neg    0.568681
# y___ctm    0.005495
# y___pos    0.060440
# dtype: float64
# --- prepare episodes for external_7904649.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.365854
# y___neg    0.569106
# y___ctm    0.005420
# y___pos    0.059621
# dtype: float64
# --- prepare episodes for external_9662265.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363636
# y___neg    0.572193
# y___ctm    0.005348
# y___pos    0.058824
# dtype: float64
# --- prepare episodes for external_7696668.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.366755
# y___neg    0.569921
# y___ctm    0.005277
# y___pos    0.058047
# dtype: float64
# --- prepare episodes for external_8004669.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364829
# y___neg    0.572178
# y___ctm    0.005249
# y___pos    0.057743
# dtype: float64
# --- prepare episodes for external_8248593.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.361757
# y___neg    0.571059
# y___ctm    0.005168
# y___pos    0.062016
# dtype: float64
# --- prepare episodes for external_7701159.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360825
# y___neg    0.572165
# y___ctm    0.005155
# y___pos    0.061856
# dtype: float64
# --- prepare episodes for external_7928979.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359694
# y___neg    0.568878
# y___ctm    0.005102
# y___pos    0.066327
# dtype: float64
# --- prepare episodes for external_7914072.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.366748
# y___neg    0.564792
# y___ctm    0.004890
# y___pos    0.063570
# dtype: float64
# --- prepare episodes for external_8508687.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364078
# y___neg    0.567961
# y___ctm    0.004854
# y___pos    0.063107
# dtype: float64
# --- prepare episodes for external_7931838.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363196
# y___neg    0.569007
# y___ctm    0.004843
# y___pos    0.062954
# dtype: float64
# --- prepare episodes for external_7834821.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.361244
# y___neg    0.571770
# y___ctm    0.004785
# y___pos    0.062201
# dtype: float64
# --- prepare episodes for external_27111207.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360382
# y___neg    0.572792
# y___ctm    0.004773
# y___pos    0.062053
# dtype: float64
# --- prepare episodes for external_8001624.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359524
# y___neg    0.573810
# y___ctm    0.004762
# y___pos    0.061905
# dtype: float64
# --- prepare episodes for external_8934507.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358670
# y___neg    0.574822
# y___ctm    0.004751
# y___pos    0.061758
# dtype: float64
# --- prepare episodes for external_8065947.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.357820
# y___neg    0.575829
# y___ctm    0.004739
# y___pos    0.061611
# dtype: float64
# --- prepare episodes for external_8440344.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359155
# y___neg    0.575117
# y___ctm    0.004695
# y___pos    0.061033
# dtype: float64
# --- prepare episodes for external_8595111.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358974
# y___neg    0.575758
# y___ctm    0.004662
# y___pos    0.060606
# dtype: float64
# --- prepare episodes for external_8281095.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363218
# y___neg    0.572414
# y___ctm    0.004598
# y___pos    0.059770
# dtype: float64
# --- prepare episodes for external_9584238.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363844
# y___neg    0.572082
# y___ctm    0.004577
# y___pos    0.059497
# dtype: float64
# --- prepare episodes for external_9347664.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.362812
# y___neg    0.573696
# y___ctm    0.004535
# y___pos    0.058957
# dtype: float64
# --- prepare episodes for external_24017001.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364865
# y___neg    0.572072
# y___ctm    0.004505
# y___pos    0.058559
# dtype: float64
# --- prepare episodes for external_7976694.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364045
# y___neg    0.573034
# y___ctm    0.004494
# y___pos    0.058427
# dtype: float64
# --- prepare episodes for external_7991586.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.366071
# y___neg    0.571429
# y___ctm    0.004464
# y___pos    0.058036
# dtype: float64
# --- prepare episodes for external_8520648.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.366667
# y___neg    0.571111
# y___ctm    0.004444
# y___pos    0.057778
# dtype: float64
# --- prepare episodes for external_8108445.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.368653
# y___neg    0.569536
# y___ctm    0.004415
# y___pos    0.057395
# dtype: float64
# --- prepare episodes for external_8210571.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363834
# y___neg    0.575163
# y___ctm    0.004357
# y___pos    0.056645
# dtype: float64
# --- prepare episodes for external_8860389.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364224
# y___neg    0.575431
# y___ctm    0.004310
# y___pos    0.056034
# dtype: float64
# --- prepare episodes for external_9369807.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364807
# y___neg    0.572961
# y___ctm    0.004292
# y___pos    0.057940
# dtype: float64
# --- prepare episodes for external_8982675.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.367304
# y___neg    0.571125
# y___ctm    0.004246
# y___pos    0.057325
# dtype: float64
# --- prepare episodes for external_7788306.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.366525
# y___neg    0.569915
# y___ctm    0.004237
# y___pos    0.059322
# dtype: float64
# --- prepare episodes for external_8896761.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364979
# y___neg    0.571730
# y___ctm    0.004219
# y___pos    0.059072
# dtype: float64
# --- prepare episodes for external_7763100.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364211
# y___neg    0.572632
# y___ctm    0.004211
# y___pos    0.058947
# dtype: float64
# --- prepare episodes for external_8052597.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.362683
# y___neg    0.574423
# y___ctm    0.004193
# y___pos    0.058700
# dtype: float64
# --- prepare episodes for external_9363255.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.361925
# y___neg    0.575314
# y___ctm    0.004184
# y___pos    0.058577
# dtype: float64
# --- prepare episodes for external_8261046.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360417
# y___neg    0.577083
# y___ctm    0.004167
# y___pos    0.058333
# dtype: float64
# --- prepare episodes for external_7730346.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359667
# y___neg    0.577963
# y___ctm    0.004158
# y___pos    0.058212
# dtype: float64
# --- prepare episodes for external_9558594.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.356557
# y___neg    0.581967
# y___ctm    0.004098
# y___pos    0.057377
# dtype: float64
# --- prepare episodes for external_7896345.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.356415
# y___neg    0.582485
# y___ctm    0.004073
# y___pos    0.057026
# dtype: float64
# --- prepare episodes for external_7931667.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.355691
# y___neg    0.583333
# y___ctm    0.004065
# y___pos    0.056911
# dtype: float64
# --- prepare episodes for external_7890834.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.355556
# y___neg    0.583838
# y___ctm    0.004040
# y___pos    0.056566
# dtype: float64
# --- prepare episodes for external_9051309.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.354839
# y___neg    0.582661
# y___ctm    0.004032
# y___pos    0.058468
# dtype: float64
# --- prepare episodes for external_9236670.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360947
# y___neg    0.577909
# y___ctm    0.003945
# y___pos    0.057199
# dtype: float64
# --- prepare episodes for external_9037020.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.357422
# y___neg    0.582031
# y___ctm    0.003906
# y___pos    0.056641
# dtype: float64
# --- prepare episodes for external_9360573.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.356031
# y___neg    0.583658
# y___ctm    0.003891
# y___pos    0.056420
# dtype: float64
# --- prepare episodes for external_8550495.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.354651
# y___neg    0.585271
# y___ctm    0.003876
# y___pos    0.056202
# dtype: float64
# --- prepare episodes for external_8911008.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.353965
# y___neg    0.584139
# y___ctm    0.003868
# y___pos    0.058027
# dtype: float64
# --- prepare episodes for external_8077683.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.352601
# y___neg    0.585742
# y___ctm    0.003854
# y___pos    0.057803
# dtype: float64
# --- prepare episodes for external_8033535.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.352490
# y___neg    0.586207
# y___ctm    0.003831
# y___pos    0.057471
# dtype: float64
# --- prepare episodes for external_8637279.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.352381
# y___neg    0.586667
# y___ctm    0.003810
# y___pos    0.057143
# dtype: float64
# --- prepare episodes for external_9139584.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.351711
# y___neg    0.585551
# y___ctm    0.003802
# y___pos    0.058935
# dtype: float64
# --- prepare episodes for external_9688302.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.351044
# y___neg    0.586338
# y___ctm    0.003795
# y___pos    0.058824
# dtype: float64
# --- prepare episodes for external_8514036.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.349716
# y___neg    0.587902
# y___ctm    0.003781
# y___pos    0.058601
# dtype: float64
# --- prepare episodes for external_8901501.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.348399
# y___neg    0.589454
# y___ctm    0.003766
# y___pos    0.058380
# dtype: float64
# --- prepare episodes for external_9100167.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.347744
# y___neg    0.588346
# y___ctm    0.003759
# y___pos    0.060150
# dtype: float64
# --- prepare episodes for external_7912386.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.352190
# y___neg    0.585766
# y___ctm    0.003650
# y___pos    0.058394
# dtype: float64
# --- prepare episodes for external_8228127.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.354204
# y___neg    0.584973
# y___ctm    0.003578
# y___pos    0.057245
# dtype: float64
# --- prepare episodes for external_7862418.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.353571
# y___neg    0.585714
# y___ctm    0.003571
# y___pos    0.057143
# dtype: float64
# --- prepare episodes for external_7860258.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.355752
# y___neg    0.584071
# y___ctm    0.003540
# y___pos    0.056637
# dtype: float64
# --- prepare episodes for external_9653604.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.356766
# y___neg    0.583480
# y___ctm    0.003515
# y___pos    0.056239
# dtype: float64
# --- prepare episodes for external_9034170.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.357388
# y___neg    0.584192
# y___ctm    0.003436
# y___pos    0.054983
# dtype: float64
# --- prepare episodes for external_8725167.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363328
# y___neg    0.578947
# y___ctm    0.003396
# y___pos    0.054329
# dtype: float64
# --- prepare episodes for external_7764354.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.362712
# y___neg    0.579661
# y___ctm    0.003390
# y___pos    0.054237
# dtype: float64
# --- prepare episodes for external_9207234.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360877
# y___neg    0.581788
# y___ctm    0.003373
# y___pos    0.053963
# dtype: float64
# --- prepare episodes for external_8728428.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360269
# y___neg    0.580808
# y___ctm    0.003367
# y___pos    0.055556
# dtype: float64
# --- prepare episodes for external_7913307.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359664
# y___neg    0.581513
# y___ctm    0.003361
# y___pos    0.055462
# dtype: float64
# --- prepare episodes for external_27109590.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360465
# y___neg    0.581395
# y___ctm    0.003322
# y___pos    0.054817
# dtype: float64
# --- prepare episodes for external_9088812.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360331
# y___neg    0.581818
# y___ctm    0.003306
# y___pos    0.054545
# dtype: float64
# --- prepare episodes for external_7998684.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360656
# y___neg    0.581967
# y___ctm    0.003279
# y___pos    0.054098
# dtype: float64
# --- prepare episodes for external_9572787.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360065
# y___neg    0.582651
# y___ctm    0.003273
# y___pos    0.054010
# dtype: float64
# --- prepare episodes for external_9050964.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359477
# y___neg    0.581699
# y___ctm    0.003268
# y___pos    0.055556
# dtype: float64
# --- prepare episodes for external_9479919.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358521
# y___neg    0.583601
# y___ctm    0.003215
# y___pos    0.054662
# dtype: float64
# --- prepare episodes for external_7691064.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.3584
# y___neg    0.5840
# y___ctm    0.0032
# y___pos    0.0544
# dtype: float64
# --- prepare episodes for external_8404386.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.357827
# y___neg    0.584665
# y___ctm    0.003195
# y___pos    0.054313
# dtype: float64
# --- prepare episodes for external_9117204.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.356688
# y___neg    0.585987
# y___ctm    0.003185
# y___pos    0.054140
# dtype: float64
# --- prepare episodes for external_8110176.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.361502
# y___neg    0.582160
# y___ctm    0.003130
# y___pos    0.053208
# dtype: float64
# --- prepare episodes for external_8725635.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360938
# y___neg    0.582812
# y___ctm    0.003125
# y___pos    0.053125
# dtype: float64
# --- prepare episodes for external_7915575.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359813
# y___neg    0.584112
# y___ctm    0.003115
# y___pos    0.052960
# dtype: float64
# --- prepare episodes for external_7962828.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.361111
# y___neg    0.580247
# y___ctm    0.003086
# y___pos    0.055556
# dtype: float64
# --- prepare episodes for external_8759634.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360000
# y___neg    0.581538
# y___ctm    0.003077
# y___pos    0.055385
# dtype: float64
# --- prepare episodes for external_7826046.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359447
# y___neg    0.582181
# y___ctm    0.003072
# y___pos    0.055300
# dtype: float64
# --- prepare episodes for external_7917510.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359877
# y___neg    0.581930
# y___ctm    0.003063
# y___pos    0.055130
# dtype: float64
# --- prepare episodes for external_8002275.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359327
# y___neg    0.582569
# y___ctm    0.003058
# y___pos    0.055046
# dtype: float64
# --- prepare episodes for external_8015523.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359209
# y___neg    0.582953
# y___ctm    0.003044
# y___pos    0.054795
# dtype: float64
# --- prepare episodes for external_9756042.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.364179
# y___neg    0.579104
# y___ctm    0.002985
# y___pos    0.053731
# dtype: float64
# --- prepare episodes for external_8328564.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363636
# y___neg    0.579732
# y___ctm    0.002981
# y___pos    0.053651
# dtype: float64
# --- prepare episodes for external_7996932.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.363095
# y___neg    0.580357
# y___ctm    0.002976
# y___pos    0.053571
# dtype: float64
# --- prepare episodes for external_9447228.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.362018
# y___neg    0.581602
# y___ctm    0.002967
# y___pos    0.053412
# dtype: float64
# --- prepare episodes for external_9768546.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.360947
# y___neg    0.582840
# y___ctm    0.002959
# y___pos    0.053254
# dtype: float64
# --- prepare episodes for external_8052927.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359882
# y___neg    0.584071
# y___ctm    0.002950
# y___pos    0.053097
# dtype: float64
# --- prepare episodes for external_9385800.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.359352
# y___neg    0.584683
# y___ctm    0.002946
# y___pos    0.053019
# dtype: float64
# --- prepare episodes for external_9332070.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.357771
# y___neg    0.586510
# y___ctm    0.002933
# y___pos    0.052786
# dtype: float64
# --- prepare episodes for external_8510229.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.356204
# y___neg    0.586861
# y___ctm    0.004380
# y___pos    0.052555
# dtype: float64
# --- prepare episodes for external_9586986.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.355167
# y___neg    0.588064
# y___ctm    0.004367
# y___pos    0.052402
# dtype: float64
# --- prepare episodes for external_7693113.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358680
# y___neg    0.585366
# y___ctm    0.004304
# y___pos    0.051650
# dtype: float64
# --- prepare episodes for external_7725054.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358166
# y___neg    0.585960
# y___ctm    0.004298
# y___pos    0.051576
# dtype: float64
# --- prepare episodes for external_8061402.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358571
# y___neg    0.585714
# y___ctm    0.004286
# y___pos    0.051429
# dtype: float64
# --- prepare episodes for external_7742454.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.357550
# y___neg    0.586895
# y___ctm    0.004274
# y___pos    0.051282
# dtype: float64
# --- prepare episodes for external_7889766.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.357041
# y___neg    0.587482
# y___ctm    0.004267
# y___pos    0.051209
# dtype: float64
# --- prepare episodes for external_8031255.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358757
# y___neg    0.586158
# y___ctm    0.004237
# y___pos    0.050847
# dtype: float64
# --- prepare episodes for external_8313360.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.358251
# y___neg    0.586742
# y___ctm    0.004231
# y___pos    0.050776
# dtype: float64
# ...
# y___nbc    0.393632
# y___neg    0.558611
# y___ctm    0.003618
# y___pos    0.044139
# dtype: float64
# --- prepare episodes for external_7995354.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.395533
# y___neg    0.556916
# y___ctm    0.003602
# y___pos    0.043948
# dtype: float64
# --- prepare episodes for external_7821438.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.395833
# y___neg    0.556753
# y___ctm    0.003592
# y___pos    0.043822
# dtype: float64
# --- prepare episodes for external_9332250.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.395549
# y___neg    0.557071
# y___ctm    0.003589
# y___pos    0.043790
# dtype: float64
# --- prepare episodes for external_7959897.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.394982
# y___neg    0.557706
# y___ctm    0.003584
# y___pos    0.043728
# dtype: float64
# --- prepare episodes for external_8342241.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.394417
# y___neg    0.558339
# y___ctm    0.003579
# y___pos    0.043665
# dtype: float64
# --- prepare episodes for external_8454057.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.394568
# y___neg    0.558256
# y___ctm    0.003574
# y___pos    0.043603
# dtype: float64
# --- prepare episodes for external_9406152.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.393723
# y___neg    0.558488
# y___ctm    0.003566
# y___pos    0.044223
# dtype: float64
# --- prepare episodes for external_9404205.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.393875
# y___neg    0.558405
# y___ctm    0.003561
# y___pos    0.044160
# dtype: float64
# --- prepare episodes for external_27111411.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.394026
# y___neg    0.558321
# y___ctm    0.003556
# y___pos    0.044097
# dtype: float64
# --- prepare episodes for external_9191202.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.393896
# y___neg    0.557133
# y___ctm    0.003549
# y___pos    0.045422
# dtype: float64
# --- prepare episodes for external_8572278.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.393768
# y___neg    0.556657
# y___ctm    0.003541
# y___pos    0.046034
# dtype: float64
# --- prepare episodes for external_8212863.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.393512
# y___neg    0.557123
# y___ctm    0.003526
# y___pos    0.045839
# dtype: float64
# --- prepare episodes for external_8715420.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.393235
# y___neg    0.557435
# y___ctm    0.003524
# y___pos    0.045807
# dtype: float64
# --- prepare episodes for external_27108264.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.392405
# y___neg    0.557665
# y___ctm    0.003516
# y___pos    0.046414
# dtype: float64
# --- prepare episodes for external_9215517.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.392006
# y___neg    0.557504
# y___ctm    0.004208
# y___pos    0.046283
# dtype: float64
# --- prepare episodes for external_9340440.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.391882
# y___neg    0.557733
# y___ctm    0.004199
# y___pos    0.046186
# dtype: float64
# --- prepare episodes for external_9579864.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.389701
# y___neg    0.560195
# y___ctm    0.004175
# y___pos    0.045929
# dtype: float64
# --- prepare episodes for external_7809387.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.390311
# y___neg    0.559862
# y___ctm    0.004152
# y___pos    0.045675
# dtype: float64
# --- prepare episodes for external_7772397.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.390614
# y___neg    0.559696
# y___ctm    0.004141
# y___pos    0.045549
# dtype: float64
# --- prepare episodes for external_8224212.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.390345
# y___neg    0.560000
# y___ctm    0.004138
# y___pos    0.045517
# dtype: float64
# --- prepare episodes for external_8084679.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.391065
# y___neg    0.559450
# y___ctm    0.004124
# y___pos    0.045361
# dtype: float64
# --- prepare episodes for external_9370680.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.390528
# y___neg    0.560055
# y___ctm    0.004118
# y___pos    0.045299
# dtype: float64
# --- prepare episodes for external_9448635.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.390977
# y___neg    0.559809
# y___ctm    0.004101
# y___pos    0.045113
# dtype: float64
# --- prepare episodes for external_8971710.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.390710
# y___neg    0.560109
# y___ctm    0.004098
# y___pos    0.045082
# dtype: float64
# --- prepare episodes for external_8797095.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.390177
# y___neg    0.560709
# y___ctm    0.004093
# y___pos    0.045020
# dtype: float64
# --- prepare episodes for external_7727892.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.389911
# y___neg    0.561009
# y___ctm    0.004090
# y___pos    0.044990
# dtype: float64
# --- prepare episodes for external_8327706.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.389646
# y___neg    0.560627
# y___ctm    0.004087
# y___pos    0.045640
# dtype: float64
# --- prepare episodes for external_9424785.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.389381
# y___neg    0.560926
# y___ctm    0.004084
# y___pos    0.045609
# dtype: float64
# --- prepare episodes for external_8839113.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.389531
# y___neg    0.560843
# y___ctm    0.004079
# y___pos    0.045547
# dtype: float64
# --- prepare episodes for external_8370129.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.389002
# y___neg    0.561439
# y___ctm    0.004073
# y___pos    0.045485
# dtype: float64
# --- prepare episodes for external_9676809.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.388475
# y___neg    0.562034
# y___ctm    0.004068
# y___pos    0.045424
# dtype: float64
# --- prepare episodes for external_8368662.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.388211
# y___neg    0.562331
# y___ctm    0.004065
# y___pos    0.045393
# dtype: float64
# --- prepare episodes for external_27111720.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387424
# y___neg    0.562542
# y___ctm    0.004057
# y___pos    0.045977
# dtype: float64
# --- prepare episodes for external_8477391.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387314
# y___neg    0.562753
# y___ctm    0.004049
# y___pos    0.045884
# dtype: float64
# --- prepare episodes for external_8502090.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387205
# y___neg    0.562963
# y___ctm    0.004040
# y___pos    0.045791
# dtype: float64
# --- prepare episodes for external_8257107.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.388220
# y___neg    0.562249
# y___ctm    0.004016
# y___pos    0.045515
# dtype: float64
# --- prepare episodes for external_9332046.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387960
# y___neg    0.562542
# y___ctm    0.004013
# y___pos    0.045485
# dtype: float64
# --- prepare episodes for external_7842939.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.388259
# y___neg    0.562375
# y___ctm    0.004003
# y___pos    0.045364
# dtype: float64
# --- prepare episodes for external_8017596.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.388040
# y___neg    0.562791
# y___ctm    0.003987
# y___pos    0.045183
# dtype: float64
# --- prepare episodes for external_9045630.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387782
# y___neg    0.563081
# y___ctm    0.003984
# y___pos    0.045153
# dtype: float64
# --- prepare episodes for external_8237667.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387417
# y___neg    0.562914
# y___ctm    0.003974
# y___pos    0.045695
# dtype: float64
# --- prepare episodes for external_8937198.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387566
# y___neg    0.562831
# y___ctm    0.003968
# y___pos    0.045635
# dtype: float64
# --- prepare episodes for external_8193561.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387310
# y___neg    0.563120
# y___ctm    0.003966
# y___pos    0.045605
# dtype: float64
# --- prepare episodes for external_8079162.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387755
# y___neg    0.562212
# y___ctm    0.004608
# y___pos    0.045425
# dtype: float64
# --- prepare episodes for external_8219349.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387245
# y___neg    0.562788
# y___ctm    0.004602
# y___pos    0.045365
# dtype: float64
# --- prepare episodes for external_7833162.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.386991
# y___neg    0.563075
# y___ctm    0.004599
# y___pos    0.045335
# dtype: float64
# --- prepare episodes for external_8716767.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387139
# y___neg    0.562992
# y___ctm    0.004593
# y___pos    0.045276
# dtype: float64
# --- prepare episodes for external_9544095.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.386885
# y___neg    0.563279
# y___ctm    0.004590
# y___pos    0.045246
# dtype: float64
# --- prepare episodes for external_8426961.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.386379
# y___neg    0.563851
# y___ctm    0.004584
# y___pos    0.045187
# dtype: float64
# --- prepare episodes for external_7741503.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.385873
# y___neg    0.564421
# y___ctm    0.004578
# y___pos    0.045128
# dtype: float64
# --- prepare episodes for external_7801536.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.385642
# y___neg    0.564168
# y___ctm    0.005718
# y___pos    0.044473
# dtype: float64
# --- prepare episodes for external_8953452.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.385397
# y___neg    0.564444
# y___ctm    0.005714
# y___pos    0.044444
# dtype: float64
# --- prepare episodes for external_8090406.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.384421
# y___neg    0.565548
# y___ctm    0.005700
# y___pos    0.044332
# dtype: float64
# --- prepare episodes for external_8470278.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.385344
# y___neg    0.564750
# y___ctm    0.005685
# y___pos    0.044220
# dtype: float64
# --- prepare episodes for external_9607653.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.385633
# y___neg    0.564587
# y___ctm    0.005671
# y___pos    0.044108
# dtype: float64
# --- prepare episodes for external_8103492.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.386692
# y___neg    0.563716
# y___ctm    0.005650
# y___pos    0.043942
# dtype: float64
# --- prepare episodes for external_27111432.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.386591
# y___neg    0.563910
# y___ctm    0.005639
# y___pos    0.043860
# dtype: float64
# --- prepare episodes for external_7865274.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.386349
# y___neg    0.564183
# y___ctm    0.005636
# y___pos    0.043832
# dtype: float64
# --- prepare episodes for external_8455875.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.385866
# y___neg    0.564728
# y___ctm    0.005629
# y___pos    0.043777
# dtype: float64
# --- prepare episodes for external_7906719.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.384663
# y___neg    0.566085
# y___ctm    0.005611
# y___pos    0.043641
# dtype: float64
# --- prepare episodes for external_9048285.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387276
# y___neg    0.563928
# y___ctm    0.005559
# y___pos    0.043237
# dtype: float64
# --- prepare episodes for external_7700685.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.386700
# y___neg    0.564655
# y___ctm    0.005542
# y___pos    0.043103
# dtype: float64
# --- prepare episodes for external_8341458.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.385176
# y___neg    0.566221
# y___ctm    0.005468
# y___pos    0.043135
# dtype: float64
# --- prepare episodes for external_8389128.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.384475
# y___neg    0.567010
# y___ctm    0.005458
# y___pos    0.043056
# dtype: float64
# --- prepare episodes for external_8663421.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.384615
# y___neg    0.566929
# y___ctm    0.005451
# y___pos    0.043004
# dtype: float64
# --- prepare episodes for external_7827798.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.385266
# y___neg    0.566425
# y___ctm    0.005435
# y___pos    0.042874
# dtype: float64
# --- prepare episodes for external_9078234.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.386514
# y___neg    0.565322
# y___ctm    0.005418
# y___pos    0.042745
# dtype: float64
# --- prepare episodes for external_7970115.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.386282
# y___neg    0.565584
# y___ctm    0.005415
# y___pos    0.042720
# dtype: float64
# --- prepare episodes for external_7999902.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.386691
# y___neg    0.565348
# y___ctm    0.005396
# y___pos    0.042566
# dtype: float64
# --- prepare episodes for external_9320226.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387962
# y___neg    0.563766
# y___ctm    0.005364
# y___pos    0.042908
# dtype: float64
# --- prepare episodes for external_8734209.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.387731
# y___neg    0.563431
# y___ctm    0.005360
# y___pos    0.043478
# dtype: float64
# --- prepare episodes for external_7719381.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.388724
# y___neg    0.562611
# y___ctm    0.005341
# y___pos    0.043323
# dtype: float64
# --- prepare episodes for external_8126430.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.388493
# y___neg    0.562871
# y___ctm    0.005338
# y___pos    0.043298
# dtype: float64
# --- prepare episodes for external_9492342.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.388988
# y___neg    0.562463
# y___ctm    0.005329
# y___pos    0.043221
# dtype: float64
# --- prepare episodes for external_8221767.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.388757
# y___neg    0.562722
# y___ctm    0.005325
# y___pos    0.043195
# dtype: float64
# --- prepare episodes for external_8012763.0
# Success! Output/responce variable mean in current sample space  ---
# y___nbc    0.389741
# y___neg    0.561910
# y___ctm    0.005307
# y___pos    0.043042
# dtype: float64
# --- prepare episodes for external_7787136.0

# %%
all_df_new = pd.concat( [bsi_stream.engineer.train_df, bsi_stream.engineer.valid_df], axis=0)
all_df_new = pd.concat( [all_df_new, bsi_stream.engineer.test_df], axis=0)
print(all_df_new.groupby(['txp___yes'])['__uid'].nunique())
if all_df is None:
    all_df = all_df_new
else:
    all_df = pd.concat( [all_df, all_df_new], axis=0)
print(len(set(all_df.__uid)))
# Out:
# txp___yes
# 0.0    1969
# 1.0      31
# Name: __uid, dtype: int64
# 7216

# %%
all_df.to_csv("./data_bsi_txp_4d_17_21_bc.csv",index=False)

# %%
all_df = pd.read_csv("./data_bsi_txp_4d_17_21_bc.csv")
all_df_add = pd.read_csv("./data_bsi_txp_4d_17_21_nbc_add.csv")

# %%
all_df_nbc = pd.concat([all_df, all_df_add],axis=0, sort=False)
all_df_nbc.to_csv("./data_bsi_txp_4d_17_21_nbc.csv",index=False)

# %%
all_df_nbc.shape
# Out:
# (3294432, 57)

# %%
all_df.__ep_relative_time.describe()
# Out:
# count    1.757472e+06
# mean    -3.000000e+01
# std      1.662679e+03
# min     -2.880000e+03
# 25%     -1.455000e+03
# 50%     -3.000000e+01
# 75%      1.395000e+03
# max      2.820000e+03
# Name: __ep_relative_time, dtype: float64

# %%
all_df_add.__ep_relative_time.describe()
# Out:
# count    1.536960e+06
# mean    -3.000000e+01
# std      1.662679e+03
# min     -2.880000e+03
# 25%     -1.455000e+03
# 50%     -3.000000e+01
# 75%      1.395000e+03
# max      2.820000e+03
# Name: __ep_relative_time, dtype: float64

# %%
## bc group 
bsi_stream.engineer.DefineEpisode(input_time_len=2*24*60, # using vital signs and labs 4 days prior to a culture 
                                  output_time_len=2*24*60, # predict one time unit into the future
                                  time_resolution=60, # aggregate minutely data to one row per hour 
                                  time_lag=0,  # no time lag between predictors and response
                                  anchor_gap=7*24*60) # the minimum distance between two episodes
# Out:
# Success! Engineer has updated attributes --- episode.

# %%
# Build MVTS dataframe or tfds  (notice that the engineer now has new attributes)
bsi_stream.engineer.BuildMVTS(csv_pool_path, 
                              nsbj = 50, # number of subjects / patients to sample from the pool 
                              replace = False, # sample with replacement or not 
                              valid_frac = 0.2, # fraction of number of subjects in validation dataset
                              test_frac = 0.1, # fraction of number of subjects in left-out test dataset
                              batch_size = 64, # batch size (usually 32,64,128..)
                              impute_input='none', # imputation on predictors
                              impute_output='none',# imputation on response (no need in BSI project)
                              sep="_", 
                              return_episode=True)
# Out:
# Engineer is sampling without replacement ---
# 50---out of---9954---subjects are sampled from csv pool of size---61865
# -- __time fixed
# -- __anchor fixed
# -- y fixed
# --- fix upper boundary for age by 90.0
# --- fix lower boundary for age by 19.92191
# -- age fixed
# --- fix upper boundary for albumin by 4.9
# --- fix lower boundary for albumin by 1.3
# -- albumin fixed
# --- fix upper boundary for alp by 800.0
# --- fix lower boundary for alp by 26.0
# -- alp fixed
# --- fix upper boundary for alt by 547.0
# --- fix lower boundary for alt by 7.0
# -- alt fixed
# --- fix upper boundary for ast by 1053.0
# --- fix lower boundary for ast by 11.0
# -- ast fixed
# --- fix upper boundary for bicarbonate by 60.0
# --- fix lower boundary for bicarbonate by 7.9
# -- bicarbonate fixed
# --- fix upper boundary for bun by 121.0
# --- fix lower boundary for bun by 3.0
# -- bun fixed
# --- fix upper boundary for calcium by 10.5
# --- fix lower boundary for calcium by 5.9
# -- calcium fixed
# --- fix upper boundary for chloride by 125.0
# --- fix lower boundary for chloride by 84.0
# -- chloride fixed
# --- fix upper boundary for co2 by 40.0
# --- fix lower boundary for co2 by 5.0
# -- co2 fixed
# --- fix upper boundary for creatinine by 5.7
# --- fix lower boundary for creatinine by 0.4
# -- creatinine fixed
# --- fix upper boundary for dbp by 150.0
# --- fix lower boundary for dbp by 20.0
# -- dbp fixed
# --- fix upper boundary for fio2_pct by 100.0
# --- fix lower boundary for fio2_pct by 21.0
# -- fio2_pct fixed
# --- fix upper boundary for glucose by 500.0
# --- fix lower boundary for glucose by 49.0
# -- glucose fixed
# --- fix upper boundary for hematocrit by 58.0
# --- fix lower boundary for hematocrit by 19.9
# -- hematocrit fixed
# --- fix upper boundary for hemoglobin by 19.7
# --- fix lower boundary for hemoglobin by 6.3
# -- hemoglobin fixed
# --- fix upper boundary for heart_rate by 162.3547
# --- fix lower boundary for heart_rate by 43.00333
# -- heart_rate fixed
# --- fix upper boundary for lactic_acid by 12.7
# --- fix lower boundary for lactic_acid by 0.5
# -- lactic_acid fixed
# --- fix upper boundary for magnesium by 3.1
# --- fix lower boundary for magnesium by 1.0
# -- magnesium fixed
# --- fix upper boundary for o2_flow by 80.0
# --- fix lower boundary for o2_flow by 0.0
# -- o2_flow fixed
# --- fix upper boundary for pco2 by 110.0
# --- fix lower boundary for pco2 by 18.0
# -- pco2 fixed
# --- fix upper boundary for peep by 18.0
# --- fix lower boundary for peep by 0.0
# -- peep fixed
# --- fix upper boundary for ph_arterial by 7.629
# --- fix lower boundary for ph_arterial by 6.827000000000001
# -- ph_arterial fixed
# --- fix upper boundary for phosphorus by 8.0
# --- fix lower boundary for phosphorus by 1.0
# -- phosphorus fixed
# --- fix upper boundary for po2 by 537.4
# --- fix lower boundary for po2 by 23.0
# -- po2 fixed
# --- fix upper boundary for potassium by 6.89
# --- fix lower boundary for potassium by 1.94
# -- potassium fixed
# --- fix upper boundary for protime_inr by 4.8
# --- fix lower boundary for protime_inr by 0.8
# -- protime_inr fixed
# --- fix upper boundary for ptt by 120.0
# --- fix lower boundary for ptt by 20.2
# -- ptt fixed
# --- fix upper boundary for platelet_count by 742.0
# --- fix lower boundary for platelet_count by 19.0
# -- platelet_count fixed
# --- fix upper boundary for resp_rate by 70.0
# --- fix lower boundary for resp_rate by 5.704498
# -- resp_rate fixed
# --- fix upper boundary for sbp by 219.0
# --- fix lower boundary for sbp by 40.0
# -- sbp fixed
# --- fix upper boundary for sodium by 156.0
# --- fix lower boundary for sodium by 121.8
# -- sodium fixed
# --- fix upper boundary for spo2 by 100.0
# --- fix lower boundary for spo2 by 79.0
# -- spo2 fixed
# --- fix upper boundary for temp by 104.0
# --- fix lower boundary for temp by 85.8
# -- temp fixed
# --- fix upper boundary for total_bilirubin by 7.4
# --- fix lower boundary for total_bilirubin by 0.2
# -- total_bilirubin fixed
# --- fix upper boundary for total_protein by 8.8
# --- fix lower boundary for total_protein by 3.7
# -- total_protein fixed
# -- txp fixed
# --- fix upper boundary for troponin by 0.89
# --- fix lower boundary for troponin by 0.02
# -- troponin fixed
# --- fix upper boundary for wbc by 50.0
# --- fix lower boundary for wbc by 0.34
# -- wbc fixed
# --- fix out-of-dictionry level/orders ['nan'] with ['no']
# -- gram_positive fixed
# --- fix out-of-dictionry level/orders ['nan'] with ['no']
# -- gram_negative fixed
# --- fix out-of-dictionry level/orders ['nan'] with ['no']
# -- fungus fixed
# --- fix out-of-dictionry level/orders ['nan'] with ['no']
# -- mycobacterial fixed
# --- prepare episodes for uvaold_10393163
# Success! Output/responce variable mean in current sample space  ---
# y___neg    1.0
# y___nbc    0.0
# y___pos    0.0
# dtype: float64
# --- prepare episodes for uvaold_10978758
# /Users/jiaxingqiu/Documents/FAIRStream/FAIRStream/Functions/make_episodes_ts.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upper_anchors['__ep_order']=upper_anchors.__time_bin//(anchor_gap//time_resolution)
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.25
# y___nbc    0.75
# y___pos    0.00
# dtype: float64
# --- prepare episodes for uvaold_10656658
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.2
# y___nbc    0.8
# y___pos    0.0
# dtype: float64
# --- prepare episodes for uvaold_9725657
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.142857
# y___nbc    0.857143
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_7547598
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.210526
# y___nbc    0.789474
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_8435695
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.25
# y___nbc    0.75
# y___pos    0.00
# dtype: float64
# --- prepare episodes for uvaold_10079406
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.272727
# y___nbc    0.727273
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_10359711
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.304348
# y___nbc    0.695652
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_6060250
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.291667
# y___nbc    0.708333
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_6855033
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.28
# y___nbc    0.72
# y___pos    0.00
# dtype: float64
# --- prepare episodes for uvaold_5984467
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.269231
# y___nbc    0.730769
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_9130682
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.25
# y___nbc    0.75
# y___pos    0.00
# dtype: float64
# --- prepare episodes for uvaold_5174625
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.275862
# y___nbc    0.724138
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_6009768
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.266667
# y___nbc    0.733333
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_6613420
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.272727
# y___nbc    0.727273
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_6789481
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.264706
# y___nbc    0.735294
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_8485104
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.285714
# y___nbc    0.714286
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_6543505
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.277778
# y___nbc    0.722222
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_8693912
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.315789
# y___nbc    0.684211
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_11416846
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.341463
# y___nbc    0.658537
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_11369473
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.333333
# y___nbc    0.666667
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_4477629
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.325581
# y___nbc    0.674419
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_9689064
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.311111
# y___nbc    0.688889
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_5557453
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.340426
# y___nbc    0.659574
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_8704581
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.333333
# y___nbc    0.666667
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_9428277
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.346939
# y___nbc    0.653061
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_7373283
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.36
# y___nbc    0.64
# y___pos    0.00
# dtype: float64
# --- prepare episodes for uvaold_5093688
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.352941
# y___nbc    0.647059
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_6595429
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.365385
# y___nbc    0.634615
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_7793705
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.351852
# y___nbc    0.648148
# y___pos    0.000000
# dtype: float64
# --- prepare episodes for uvaold_9911169
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.339286
# y___nbc    0.642857
# y___pos    0.017857
# dtype: float64
# --- prepare episodes for uvaold_7582507
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.327586
# y___nbc    0.655172
# y___pos    0.017241
# dtype: float64
# --- prepare episodes for uvaold_7896011
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.338983
# y___nbc    0.644068
# y___pos    0.016949
# dtype: float64
# --- prepare episodes for uvaold_8932061
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.333333
# y___nbc    0.650000
# y___pos    0.016667
# dtype: float64
# --- prepare episodes for uvaold_5374672
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.327869
# y___nbc    0.655738
# y___pos    0.016393
# dtype: float64
# --- prepare episodes for uvaold_11651966
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.333333
# y___nbc    0.650794
# y___pos    0.015873
# dtype: float64
# --- prepare episodes for uvaold_8421769
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.348485
# y___nbc    0.636364
# y___pos    0.015152
# dtype: float64
# --- prepare episodes for uvaold_10403266
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.358209
# y___nbc    0.626866
# y___pos    0.014925
# dtype: float64
# --- prepare episodes for uvaold_9141621
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.367647
# y___nbc    0.617647
# y___pos    0.014706
# dtype: float64
# --- prepare episodes for uvaold_10087723
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.371429
# y___nbc    0.614286
# y___pos    0.014286
# dtype: float64
# --- prepare episodes for uvaold_7955669
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.366197
# y___nbc    0.619718
# y___pos    0.014085
# dtype: float64
# --- prepare episodes for uvaold_9391005
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.361111
# y___nbc    0.611111
# y___pos    0.027778
# dtype: float64
# --- prepare episodes for uvaold_11555467
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.356164
# y___nbc    0.602740
# y___pos    0.041096
# dtype: float64
# --- prepare episodes for uvaold_6613443
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.364865
# y___nbc    0.594595
# y___pos    0.040541
# dtype: float64
# --- prepare episodes for uvaold_11083058
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.3500
# y___nbc    0.6125
# y___pos    0.0375
# dtype: float64
# --- prepare episodes for uvaold_7137982
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.345679
# y___nbc    0.604938
# y___pos    0.049383
# dtype: float64
# --- prepare episodes for uvaold_6250721
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.341463
# y___nbc    0.609756
# y___pos    0.048780
# dtype: float64
# --- prepare episodes for uvaold_5205748
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.345238
# y___nbc    0.607143
# y___pos    0.047619
# dtype: float64
# --- prepare episodes for uvaold_8010837
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.341176
# y___nbc    0.611765
# y___pos    0.047059
# dtype: float64
# --- prepare episodes for uvaold_9218930
# Success! Output/responce variable mean in current sample space  ---
# y___neg    0.337209
# y___nbc    0.616279
# y___pos    0.046512
# dtype: float64
# Success! Engineer has updated attributes --- mvts_df, input_vars, output_vars, input_vars_byside, output_vars_byside.
# Success! Engineer has updated attributes --- train_df, valid_df and test_df.
# Using 'mask' for predictor imputation (constant value -333) because too few subjects are sampled.
# Using 'mode' for response imputation because too few subjects are sampled.
# Success! Engineer has updated attributes --- train_df_imputed, valid_df_imputed and test_df_imputed.
# Success! Engineer has updated attributes --- train_tfds, valid_tfds and test_tfds.

# %%
all_df.to_csv("./data_bsi_txp_4d_17_21_bc.csv",index=False)

# %%
# nbc
#all_df.to_csv("./data_bsi_txp_4d_nbc.csv",index=False)
# bc
#all_df.to_csv("./data_bsi_txp_4d_bc.csv",index=False)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', 500)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

import FAIRStream

# %%
# csv pool folder directory
csv_pool_path = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/csv_pool'
# current experiment working directory
work_dir = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case_txp'

# %%
# initiate a FAIRStream object instance for BSI project
bsi_stream = FAIRStream.FAIRStream(work_dir)
# take a look at dictionaries in engineer's hands
#bsi_stream.engineer.csv_source_dict
bsi_stream.engineer.variable_dict

# %%
# define an episode (notice that the engineer now has new attributes)
bsi_stream.engineer.DefineEpisode(input_time_len=2*24*60, # using vital signs and labs 4 days prior to a culture 
                                  output_time_len=24*60, # predict one time unit into the future
                                  time_resolution=60, # aggregate minutely data to one row per hour 
                                  time_lag=0,  # no time lag between predictors and response
                                  anchor_gap=7*24*60) # the minimum distance between two episodes

# %%
print(bsi_stream.engineer.episode)

# %%
# Build MVTS dataframe or tfds  (notice that the engineer now has new attributes)
bsi_stream.engineer.BuildMVTS(csv_pool_path, 
                              nsbj = 6000, # number of subjects / patients to sample from the pool 
                              replace=False, # sample with replacement or not 
                              valid_frac = 0.2, # fraction of number of subjects in validation dataset
                              test_frac = 0.1, # fraction of number of subjects in left-out test dataset
                              batch_size = 64, # batch size (usually 32,64,128..)
                              impute_input='median', # imputation on predictors
                              impute_output='median',
                              sep="_")# imputation on response (no need in BSI project)
# please see the end of console 
# --- Success! Engineer has updated attributes --- train_df_imputed, valid_df_imputed and test_df_imputed. 
# --- Success! Engineer has updated attributes --- train_tfds, valid_tfds and test_tfds.

# %%
all_df = pd.concat( [bsi_stream.engineer.train_df, bsi_stream.engineer.valid_df], axis=0)
all_df = pd.concat( [all_df, bsi_stream.engineer.test_df], axis=0)
print(len(set(all_df.__uid)))
all_df.describe()

# %%
all_df.to_csv("./whole_df_uvanew.csv", index=False)

# %%
from random import randint
import matplotlib.pylab as plt 
import numpy as np
from tensorflow.keras.models import Sequential, Model

def get_feature_maps(model, layer_id, input_image):
    model_ = Model(inputs=[model.input], outputs=[model.layers[layer_id].output])
    return model_.predict(np.expand_dims(input_image, axis=0))[0,:,:,:].transpose((2,1,0))




def plot_features_map(input_image_list, 
                      cnn,
                      img_title_list,
                      layer_idx):
    
    nrow = len(layer_idx)
    ncol = len(input_image_list)
    
    fig, ax = plt.subplots(nrow+1, ncol, figsize=(20,20))
    
    for j in range(ncol):
        input_image = input_image_list[j]
        ax[0][j].imshow(input_image[:,:,0].transpose(1,0))
        ax[0][j].set_title(img_title_list[j])
        for i in range(nrow):
            feature_map = get_feature_maps(cnn, layer_idx[i], input_image)
            ax[i+1][j].imshow(feature_map[0,:,:])
            ax[i+1][j].set_title('layer {} - {}'.format(layer_idx[i], cnn.layers[layer_idx[i]].get_config()['name']))

    return

# %% [markdown]
# ## setup

# %%
# csv pool folder directory
csv_pool_path = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/csv_pool'


# current experiment working directory
work_dir = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case4'

# %%
# initiate a FAIRStream object instance for BSI project
bsi_stream = FAIRStream.FAIRStream(work_dir)
# take a look at dictionaries in engineer's hands
#bsi_stream.engineer.csv_source_dict
bsi_stream.engineer.variable_dict

# %% [markdown]
# ## Define Episode

# %%
# define an episode (notice that the engineer now has new attributes)
bsi_stream.engineer.DefineEpisode(input_time_len=4*24*60, # using vital signs and labs 4 days prior to a culture 
                                  output_time_len=1, # predict one time unit into the future
                                  time_resolution=60, # aggregate minutely data to one row per hour 
                                  time_lag=0,  # no time lag between predictors and response
                                  anchor_gap=7*24*60) # the minimum distance between two episodes

# %% [markdown]
# ## Build MVTS (multi-variable time series) data objects
# - train_df_imputed, valid_df_imputed and test_df_imputed are dataframes
# - train_tfds, valid_tfds and test_tfds are tensorflow datasets

# %%
# # Build MVTS dataframe or tfds  (notice that the engineer now has new attributes)
# bsi_stream.engineer.BuildMVTS(csv_pool_path, 
#                               nsbj = 10, # number of subjects / patients to sample from the pool 
#                               valid_frac = 0.2, # fraction of number of subjects in validation dataset
#                               test_frac = 0.1, # fraction of number of subjects in left-out test dataset
#                               batch_size = 64, # batch size (usually 32,64,128..)
#                               impute_input='median', # imputation on predictors
#                               impute_output='median' )# imputation on response (no need in BSI project)

# # please see the end of console 
# # --- Success! Engineer has updated attributes --- train_df_imputed, valid_df_imputed and test_df_imputed. 
# # --- Success! Engineer has updated attributes --- train_tfds, valid_tfds and test_tfds.

# %% [markdown]
# ### print all the attributes of the engineer

# %%
# bsi_stream.engineer.info()

# # extract X, Y numpy array by engineer build-in function
# X_train, Y_train, X_valid, Y_valid, X_test, Y_test = bsi_stream.engineer.ExtractXY()

# X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
# X_valid = X_valid.reshape(X_valid.shape[0], X_valid.shape[1], X_valid.shape[2], 1)
# X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
# X_train = X_train.astype('float32')
# X_valid = X_valid.astype('float32')
# X_test = X_test.astype('float32')

# Y_train = Y_train.reshape(Y_train.shape[0], Y_train.shape[2])
# Y_valid = Y_valid.reshape(Y_valid.shape[0], Y_valid.shape[2])
# Y_test = Y_test.reshape(Y_test.shape[0], Y_test.shape[2])

# X_all = np.concatenate((X_train, X_valid, X_test), axis=0)
# Y_all = np.concatenate((Y_train, Y_valid, Y_test), axis=0)

# %%
# specify input column names
bsi_stream.engineer.input_vars = ['age___vital', 'age___lab', 'temp___vital', 'heart_rate___vital', 'systolic_blood_pressure___vital', 'diastolic_blood_pressure___vital', 'resp_rate___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'wbc___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'paco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital']

# %% [markdown]
# ## --- Pre-modeling Interpretability (raw scale) ---

# %%
X_all = np.load("./X_all.npy")
Y_all = np.load("./Y_all.npy")
X_train = np.load("./X_train.npy")
Y_train = np.load("./Y_train.npy")
X_valid = np.load("./X_valid.npy")
Y_valid = np.load("./Y_valid.npy")
X_test = np.load("./X_test.npy")
Y_test = np.load("./Y_test.npy")

print("X_train shape", X_train.shape)
print("Y_train shape", Y_train.shape)
print("X_valid shape", X_valid.shape)
print("Y_valid shape", Y_valid.shape)
print("X_test shape", X_test.shape)
print("Y_test shape", Y_test.shape)
print("X_all shape", X_all.shape)
print("Y_all shape", Y_all.shape)

X_pos = X_all[Y_all[:,1]==1.0][:,:,:,0]
X_ctrl = X_all[Y_all[:,1]==0.0][:,:,:,0]
print("X_pos shape", X_pos.shape)
print("X_ctrl shape", X_ctrl.shape)

# %% [markdown]
# ### 1. print a few episode as images

# %%
fig, ax = plt.subplots(1,10,figsize=(20,20))
axes = ax.flatten()
for i in range(10): 
    norm = colors.TwoSlopeNorm(vmin = -np.max(np.abs(X_pos[i])), 
                               vcenter = 0,  # change zero to be not white 
                               vmax = np.max(np.abs(X_pos[i])) )
    axes[i].imshow(X_pos[i], cmap='bwr', norm=norm)
    axes[i].set_title('postive episode {}'.format(i))

fig, ax = plt.subplots(1,10,figsize=(20,20))
axes = ax.flatten()
for i in range(10):
    norm = colors.TwoSlopeNorm(vmin = -np.max(np.abs(X_pos[i])), 
                               vcenter = 0, 
                               vmax = np.max(np.abs(X_pos[i])) )
    axes[i].imshow(X_ctrl[i], cmap='bwr', norm=norm)
    axes[i].set_title('control episode {}'.format(i))

# %% [markdown]
# ### 2. Visualize Statistical Moments -- Positive VS Control Group

# %% [markdown]
# #### Statistic Moment 1 -- mean

# %%
# outlier in image

# %%
X_pos_stat = X_pos.mean(axis=0).transpose((1,0))
X_ctrl_stat = X_ctrl.mean(axis=0).transpose((1,0))
X_all_stat = X_all.mean(axis=0)[:,:,0].transpose((1,0))

norm = colors.TwoSlopeNorm(vmin = -max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ), 
                               vcenter = 0, 
                               vmax = max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ) )


fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()

im = ax[0].imshow(X_pos_stat, cmap='bwr', norm=norm)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12))
fig.colorbar(im, ax=ax[0])

im = ax[1].imshow(X_ctrl_stat, cmap='bwr', norm=norm)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12))
fig.colorbar(im, ax=ax[1])

im = ax[2].imshow(X_all_stat, cmap='bwr', norm=norm)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12))
fig.colorbar(im, ax=ax[2])

# %% [markdown]
# #### Statistic Moment 2 -- std

# %%
X_pos_stat = X_pos.std(axis=0).transpose((1,0))
X_ctrl_stat = X_ctrl.std(axis=0).transpose((1,0))
X_all_stat = X_all.std(axis=0)[:,:,0].transpose((1,0))

norm = colors.TwoSlopeNorm(vmin = -max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ), 
                               vcenter = 0, 
                               vmax = max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ) )


fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()
im=ax[0].imshow(X_pos_stat, cmap='bwr', norm=norm)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[0])

im=ax[1].imshow(X_ctrl_stat, cmap='bwr', norm=norm)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[1])

im=ax[2].imshow(X_all_stat, cmap='bwr', norm=norm)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[2])

# %% [markdown]
# #### Statistic Moment 3 -- skewness

# %%
X_pos_stat = scipy.stats.skew(X_pos, axis=0).transpose((1,0))
X_ctrl_stat = scipy.stats.skew(X_ctrl, axis=0).transpose((1,0))
X_all_stat = scipy.stats.skew(X_all, axis=0)[:,:,0].transpose((1,0))

norm = colors.TwoSlopeNorm(vmin = -max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ), 
                               vcenter = 0, 
                               vmax = max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ) )


fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()
im=ax[0].imshow(X_pos_stat, cmap='bwr', norm=norm)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[0])

im=ax[1].imshow(X_ctrl_stat, cmap='bwr', norm=norm)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[1])

im=ax[2].imshow(X_all_stat, cmap='bwr', norm=norm)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[2])

# %% [markdown]
# #### Statistic Moment 4 -- Kurtosis

# %%
X_pos_stat = scipy.stats.kurtosis(X_pos, axis=0).transpose((1,0))
X_ctrl_stat = scipy.stats.kurtosis(X_ctrl, axis=0).transpose((1,0))
X_all_stat = scipy.stats.kurtosis(X_all, axis=0)[:,:,0].transpose((1,0))

norm = colors.TwoSlopeNorm(vmin = -max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ), 
                               vcenter = 0, 
                               vmax = max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ) )


fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()
im=ax[0].imshow(X_pos_stat, cmap='bwr', norm=norm)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[0])

im=ax[1].imshow(X_ctrl_stat, cmap='bwr', norm=norm)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[1])

im=ax[2].imshow(X_all_stat, cmap='bwr', norm=norm)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[2])

# %% [markdown]
# ## --- Modeling interpretation raw scale (CNN) ---

# %%
X_train_2d = X_train[:,:,:,0].reshape(X_train[:,:,:,0].shape[0],-1)
X_valid_2d = X_valid[:,:,:,0].reshape(X_valid[:,:,:,0].shape[0],-1)
Y_train_binary = Y_train[:,1]
Y_valid_binary = Y_valid[:,1]
print(X_train_2d.shape)
print(Y_train_binary.shape)
print(X_valid_2d.shape)
print(Y_valid_binary.shape)

# %%
import sklearn
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(solver='liblinear').fit(X_train_2d, Y_train_binary)

#to check the shape of the coefficient matrix
clf.coef_.shape

# %%
scale = np.max(np.abs(clf.coef_))

p = plt.figure(figsize=(25, 25));
nclasses=1
for i in range(nclasses):
    p = plt.subplot(1, nclasses, i + 1)
    p = plt.imshow(clf.coef_[i].reshape(96, 25).T,
                  cmap=plt.cm.RdBu, vmin=-scale, vmax=scale);
    p = plt.axis('off')
    p = plt.title('positive');

# %% [markdown]
# ### AUROC for logistic regression

# %%
Y_valid_pred = clf.predict_proba(X_valid_2d)
sklearn.metrics.roc_auc_score(Y_valid_binary, Y_valid_pred[:,1])

# %% [markdown]
# ### binary setup logistic regression

# %%
myMetrics = [
    keras.metrics.AUC(name='AUROC', curve='ROC'),
    keras.metrics.AUC(name='AUPRC', curve='PR')
]

keras.backend.clear_session()
mdl = keras.models.Sequential([
    keras.layers.Flatten(input_shape=list(X_train.shape)[1:4]),
    keras.layers.Dense(1, activation='sigmoid')
])
mdl.summary()
mdl.compile(loss="binary_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
callback = EarlyStopping(monitor='val_loss', patience=5)
his = mdl.fit(X_train, Y_train_binary, 
              epochs=50, 
              validation_data=(X_valid,Y_valid_binary), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-4)
his = mdl.fit(X_train, Y_train_binary, 
              epochs=50, 
              validation_data=(X_valid,Y_valid_binary), callbacks=[callback])

# %% [markdown]
# ### multiple classification setup logistic regression

# %%
myMetrics = [
    keras.metrics.AUC(name='AUROC', curve='ROC', multi_label=True),
    keras.metrics.AUC(name='AUPRC', curve='PR', multi_label=True),
    #keras.metrics.recall(....),
]

keras.backend.clear_session()
mdl = keras.models.Sequential([
    keras.layers.Flatten(input_shape=list(X_train.shape)[1:4]),
    keras.layers.Dense(2, activation='softmax')
])
mdl.summary()
mdl.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
callback = EarlyStopping(monitor='val_loss', patience=5)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-4)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])

# %%
myMetrics = [
    keras.metrics.AUC(name='AUROC', curve='ROC', multi_label=True),
    keras.metrics.AUC(name='AUPRC', curve='PR', multi_label=True),
    keras.metrics.recall(....),
]

keras.backend.clear_session()
mdl = keras.models.Sequential([
    keras.layers.Conv2D(64, 
                        kernel_size=(3,3),
                        activation='relu', 
                        padding='same',
                        input_shape=list(X_train.shape)[1:4]),
    keras.layers.MaxPool2D(pool_size=(1,1)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(32, 
                        kernel_size=(3,3),
                        activation='relu', 
                        padding='same'),
    keras.layers.MaxPool2D(pool_size=(1,1)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(1, 
                        kernel_size=(3,3),
                        activation='relu', 
                        padding='same'),
    keras.layers.MaxPool2D(pool_size=(1,1)),
    keras.layers.BatchNormalization(),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
])
mdl.summary()
mdl.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
callback = EarlyStopping(monitor='val_loss', patience=5)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-4)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])

# %%
X_train_pos_img = X_train[Y_train[:,0]==1.0].mean(axis=0)
X_train_ctrl_img = X_train[Y_train[:,0]==0.0].mean(axis=0)

X_valid_pos_img = X_valid[Y_valid[:,0]==1.0].mean(axis=0)
X_valid_ctrl_img = X_valid[Y_valid[:,0]==0.0].mean(axis=0)

X_all_pos_img = X_all[Y_all[:,0]==1.0].mean(axis=0)
X_all_ctrl_img = X_all[Y_all[:,0]==0.0].mean(axis=0)

plot_features_map(input_image_list=[X_all_pos_img, X_all_ctrl_img,
                                    X_train_pos_img, X_train_ctrl_img, 
                                    X_valid_pos_img, X_valid_ctrl_img],
                  img_title_list=["POS (all)", "CTRL (all)",
                                  "POS (train)", "CTRL (train)", 
                                  "POS (valid)", " CTRL (valid)"],
                  layer_idx=[0,3,6], 
                  cnn=mdl)

# %% [markdown]
# ## --- Post-Modeling interpretation (raw scale + saliency map) ---

# %%
from vis.visualization import visualize_saliency
from vis.utils import utils
from keras import activations
def plot_saliency(img_idx):
    grads = visualize_saliency(mdl,
                               "visualized_layer",
                               filter_indices=Y_all[img_idx][0], 
                               seed_input=X_all[img_idx], 
                               backprop_modifier=None,
                               grad_modifier="absolute")
    fig, ax = plt.subplots(1,2, figsize=(10,5))
    ax[0].imshow(X_all[img_idx])
    ax[0].set_title('original img id {}'.format(img_idx))
    ax[1].imshow(grads, cmap='jet')
    ax[1].set_title('saliency - predicted {}'.format(img_idx))

plot_saliency(img_idx = 0)

# %% [markdown]
# ## --- Pre-training Interpretability (standardized) ---

# %%
X_all = np.load("./X_all.npy")
Y_all = np.load("./Y_all.npy")
X_train = np.load("./X_train.npy")
Y_train = np.load("./Y_train.npy")
X_valid = np.load("./X_valid.npy")
Y_valid = np.load("./Y_valid.npy")
X_test = np.load("./X_test.npy")
Y_test = np.load("./Y_test.npy")

print("X_train shape", X_train.shape)
print("Y_train shape", Y_train.shape)
print("X_valid shape", X_valid.shape)
print("Y_valid shape", Y_valid.shape)
print("X_test shape", X_test.shape)
print("Y_test shape", Y_test.shape)
print("X_all shape", X_all.shape)
print("Y_all shape", Y_all.shape)

X_train = (X_train - X_all.mean(axis=0))/X_all.std(axis=0)
X_valid = (X_valid - X_all.mean(axis=0))/X_all.std(axis=0)
X_all = (X_all - X_all.mean(axis=0))/X_all.std(axis=0)

print("X_train shape", X_train.shape)
print("Y_train shape", Y_train.shape)
print("X_valid shape", X_valid.shape)
print("Y_valid shape", Y_valid.shape)
print("X_all shape", X_all.shape)
print("Y_all shape", Y_all.shape)


X_pos = X_all[Y_all[:,1]==1.0][:,:,:,0]
X_ctrl = X_all[Y_all[:,1]==0.0][:,:,:,0]
print("X_pos shape", X_pos.shape)
print("X_ctrl shape", X_ctrl.shape)

# %%
fig, ax = plt.subplots(1,10,figsize=(20,20))
axes = ax.flatten()
for i in range(10): 
    norm = colors.TwoSlopeNorm(vmin = -np.max(np.abs(X_pos[i])), 
                               vcenter = 0, 
                               vmax = np.max(np.abs(X_pos[i])) )
    axes[i].imshow(X_pos[i], cmap='bwr', norm=norm)
    axes[i].set_title('postive episode {}'.format(i))

fig, ax = plt.subplots(1,10,figsize=(20,20))
axes = ax.flatten()
for i in range(10):
    norm = colors.TwoSlopeNorm(vmin = -np.max(np.abs(X_pos[i])), 
                               vcenter = 0, 
                               vmax = np.max(np.abs(X_pos[i])) )
    axes[i].imshow(X_ctrl[i], cmap='bwr', norm=norm)
    axes[i].set_title('control episode {}'.format(i))

# %% [markdown]
# #### Statistic Moment 1 -- mean

# %%
X_pos_stat = X_pos.mean(axis=0).transpose((1,0))
X_ctrl_stat = X_ctrl.mean(axis=0).transpose((1,0))
X_all_stat = X_all.mean(axis=0)[:,:,0].transpose((1,0))

norm = colors.TwoSlopeNorm(vmin = -max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ), 
                               vcenter = 0, 
                               vmax = max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ) )


fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()

im = ax[0].imshow(X_pos_stat, cmap='bwr', norm=norm)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12))
fig.colorbar(im, ax=ax[0])

im = ax[1].imshow(X_ctrl_stat, cmap='bwr', norm=norm)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12))
fig.colorbar(im, ax=ax[1])

im = ax[2].imshow(X_all_stat, cmap='bwr', norm=norm)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12))
fig.colorbar(im, ax=ax[2])

# %% [markdown]
# ### Statistic Moment 2 -- std

# %%
X_pos_stat = X_pos.std(axis=0).transpose((1,0))
X_ctrl_stat = X_ctrl.std(axis=0).transpose((1,0))
X_all_stat = X_all.std(axis=0)[:,:,0].transpose((1,0))

norm = colors.TwoSlopeNorm(vmin = -max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ), 
                               vcenter = 0, 
                               vmax = max( np.max(np.abs(X_all_stat)),np.max(np.abs(X_pos_stat)),np.max(np.abs(X_ctrl_stat)) ) )


fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()
im=ax[0].imshow(X_pos_stat, cmap='bwr', norm=norm)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[0])

im=ax[1].imshow(X_ctrl_stat, cmap='bwr', norm=norm)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[1])

im=ax[2].imshow(X_all_stat, cmap='bwr', norm=norm)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12));
fig.colorbar(im, ax=ax[2])

# %% [markdown]
# #### Statistic Moment 3 -- skewness

# %% [markdown]
# #### Statistic Moment 4 -- Kurtosis
