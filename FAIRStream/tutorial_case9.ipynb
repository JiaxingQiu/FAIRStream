# %% [markdown]
# ## SHAP -- SHapley Additive exPlanations

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import scipy
from matplotlib import colors

import FAIRStream

# %%
# csv pool folder directory
csv_pool_path = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/csv_pool'
# current experiment working directory
work_dir = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case_txp'

# %%
# initiate a FAIRStream object instance for BSI project
bsi_stream = FAIRStream.FAIRStream(work_dir)
# take a look at dictionaries in engineer's hands
#bsi_stream.engineer.csv_source_dict
bsi_stream.engineer.variable_dict
# Out:
# Success: Querier has initiated a csv source dictionary in:/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case_txp/meta_data/csv_source_dict_demo.json
# Success: Querier has initiated a variable dictionary in:/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case_txp/meta_data/variable_dict_demo.json
# Unable to read sql source dictionary. Use Querier.update_sql_source_dict() to build one.
# {'__uid': {'src_names': ['id', 'ID', 'subject_id', 'subject_id'],
#   'label': 'unique subject id for current study',
#   'unique_per_sbj': True},
#  '__time': {'src_names': ['tsa', 'tsa', 'timeMinutes', 'timeMinutes'],
#   'label': 'time since admission',
#   'unit': 'minute'},
#  '__anchor': {'src_names': ['True_positive', 'True positive'],
#   'label': 'anchor for an episode',
#   'unique_per_sbj': False,
#   'factor': {'levels': {'__neg_nbc': ['0', '0.0', 'nan'],
#     '__pos': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': '__neg_nbc'}}},
#  'y': {'output': True,
#   'src_names': ['True_positive', 'True positive'],
#   'label': 'Event outcome result',
#   'unique_per_sbj': False,
#   'factor': {'levels': {'nbc': ['nan'],
#     'neg': ['0', '0.0'],
#     'pos': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': 'nbc'}}},
#  'txp': {'input': True,
#   'src_names': ['Confirmed Txp'],
#   'label': 'Transplant recipient',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'no': ['0', '0.0', 'nan'], 'yes': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': 'no'}}},
#  'age': {'input': True,
#   'src_names': ['age', 'AGE'],
#   'label': 'age at admission',
#   'unique_per_sbj': True,
#   'numeric': {'scaler': 'none',
#    'unit': 'year',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 110},
#    'impute_per_sbj': {'forward': 0, 'backward': 0}}},
#  'temp': {'input': True,
#   'src_names': ['Temp', 'tempc'],
#   'label': 'subject body temperature',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'celsius',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 33,
#     'value_max': 50},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'heart_rate': {'input': True,
#   'src_names': ['hr', 'heartrate'],
#   'label': 'subject heart rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'beats per minute',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 10,
#     'value_max': 200},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'resp_rate': {'input': True,
#   'src_names': ['rr', 'resprate'],
#   'label': 'subject respiratory rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 200},
#    'unit': 'mm Hg',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'spo2': {'input': True,
#   'src_names': ['so2'],
#   'label': 'SpO2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 79},
#    'unit': '',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'x_hr_rr': {'input': True,
#   'src_names': ['x.hr.rr'],
#   'label': 'cross correlation between HR and resp_rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -1,
#     'value_max': 1},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'x_hr_spo2': {'input': True,
#   'src_names': ['x.hr.spo2'],
#   'label': 'cross correlation between HR and spo2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -1,
#     'value_max': 1},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'x_rr_spo2': {'input': True,
#   'src_names': ['x.hr.spo2'],
#   'label': 'cross correlation between resp_rate and spo2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -1,
#     'value_max': 1},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  's_hr': {'input': True,
#   'src_names': ['s.hr'],
#   'label': 'HR sd',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -99999,
#     'value_max': 99999},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  's_rr': {'input': True,
#   'src_names': ['s.rr'],
#   'label': 'resp_rate sd',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -99999,
#     'value_max': 99999},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  's_so2': {'input': True,
#   'src_names': ['s.so2'],
#   'label': 'SPO2 sd',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': '',
#    'cutoff': {'quantile_min': 0.0,
#     'quantile_max': 1,
#     'value_min': -99999,
#     'value_max': 99999},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'systolic_blood_pressure': {'input': True,
#   'src_names': ['SBP', 'sysbp'],
#   'label': 'subject systolic blood pressure',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'mm Hg',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 40,
#     'value_max': 250},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'diastolic_blood_pressure': {'input': True,
#   'src_names': ['DBP', 'diasbp'],
#   'label': 'subject diastolic blood pressure',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'mm Hg',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 26,
#     'value_max': 150},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'glucose': {'input': True,
#   'src_names': ['GLUCOSE', 'Glucose'],
#   'label': 'Glucose',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 49,
#     'value_max': 460},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'bilirubin': {'input': True,
#   'src_names': ['TOTAL.BILIRUBIN', 'bilirubin'],
#   'label': 'Bilirubin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 50},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'potassium': {'input': True,
#   'src_names': ['POTASSIUM', 'Potassium'],
#   'label': 'Potassium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 2.4,
#     'value_max': 6.6},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'albumin': {'input': True,
#   'src_names': ['Albumin', 'ALBUMIN'],
#   'label': 'Albumin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 5},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'calcium': {'input': True,
#   'src_names': ['CALCIUM', 'Calcium'],
#   'label': 'Calcium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 6.1,
#     'value_max': 12},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'sodium': {'input': True,
#   'src_names': ['SODIUM', 'Sodium'],
#   'label': 'Sodium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 119,
#     'value_max': 172},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'wbc': {'input': True,
#   'src_names': ['WHITE.BLOOD.CELL.COUNT', 'WBC'],
#   'label': 'WBC',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 33.85},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'phosphorus': {'input': True,
#   'src_names': ['PHOSPHORUS'],
#   'label': 'Phosphorus',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 5,
#     'value_max': 8},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'protin_inr': {'input': True,
#   'src_names': ['PROTIME_INR'],
#   'label': 'Protin_inr',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 5},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'creatinine': {'input': True,
#   'src_names': ['CREATININE', 'Creatinine'],
#   'label': 'Creatinine',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 10},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'platelet_count': {'input': True,
#   'src_names': ['PLATELET.COUNT', 'plateletcount'],
#   'label': 'PlateletCount',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1001},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'alt': {'input': True,
#   'src_names': ['ALT.GPT', 'ALT'],
#   'label': 'ALT',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1085},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'alp': {'input': True,
#   'src_names': ['ALKALINE.PHOSPHATASE', 'ALP'],
#   'label': 'ALP',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 800},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'ast': {'input': True,
#   'src_names': ['AST.GOT', 'AST'],
#   'label': 'AST',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1203},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'pco2': {'input': True,
#   'src_names': ['PCO2', 'PaCO2'],
#   'label': 'PCO2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100.5},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'chloride': {'input': True,
#   'src_names': ['CHLORIDE', 'Chloride'],
#   'label': 'Chloride',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 83,
#     'value_max': 132},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'troponin': {'input': True,
#   'src_names': ['TROPONIN.I', 'Troponin'],
#   'label': 'Troponin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 23.5},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'ptt': {'input': True,
#   'src_names': ['PARTIAL.THROMBOPLASTIN.TIME', 'PTT'],
#   'label': 'partial_thromboplastin_time',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 140},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'lactate': {'input': True,
#   'src_names': ['Lactate', 'LACTIC.ACID'],
#   'label': 'Lactate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 19.1},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'bun': {'input': True,
#   'src_names': ['BLOOD.UREA.NITROGEN', 'BUN'],
#   'label': 'BUN',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 143},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'o2sat': {'input': True,
#   'src_names': ['OXYGEN_SATURATION'],
#   'label': 'Oxygen Satuation',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 17.6},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}},
#  'magnesium': {'input': True,
#   'src_names': ['MAGNESIUM', 'Magnesium'],
#   'label': 'Magnesium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 3.4},
#    'unit': '',
#    'impute_per_sbj': {'forward': 2880, 'backward': 1440}}}}

# %%
# define an episode (notice that the engineer now has new attributes)
bsi_stream.engineer.DefineEpisode(input_time_len=2*24*60, # using vital signs and labs 4 days prior to a culture 
                                  output_time_len=24*60, # predict one time unit into the future
                                  time_resolution=60, # aggregate minutely data to one row per hour 
                                  time_lag=0,  # no time lag between predictors and response
                                  anchor_gap=7*24*60) # the minimum distance between two episodes
# Out:
#
# Success! An episode is defined to
# --- use 2880 minute(s) long input variables
# --- predict 1440 minute(s) response variables into the future
# --- lag 0 minute(s) between predictors and responses
# --- increase by every 60 minute(s)
# --- last at most 10080 minute(s) long
# Success! Engineer has updated attributes --- episode.

# %%
# # Build MVTS dataframe or tfds  (notice that the engineer now has new attributes)
# bsi_stream.engineer.BuildMVTS(csv_pool_path, 
#                               #nsbj = 6000, # number of subjects / patients to sample from the pool 
#                               nsbj = 60, # number of subjects / patients to sample from the pool 
#                               replace=True, # sample with replacement or not 
#                               valid_frac = 0.2, # fraction of number of subjects in validation dataset
#                               test_frac = 0, # fraction of number of subjects in left-out test dataset
#                               batch_size = 64, # batch size (usually 32,64,128..)
#                               impute_input='median', # imputation on predictors
#                               impute_output='median' )# imputation on response (no need in BSI project)

# # please see the end of console 
# # # --- Success! Engineer has updated attributes --- train_df_imputed, valid_df_imputed and test_df_imputed. 
# # # --- Success! Engineer has updated attributes --- train_tfds, valid_tfds and test_tfds.

# %%
# bsi_stream.engineer.info()

# %%
# # save raw dataframe in a csv
# bsi_stream.engineer.train_df.to_csv("./train_df.csv", index=False)
# bsi_stream.engineer.valid_df.to_csv("./valid_df.csv", index=False)
# bsi_stream.engineer.train_df_imputed.to_csv("./train_df_median.csv", index=False)
# bsi_stream.engineer.valid_df_imputed.to_csv("./valid_df_median.csv", index=False)

# %% [markdown]
# ## Model -- scale inputs by percentile

# %%
# input and output variable name lists
input_vars = ['txp___yes', 'age___vital', 'temp___vital', 'heart_rate___vital', 'resp_rate___vital', 'spo2___vital', 'x_hr_rr___vital', 's_hr___vital', 's_rr___vital', 's_so2___vital', 'diastolic_blood_pressure___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'sodium___vital', 'wbc___vital', 'phosphorus___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'pco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital'] # 'systolic_blood_pressure___vital',
output_var = ['y___pos']

# read datasets
train_df = pd.read_csv("./train_df.csv")
valid_df = pd.read_csv("./valid_df.csv")
whole_df = pd.concat([train_df, valid_df], axis=0)
whole_df.reset_index(drop=True,inplace=True)

# percentile of inputs
whole_df[input_vars] = whole_df[input_vars].rank(pct=True)

# %%
train_df = whole_df.loc[range(train_df.shape[0]),:].copy()
valid_df = whole_df.loc[range(train_df.shape[0], whole_df.shape[0]),:].copy()

# select modeling time window
train_df = train_df.loc[(train_df['__ep_relative_time']/60>=-24) & (train_df['__ep_relative_time']/60<=0) ,:]
valid_df = valid_df.loc[(valid_df['__ep_relative_time']/60>=-24) & (valid_df['__ep_relative_time']/60<=0) ,:]


# median imputation
train_df.fillna(train_df.median(), inplace=True)
valid_df.fillna(train_df.median(), inplace=True)


# combine to one dataframe
whole_df = pd.concat([train_df, valid_df], axis=0)

# %%
# reformat inputs to be 2d image and 1 output per image
X_whole = whole_df[input_vars].values
Y_whole = whole_df[output_var].values
X_whole = np.reshape(X_whole, (-1,25,31) )
Y_whole = np.reshape(Y_whole, (-1,25,1) )[:,0,:]
print(X_whole.shape)
print(Y_whole.shape)

# reformat inputs to be 2d image and 1 output per image
X_train = train_df[input_vars].values
Y_train = train_df[output_var].values
X_train = np.reshape(X_train, (-1,25,31) )
Y_train = np.reshape(Y_train, (-1,25,1) )[:,0,:]
print(X_train.shape)
print(Y_train.shape)

# reformat inputs to be 2d image and 1 output per image
X_valid = valid_df[input_vars].values
Y_valid = valid_df[output_var].values
X_valid = np.reshape(X_valid, (-1,25,31) )
Y_valid = np.reshape(Y_valid, (-1,25,1) )[:,0,:]
print(X_valid.shape)
print(Y_valid.shape)

# # add fake postive and negative cases
# fake_pos = np.mean(X_whole[Y_whole[:,0]==1,:,:],axis=0)
# fake_ctrl = np.mean(X_whole[Y_whole[:,0]==0,:,:],axis=0)
# new_cases = np.stack([fake_pos,fake_ctrl])
# X_valid = np.append(new_cases, X_valid, axis=0)
# Out:
# (6557, 25, 31)
# (6557, 1)
# (5226, 25, 31)
# (5226, 1)
# (1331, 25, 31)
# (1331, 1)

# %% [markdown]
# ### Logistic Regression

# %%
myMetrics = [
    keras.metrics.AUC(name='AUROC', curve='ROC'),
    keras.metrics.AUC(name='AUPRC', curve='PR')
]

keras.backend.clear_session()
mdl = keras.models.Sequential([
    keras.layers.Flatten(input_shape=list(X_train.shape)[1:4]),
    keras.layers.Dense(1, activation='sigmoid')
])
mdl.summary()
mdl.compile(loss="binary_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 801
# =================================================================
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 164/164 [==============================] - 1s 3ms/step - loss: 0.3950 - AUROC: 0.5730 - AUPRC: 0.1692 - val_loss: 0.3778 - val_AUROC: 0.7211 - val_AUPRC: 0.3165
# Epoch 2/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3555 - AUROC: 0.7488 - AUPRC: 0.3575 - val_loss: 0.3741 - val_AUROC: 0.7500 - val_AUPRC: 0.3451
# Epoch 3/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3415 - AUROC: 0.7645 - AUPRC: 0.3653 - val_loss: 0.3503 - val_AUROC: 0.7655 - val_AUPRC: 0.3634
# Epoch 4/50
# 164/164 [==============================] - 0s 899us/step - loss: 0.3263 - AUROC: 0.7770 - AUPRC: 0.3899 - val_loss: 0.3707 - val_AUROC: 0.7680 - val_AUPRC: 0.3734
# Epoch 5/50
# 164/164 [==============================] - 0s 918us/step - loss: 0.3201 - AUROC: 0.7907 - AUPRC: 0.3909 - val_loss: 0.3444 - val_AUROC: 0.7756 - val_AUPRC: 0.3825
# Epoch 6/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3357 - AUROC: 0.7938 - AUPRC: 0.4351 - val_loss: 0.3461 - val_AUROC: 0.7773 - val_AUPRC: 0.3892
# Epoch 7/50
# 164/164 [==============================] - 0s 982us/step - loss: 0.3033 - AUROC: 0.8098 - AUPRC: 0.4162 - val_loss: 0.3621 - val_AUROC: 0.7787 - val_AUPRC: 0.3956
# Epoch 8/50
# 164/164 [==============================] - 0s 875us/step - loss: 0.3037 - AUROC: 0.8073 - AUPRC: 0.4274 - val_loss: 0.3425 - val_AUROC: 0.7809 - val_AUPRC: 0.3987
# Epoch 9/50
# 164/164 [==============================] - 0s 937us/step - loss: 0.3283 - AUROC: 0.7954 - AUPRC: 0.4195 - val_loss: 0.3402 - val_AUROC: 0.7804 - val_AUPRC: 0.3991
# Epoch 10/50
# 164/164 [==============================] - 0s 969us/step - loss: 0.3205 - AUROC: 0.8085 - AUPRC: 0.4378 - val_loss: 0.3398 - val_AUROC: 0.7832 - val_AUPRC: 0.4051
# Epoch 11/50
# 164/164 [==============================] - 0s 888us/step - loss: 0.3032 - AUROC: 0.8193 - AUPRC: 0.4720 - val_loss: 0.3390 - val_AUROC: 0.7834 - val_AUPRC: 0.4064
# Epoch 12/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3043 - AUROC: 0.8064 - AUPRC: 0.4255 - val_loss: 0.3399 - val_AUROC: 0.7833 - val_AUPRC: 0.4104
# Epoch 13/50
# 164/164 [==============================] - 0s 958us/step - loss: 0.3178 - AUROC: 0.8018 - AUPRC: 0.4452 - val_loss: 0.3537 - val_AUROC: 0.7830 - val_AUPRC: 0.4130
# Epoch 14/50
# 164/164 [==============================] - 0s 988us/step - loss: 0.3157 - AUROC: 0.8242 - AUPRC: 0.4572 - val_loss: 0.3463 - val_AUROC: 0.7862 - val_AUPRC: 0.4147
# Epoch 15/50
# 164/164 [==============================] - 0s 989us/step - loss: 0.3029 - AUROC: 0.8285 - AUPRC: 0.4406 - val_loss: 0.3362 - val_AUROC: 0.7863 - val_AUPRC: 0.4163
# Epoch 16/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3075 - AUROC: 0.8044 - AUPRC: 0.4740 - val_loss: 0.3360 - val_AUROC: 0.7865 - val_AUPRC: 0.4176
# Epoch 17/50
# 164/164 [==============================] - 0s 995us/step - loss: 0.3204 - AUROC: 0.7865 - AUPRC: 0.3931 - val_loss: 0.3356 - val_AUROC: 0.7865 - val_AUPRC: 0.4186
# Epoch 18/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3055 - AUROC: 0.8117 - AUPRC: 0.4343 - val_loss: 0.3382 - val_AUROC: 0.7883 - val_AUPRC: 0.4210
# Epoch 19/50
# 164/164 [==============================] - 0s 975us/step - loss: 0.2956 - AUROC: 0.8235 - AUPRC: 0.4861 - val_loss: 0.3398 - val_AUROC: 0.7892 - val_AUPRC: 0.4257
# Epoch 20/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2923 - AUROC: 0.8319 - AUPRC: 0.4948 - val_loss: 0.3351 - val_AUROC: 0.7890 - val_AUPRC: 0.4240
# Epoch 21/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3060 - AUROC: 0.8214 - AUPRC: 0.4612 - val_loss: 0.3346 - val_AUROC: 0.7896 - val_AUPRC: 0.4261
# Epoch 22/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3155 - AUROC: 0.7898 - AUPRC: 0.4286 - val_loss: 0.3365 - val_AUROC: 0.7908 - val_AUPRC: 0.4281
# Epoch 23/50
# 164/164 [==============================] - 0s 959us/step - loss: 0.3005 - AUROC: 0.8220 - AUPRC: 0.4692 - val_loss: 0.3326 - val_AUROC: 0.7913 - val_AUPRC: 0.4286
# Epoch 24/50
# 164/164 [==============================] - 0s 940us/step - loss: 0.2968 - AUROC: 0.8284 - AUPRC: 0.4642 - val_loss: 0.3331 - val_AUROC: 0.7906 - val_AUPRC: 0.4307
# Epoch 25/50
# 164/164 [==============================] - 0s 885us/step - loss: 0.3008 - AUROC: 0.8178 - AUPRC: 0.4623 - val_loss: 0.3323 - val_AUROC: 0.7918 - val_AUPRC: 0.4312
# Epoch 26/50
# 164/164 [==============================] - 0s 934us/step - loss: 0.2965 - AUROC: 0.8284 - AUPRC: 0.4606 - val_loss: 0.3365 - val_AUROC: 0.7913 - val_AUPRC: 0.4334
# Epoch 27/50
# 164/164 [==============================] - 0s 924us/step - loss: 0.3006 - AUROC: 0.8306 - AUPRC: 0.5019 - val_loss: 0.3318 - val_AUROC: 0.7923 - val_AUPRC: 0.4335
# Epoch 28/50
# 164/164 [==============================] - 0s 886us/step - loss: 0.2977 - AUROC: 0.8152 - AUPRC: 0.4653 - val_loss: 0.3371 - val_AUROC: 0.7932 - val_AUPRC: 0.4344
# Epoch 29/50
# 164/164 [==============================] - 0s 946us/step - loss: 0.2983 - AUROC: 0.8215 - AUPRC: 0.4876 - val_loss: 0.3350 - val_AUROC: 0.7926 - val_AUPRC: 0.4403
# Epoch 30/50
# 164/164 [==============================] - 0s 936us/step - loss: 0.3076 - AUROC: 0.8302 - AUPRC: 0.5244 - val_loss: 0.3341 - val_AUROC: 0.7934 - val_AUPRC: 0.4382
# Epoch 31/50
# 164/164 [==============================] - 0s 872us/step - loss: 0.3182 - AUROC: 0.8090 - AUPRC: 0.4990 - val_loss: 0.3743 - val_AUROC: 0.7915 - val_AUPRC: 0.4440
# Epoch 32/50
# 164/164 [==============================] - 0s 906us/step - loss: 0.3025 - AUROC: 0.8314 - AUPRC: 0.5122 - val_loss: 0.3338 - val_AUROC: 0.7935 - val_AUPRC: 0.4396
# Epoch 33/50
# 164/164 [==============================] - 0s 944us/step - loss: 0.3128 - AUROC: 0.8223 - AUPRC: 0.4864 - val_loss: 0.3397 - val_AUROC: 0.7938 - val_AUPRC: 0.4435
# Epoch 34/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3079 - AUROC: 0.8175 - AUPRC: 0.4554 - val_loss: 0.3478 - val_AUROC: 0.7946 - val_AUPRC: 0.4448
# Epoch 35/50
# 164/164 [==============================] - 0s 987us/step - loss: 0.2941 - AUROC: 0.8248 - AUPRC: 0.4781 - val_loss: 0.3377 - val_AUROC: 0.7956 - val_AUPRC: 0.4431
# Epoch 36/50
# 164/164 [==============================] - 0s 932us/step - loss: 0.2964 - AUROC: 0.8254 - AUPRC: 0.4944 - val_loss: 0.3300 - val_AUROC: 0.7949 - val_AUPRC: 0.4424
# Epoch 37/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3075 - AUROC: 0.8240 - AUPRC: 0.4734 - val_loss: 0.3301 - val_AUROC: 0.7952 - val_AUPRC: 0.4429
# Epoch 38/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2927 - AUROC: 0.8346 - AUPRC: 0.4911 - val_loss: 0.3392 - val_AUROC: 0.7948 - val_AUPRC: 0.4483
# Epoch 39/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3039 - AUROC: 0.8263 - AUPRC: 0.4821 - val_loss: 0.3293 - val_AUROC: 0.7961 - val_AUPRC: 0.4459
# Epoch 40/50
# 164/164 [==============================] - 0s 976us/step - loss: 0.2908 - AUROC: 0.8302 - AUPRC: 0.5172 - val_loss: 0.3354 - val_AUROC: 0.7971 - val_AUPRC: 0.4482
# Epoch 41/50
# 164/164 [==============================] - 0s 925us/step - loss: 0.3191 - AUROC: 0.8131 - AUPRC: 0.4779 - val_loss: 0.3321 - val_AUROC: 0.7964 - val_AUPRC: 0.4444
# Epoch 42/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3011 - AUROC: 0.8226 - AUPRC: 0.4747 - val_loss: 0.3286 - val_AUROC: 0.7979 - val_AUPRC: 0.4461
# Epoch 43/50
# 164/164 [==============================] - 0s 927us/step - loss: 0.2942 - AUROC: 0.8079 - AUPRC: 0.4485 - val_loss: 0.3292 - val_AUROC: 0.7976 - val_AUPRC: 0.4471
# Epoch 44/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2919 - AUROC: 0.8259 - AUPRC: 0.4708 - val_loss: 0.3298 - val_AUROC: 0.7981 - val_AUPRC: 0.4515
# Epoch 45/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2979 - AUROC: 0.8307 - AUPRC: 0.4892 - val_loss: 0.3345 - val_AUROC: 0.7985 - val_AUPRC: 0.4527
# Epoch 46/50
# 164/164 [==============================] - 0s 974us/step - loss: 0.2984 - AUROC: 0.8356 - AUPRC: 0.5215 - val_loss: 0.3309 - val_AUROC: 0.7976 - val_AUPRC: 0.4516
# Epoch 47/50
# 164/164 [==============================] - 0s 987us/step - loss: 0.2969 - AUROC: 0.8306 - AUPRC: 0.4867 - val_loss: 0.3303 - val_AUROC: 0.7982 - val_AUPRC: 0.4536
# Epoch 48/50
# 164/164 [==============================] - 0s 975us/step - loss: 0.3025 - AUROC: 0.8287 - AUPRC: 0.4929 - val_loss: 0.3293 - val_AUROC: 0.7976 - val_AUPRC: 0.4488
# Epoch 49/50
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3045 - AUROC: 0.8188 - AUPRC: 0.4855 - val_loss: 0.3288 - val_AUROC: 0.7988 - val_AUPRC: 0.4509
# Epoch 50/50
# 164/164 [==============================] - 0s 962us/step - loss: 0.2876 - AUROC: 0.8468 - AUPRC: 0.5404 - val_loss: 0.3276 - val_AUROC: 0.7987 - val_AUPRC: 0.4544

# %% [markdown]
# ### LSTM

# %%
# myMetrics = [
#     keras.metrics.AUC(name='AUROC', curve='ROC'),
#     keras.metrics.AUC(name='AUPRC', curve='PR')
# ]

# keras.backend.clear_session()
# mdl = keras.models.Sequential([
#     keras.Input(shape=list(X_train.shape)[1:4]),
#     keras.layers.LSTM(16, dropout=0.2, recurrent_dropout=0.2),
#     keras.layers.Dense(1, activation='sigmoid')
# ])
# mdl.summary()
# mdl.compile(loss="binary_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
# callback = EarlyStopping(monitor='val_loss', patience=10)
# his = mdl.fit(X_train, Y_train, 
#               epochs=50, 
#               validation_data=(X_valid,Y_valid), callbacks=[callback])
# keras.backend.set_value(mdl.optimizer.learning_rate, 1e-4)
# his = mdl.fit(X_train, Y_train, 
#               epochs=50, 
#               validation_data=(X_valid,Y_valid), callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 16)                3136
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 3,153
# Trainable params: 3,153
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 164/164 [==============================] - 5s 19ms/step - loss: 0.4048 - AUROC: 0.5698 - AUPRC: 0.1573 - val_loss: 0.3830 - val_AUROC: 0.7134 - val_AUPRC: 0.2600
# Epoch 2/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.3628 - AUROC: 0.7149 - AUPRC: 0.2772 - val_loss: 0.3836 - val_AUROC: 0.7392 - val_AUPRC: 0.3051
# Epoch 3/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.3577 - AUROC: 0.7351 - AUPRC: 0.2880 - val_loss: 0.3581 - val_AUROC: 0.7485 - val_AUPRC: 0.3320
# Epoch 4/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.3289 - AUROC: 0.7649 - AUPRC: 0.3293 - val_loss: 0.3485 - val_AUROC: 0.7708 - val_AUPRC: 0.3578
# Epoch 5/50
# 164/164 [==============================] - 3s 16ms/step - loss: 0.3231 - AUROC: 0.7900 - AUPRC: 0.4120 - val_loss: 0.3580 - val_AUROC: 0.7539 - val_AUPRC: 0.3461
# Epoch 6/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.3248 - AUROC: 0.7863 - AUPRC: 0.4013 - val_loss: 0.3682 - val_AUROC: 0.7724 - val_AUPRC: 0.3652
# Epoch 7/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.3162 - AUROC: 0.7972 - AUPRC: 0.4279 - val_loss: 0.3514 - val_AUROC: 0.7793 - val_AUPRC: 0.3814
# Epoch 8/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.3037 - AUROC: 0.8177 - AUPRC: 0.4167 - val_loss: 0.3619 - val_AUROC: 0.7775 - val_AUPRC: 0.3927
# Epoch 9/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.3124 - AUROC: 0.8010 - AUPRC: 0.4527 - val_loss: 0.3470 - val_AUROC: 0.7757 - val_AUPRC: 0.3684
# Epoch 10/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.3268 - AUROC: 0.7849 - AUPRC: 0.3692 - val_loss: 0.3655 - val_AUROC: 0.7792 - val_AUPRC: 0.3873
# Epoch 11/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.3129 - AUROC: 0.8067 - AUPRC: 0.4357 - val_loss: 0.3531 - val_AUROC: 0.7957 - val_AUPRC: 0.3924
# Epoch 12/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.3002 - AUROC: 0.8137 - AUPRC: 0.4485 - val_loss: 0.3362 - val_AUROC: 0.8004 - val_AUPRC: 0.3991
# Epoch 13/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.3216 - AUROC: 0.8169 - AUPRC: 0.4853 - val_loss: 0.3432 - val_AUROC: 0.8054 - val_AUPRC: 0.4121
# Epoch 14/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.3055 - AUROC: 0.8335 - AUPRC: 0.4875 - val_loss: 0.3397 - val_AUROC: 0.7921 - val_AUPRC: 0.4078
# Epoch 15/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2928 - AUROC: 0.8271 - AUPRC: 0.4515 - val_loss: 0.3403 - val_AUROC: 0.8023 - val_AUPRC: 0.4264
# Epoch 16/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2951 - AUROC: 0.8320 - AUPRC: 0.4891 - val_loss: 0.3473 - val_AUROC: 0.8049 - val_AUPRC: 0.4289
# Epoch 17/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2951 - AUROC: 0.8379 - AUPRC: 0.4816 - val_loss: 0.3327 - val_AUROC: 0.8010 - val_AUPRC: 0.4299
# Epoch 18/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2972 - AUROC: 0.8260 - AUPRC: 0.4722 - val_loss: 0.3407 - val_AUROC: 0.7882 - val_AUPRC: 0.4039
# Epoch 19/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2898 - AUROC: 0.8331 - AUPRC: 0.4538 - val_loss: 0.3266 - val_AUROC: 0.8141 - val_AUPRC: 0.4213
# Epoch 20/50
# 164/164 [==============================] - 3s 19ms/step - loss: 0.2913 - AUROC: 0.8350 - AUPRC: 0.5020 - val_loss: 0.3340 - val_AUROC: 0.7969 - val_AUPRC: 0.4266
# Epoch 21/50
# 164/164 [==============================] - 3s 19ms/step - loss: 0.3031 - AUROC: 0.8380 - AUPRC: 0.5219 - val_loss: 0.3342 - val_AUROC: 0.8042 - val_AUPRC: 0.4227
# Epoch 22/50
# 164/164 [==============================] - 3s 19ms/step - loss: 0.2872 - AUROC: 0.8383 - AUPRC: 0.4794 - val_loss: 0.3315 - val_AUROC: 0.8119 - val_AUPRC: 0.4433
# Epoch 23/50
# 164/164 [==============================] - 3s 20ms/step - loss: 0.2966 - AUROC: 0.8386 - AUPRC: 0.5301 - val_loss: 0.3303 - val_AUROC: 0.7995 - val_AUPRC: 0.4396
# Epoch 24/50
# 164/164 [==============================] - 3s 20ms/step - loss: 0.2923 - AUROC: 0.8412 - AUPRC: 0.5216 - val_loss: 0.3373 - val_AUROC: 0.7992 - val_AUPRC: 0.4183
# Epoch 25/50
# 164/164 [==============================] - 3s 20ms/step - loss: 0.2940 - AUROC: 0.8411 - AUPRC: 0.5111 - val_loss: 0.3326 - val_AUROC: 0.8048 - val_AUPRC: 0.4329
# Epoch 26/50
# 164/164 [==============================] - 3s 20ms/step - loss: 0.3101 - AUROC: 0.8284 - AUPRC: 0.4838 - val_loss: 0.3281 - val_AUROC: 0.8126 - val_AUPRC: 0.4308
# Epoch 27/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2937 - AUROC: 0.8287 - AUPRC: 0.4561 - val_loss: 0.3266 - val_AUROC: 0.8146 - val_AUPRC: 0.4432
# Epoch 28/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2872 - AUROC: 0.8366 - AUPRC: 0.4854 - val_loss: 0.3236 - val_AUROC: 0.8221 - val_AUPRC: 0.4492
# Epoch 29/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2833 - AUROC: 0.8523 - AUPRC: 0.4990 - val_loss: 0.3250 - val_AUROC: 0.8148 - val_AUPRC: 0.4519
# Epoch 30/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.3023 - AUROC: 0.8306 - AUPRC: 0.5010 - val_loss: 0.3355 - val_AUROC: 0.8174 - val_AUPRC: 0.4332
# Epoch 31/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2946 - AUROC: 0.8418 - AUPRC: 0.5254 - val_loss: 0.3282 - val_AUROC: 0.8080 - val_AUPRC: 0.4365
# Epoch 32/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2757 - AUROC: 0.8505 - AUPRC: 0.5255 - val_loss: 0.3237 - val_AUROC: 0.8206 - val_AUPRC: 0.4551
# Epoch 33/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2760 - AUROC: 0.8578 - AUPRC: 0.5474 - val_loss: 0.3383 - val_AUROC: 0.8031 - val_AUPRC: 0.4195
# Epoch 34/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2820 - AUROC: 0.8544 - AUPRC: 0.5393 - val_loss: 0.3393 - val_AUROC: 0.8081 - val_AUPRC: 0.4209
# Epoch 35/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2696 - AUROC: 0.8592 - AUPRC: 0.5414 - val_loss: 0.3293 - val_AUROC: 0.8121 - val_AUPRC: 0.4451
# Epoch 36/50
# 164/164 [==============================] - 3s 18ms/step - loss: 0.2758 - AUROC: 0.8505 - AUPRC: 0.5161 - val_loss: 0.3411 - val_AUROC: 0.8176 - val_AUPRC: 0.4436
# Epoch 37/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2738 - AUROC: 0.8528 - AUPRC: 0.5291 - val_loss: 0.3264 - val_AUROC: 0.8231 - val_AUPRC: 0.4370
# Epoch 38/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2709 - AUROC: 0.8570 - AUPRC: 0.5202 - val_loss: 0.3288 - val_AUROC: 0.8147 - val_AUPRC: 0.4350
# Epoch 1/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2718 - AUROC: 0.8623 - AUPRC: 0.5559 - val_loss: 0.3315 - val_AUROC: 0.8180 - val_AUPRC: 0.4394
# Epoch 2/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2717 - AUROC: 0.8639 - AUPRC: 0.5547 - val_loss: 0.3322 - val_AUROC: 0.8188 - val_AUPRC: 0.4420
# Epoch 3/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2716 - AUROC: 0.8647 - AUPRC: 0.5554 - val_loss: 0.3310 - val_AUROC: 0.8183 - val_AUPRC: 0.4385
# Epoch 4/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2706 - AUROC: 0.8631 - AUPRC: 0.5599 - val_loss: 0.3324 - val_AUROC: 0.8173 - val_AUPRC: 0.4407
# Epoch 5/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2722 - AUROC: 0.8622 - AUPRC: 0.5603 - val_loss: 0.3349 - val_AUROC: 0.8156 - val_AUPRC: 0.4384
# Epoch 6/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2698 - AUROC: 0.8668 - AUPRC: 0.5601 - val_loss: 0.3312 - val_AUROC: 0.8183 - val_AUPRC: 0.4403
# Epoch 7/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2713 - AUROC: 0.8650 - AUPRC: 0.5590 - val_loss: 0.3322 - val_AUROC: 0.8185 - val_AUPRC: 0.4412
# Epoch 8/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2704 - AUROC: 0.8651 - AUPRC: 0.5602 - val_loss: 0.3313 - val_AUROC: 0.8193 - val_AUPRC: 0.4438
# Epoch 9/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2722 - AUROC: 0.8611 - AUPRC: 0.5632 - val_loss: 0.3324 - val_AUROC: 0.8186 - val_AUPRC: 0.4406
# Epoch 10/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2697 - AUROC: 0.8668 - AUPRC: 0.5629 - val_loss: 0.3307 - val_AUROC: 0.8195 - val_AUPRC: 0.4389
# Epoch 11/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2677 - AUROC: 0.8665 - AUPRC: 0.5739 - val_loss: 0.3396 - val_AUROC: 0.8161 - val_AUPRC: 0.4403
# Epoch 12/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2689 - AUROC: 0.8660 - AUPRC: 0.5652 - val_loss: 0.3376 - val_AUROC: 0.8160 - val_AUPRC: 0.4397
# Epoch 13/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2703 - AUROC: 0.8669 - AUPRC: 0.5618 - val_loss: 0.3368 - val_AUROC: 0.8188 - val_AUPRC: 0.4406
# Epoch 14/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2687 - AUROC: 0.8668 - AUPRC: 0.5690 - val_loss: 0.3323 - val_AUROC: 0.8197 - val_AUPRC: 0.4442
# Epoch 15/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2694 - AUROC: 0.8655 - AUPRC: 0.5668 - val_loss: 0.3345 - val_AUROC: 0.8169 - val_AUPRC: 0.4395
# Epoch 16/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2704 - AUROC: 0.8641 - AUPRC: 0.5617 - val_loss: 0.3355 - val_AUROC: 0.8171 - val_AUPRC: 0.4387
# Epoch 17/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2693 - AUROC: 0.8675 - AUPRC: 0.5628 - val_loss: 0.3339 - val_AUROC: 0.8176 - val_AUPRC: 0.4401
# Epoch 18/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2672 - AUROC: 0.8684 - AUPRC: 0.5761 - val_loss: 0.3368 - val_AUROC: 0.8162 - val_AUPRC: 0.4376
# Epoch 19/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2691 - AUROC: 0.8654 - AUPRC: 0.5661 - val_loss: 0.3377 - val_AUROC: 0.8162 - val_AUPRC: 0.4360
# Epoch 20/50
# 164/164 [==============================] - 3s 17ms/step - loss: 0.2709 - AUROC: 0.8652 - AUPRC: 0.5648 - val_loss: 0.3357 - val_AUROC: 0.8197 - val_AUPRC: 0.4436

# %%
import shap

# add fake postive and negative cases
fake_pos = np.mean(X_whole[Y_whole[:,0]==1,:,:],axis=0)
fake_ctrl = np.mean(X_whole[Y_whole[:,0]==0,:,:],axis=0)
new_cases = np.stack([fake_pos,fake_ctrl])
X_valid = np.append(new_cases, X_valid, axis=0)

explainer = shap.DeepExplainer(mdl, X_train)
values = explainer.shap_values(X_valid)
# Out:
# WARNING:tensorflow:`tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
# WARNING:tensorflow:`tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
# You have provided over 5k background samples! For better performance consider using smaller random sample.

# %%
input_vars = ['txp', 'age', 'temperature', 'heart_rate', 'resp_rate', 'spo2', 'x_hr_rr', 's_hr', 's_rr', 
              's_so2', 'systolic_blood_pressure', 'diastolic_blood_pressure', 'glucose', 'bilirubin', 
              'potassium', 'albumin', 'calcium', 'sodium', 'wbc', 'phosphorus', 'creatinine', 'platelet_count',
              'alt', 'alp', 'ast', 'pco2', 'chloride', 'troponin', 'ptt', 'lactate', 'bun', 'magnesium']

# init the JS visualization code
shap.initjs()
# visualize the first prediction's explanation with a force plot
shap.force_plot(explainer.expected_value[0].numpy(), values[0][0], X_valid[0], feature_names=input_vars)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iPR79G39ZZTCFSKQ89UCW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.14811572432518005, "link": "identity", "featureNames": ["txp", "age", "temperature", "heart_rate", "resp_rate", "spo2", "x_hr_rr", "s_hr", "s_rr", "s_so2", "systolic_blood_pressure", "diastolic_blood_pressure", "glucose", "bilirubin", "potassium", "albumin", "calcium", "sodium", "wbc", "phosphorus", "creatinine", "platelet_count", "alt", "alp", "ast", "pco2", "chloride", "troponin", "ptt", "lactate", "bun", "magnesium"], "explanations": [{"outValue": 0.16815301257412546, "simIndex": 1.0, "features": {"0": {"effect": -3.0389132681746808e-05, "value": 0.5081616694298112}, "1": {"effect": 1.107359084155087e-05, "value": 0.5123422704187037}, "2": {"effect": 0.0008022578563055163, "value": 0.5052753372551939}, "3": {"effect": -2.3594141171614635e-05, "value": 0.5270449031259573}, "4": {"effect": -3.283285951163942e-05, "value": 0.5321421492476702}, "5": {"effect": 1.7753360837646744e-05, "value": 0.5072571400662084}, "6": {"effect": -4.314558388958252e-05, "value": 0.49004623030956007}, "7": {"effect": -0.00020169419621690043, "value": 0.5310194404579778}, "8": {"effect": -0.000295846393138873, "value": 0.4889236160110439}, "9": {"effect": -1.0552656675935835e-05, "value": 0.5191634347570676}, "10": {"effect": 0.00011119660369711938, "value": 0.5156512963736943}, "11": {"effect": 0.001522626773470498, "value": 0.49478387225814435}, "12": {"effect": 2.48271499132663e-05, "value": 0.5045343968319622}, "13": {"effect": 0.00226537309628312, "value": 0.5391870092923929}, "14": {"effect": 5.455579244709155e-05, "value": 0.49280986395780235}, "15": {"effect": 0.004028693953009762, "value": 0.43788606353545056}, "16": {"effect": 0.0033457946925932133, "value": 0.4883777768086609}, "17": {"effect": 1.2214718466738276e-06, "value": 0.5062819720377488}, "18": {"effect": 0.0015083085583743395, "value": 0.47327497464196794}, "19": {"effect": 5.9151048504059517e-05, "value": 0.4910656612221371}, "20": {"effect": 0.0012985133986229446, "value": 0.48125450502414535}, "21": {"effect": 0.0018108543793761364, "value": 0.46081163185609103}, "22": {"effect": 2.75396378854058e-05, "value": 0.5177153742290606}, "23": {"effect": -8.653613607219979e-05, "value": 0.5273718481615212}, "24": {"effect": 0.0004192649123564216, "value": 0.5128380585127996}, "25": {"effect": -9.685414646209737e-06, "value": 0.5117255809380005}, "26": {"effect": 0.001412890185266733, "value": 0.48991416373246055}, "27": {"effect": 6.3896406117976745e-06, "value": 0.47246938680927714}, "28": {"effect": 0.0005265197829401341, "value": 0.537573934289273}, "29": {"effect": 0.0007961785456034204, "value": 0.48253644706804705}, "30": {"effect": 6.404431058732238e-05, "value": 0.5454333700305978}, "31": {"effect": 0.0006565360215759174, "value": 0.5711523802996262}}}, {"outValue": 0.1627939662327051, "simIndex": 2.0, "features": {"0": {"effect": 4.5348992512853066e-05, "value": 0.5081616694298112}, "1": {"effect": -6.598314079772296e-05, "value": 0.5123422704187037}, "2": {"effect": 0.00019412688164437237, "value": 0.5053609830779159}, "3": {"effect": -3.063744672826346e-05, "value": 0.5268138785864258}, "4": {"effect": 0.00023545423824851747, "value": 0.5289445829052138}, "5": {"effect": 5.651306652048583e-05, "value": 0.5071693244178367}, "6": {"effect": 2.8258092915983877e-05, "value": 0.4891828445847865}, "7": {"effect": -0.00011784507203145625, "value": 0.5346442564984523}, "8": {"effect": -5.685691845272097e-06, "value": 0.49075366608175935}, "9": {"effect": -0.00011471422385504703, "value": 0.525077622123488}, "10": {"effect": -8.336026995679153e-06, "value": 0.5115195852540615}, "11": {"effect": 0.0016284454636498618, "value": 0.4940868269171859}, "12": {"effect": 3.761934183406775e-06, "value": 0.5069228567974958}, "13": {"effect": 0.0017848483331963266, "value": 0.5394771002358032}, "14": {"effect": 4.902554981741239e-06, "value": 0.4926944436740697}, "15": {"effect": 0.0037334 ...

# %%
input_vars = ['txp', 'age', 'temperature', 'heart_rate', 'resp_rate', 'spo2', 'x_hr_rr', 's_hr', 's_rr', 
              's_so2', 'systolic_blood_pressure', 'diastolic_blood_pressure', 'glucose', 'bilirubin', 
              'potassium', 'albumin', 'calcium', 'sodium', 'wbc', 'phosphorus', 'creatinine', 'platelet_count',
              'alt', 'alp', 'ast', 'pco2', 'chloride', 'troponin', 'ptt', 'lactate', 'bun', 'magnesium']

# init the JS visualization code
shap.initjs()
# visualize the first prediction's explanation with a force plot
shap.force_plot(explainer.expected_value[0].numpy(), values[0][0], X_valid[1], feature_names=input_vars)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iWDLE8TJR6124KGQL941L'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.14811572432518005, "link": "identity", "featureNames": ["txp", "age", "temperature", "heart_rate", "resp_rate", "spo2", "x_hr_rr", "s_hr", "s_rr", "s_so2", "systolic_blood_pressure", "diastolic_blood_pressure", "glucose", "bilirubin", "potassium", "albumin", "calcium", "sodium", "wbc", "phosphorus", "creatinine", "platelet_count", "alt", "alp", "ast", "pco2", "chloride", "troponin", "ptt", "lactate", "bun", "magnesium"], "explanations": [{"outValue": 0.16815301257412546, "simIndex": 1.0, "features": {"0": {"effect": -3.0389132681746808e-05, "value": 0.4987410493581581}, "1": {"effect": 1.107359084155087e-05, "value": 0.4980955586773326}, "2": {"effect": 0.0008022578563055163, "value": 0.47127246028889935}, "3": {"effect": -2.3594141171614635e-05, "value": 0.5225987239065358}, "4": {"effect": -3.283285951163942e-05, "value": 0.5397521052622556}, "5": {"effect": 1.7753360837646744e-05, "value": 0.5096990621209601}, "6": {"effect": -4.314558388958252e-05, "value": 0.48405393661157}, "7": {"effect": -0.00020169419621690043, "value": 0.5506239927053953}, "8": {"effect": -0.000295846393138873, "value": 0.5066356970254543}, "9": {"effect": -1.0552656675935835e-05, "value": 0.5477533779542866}, "10": {"effect": 0.00011119660369711938, "value": 0.5407930636971404}, "11": {"effect": 0.001522626773470498, "value": 0.5587690024206425}, "12": {"effect": 2.48271499132663e-05, "value": 0.508812883702394}, "13": {"effect": 0.00226537309628312, "value": 0.47893868112222593}, "14": {"effect": 5.455579244709155e-05, "value": 0.49023134046855094}, "15": {"effect": 0.004028693953009762, "value": 0.5339767241914283}, "16": {"effect": 0.0033457946925932133, "value": 0.561156969341987}, "17": {"effect": 1.2214718466738276e-06, "value": 0.5080019225750424}, "18": {"effect": 0.0015083085583743395, "value": 0.5047553424481315}, "19": {"effect": 5.9151048504059517e-05, "value": 0.5173266735204946}, "20": {"effect": 0.0012985133986229446, "value": 0.51750335909104}, "21": {"effect": 0.0018108543793761364, "value": 0.5309539013311706}, "22": {"effect": 2.75396378854058e-05, "value": 0.5034804074562506}, "23": {"effect": -8.653613607219979e-05, "value": 0.5060248500324787}, "24": {"effect": 0.0004192649123564216, "value": 0.493603303937439}, "25": {"effect": -9.685414646209737e-06, "value": 0.524387009767123}, "26": {"effect": 0.001412890185266733, "value": 0.4456143765841336}, "27": {"effect": 6.3896406117976745e-06, "value": 0.47225013920349507}, "28": {"effect": 0.0005265197829401341, "value": 0.5011580297959344}, "29": {"effect": 0.0007961785456034204, "value": 0.5173358269193369}, "30": {"effect": 6.404431058732238e-05, "value": 0.5002538018307985}, "31": {"effect": 0.0006565360215759174, "value": 0.5424919065393653}}}, {"outValue": 0.1627939662327051, "simIndex": 2.0, "features": {"0": {"effect": 4.5348992512853066e-05, "value": 0.4987410493581581}, "1": {"effect": -6.598314079772296e-05, "value": 0.4980955586773326}, "2": {"effect": 0.00019412688164437237, "value": 0.47088098130849393}, "3": {"effect": -3.063744672826346e-05, "value": 0.522689650039886}, "4": {"effect": 0.00023545423824851747, "value": 0.5401726488291491}, "5": {"effect": 5.651306652048583e-05, "value": 0.5099919610158073}, "6": {"effect": 2.8258092915983877e-05, "value": 0.48366012184440543}, "7": {"effect": -0.00011784507203145625, "value": 0.5507497667465979}, "8": {"effect": -5.685691845272097e-06, "value": 0.5069219157979054}, "9": {"effect": -0.00011471422385504703, "value": 0.5475363568893349}, "10": {"effect": -8.336026995679153e-06, "value": 0.5409678099285279}, "11": {"effect": 0.0016284454636498618, "value": 0.5585574622062699}, "12": {"effect": 3.761934183406775e-06, "value": 0.509418250606105}, "13": {"effect": 0.0017848483331963266, "value": 0.4700183394321351}, "14": {"effect": 4.902554981741239e-06, "value": 0.4901694357533597}, "15": {"effect": 0.0037334698378803347, ...

# %% [markdown]
# ### Prepare dataset

# %%
# input and output variable name lists
input_vars = ['txp___yes', 'age___vital', 'temp___vital', 'heart_rate___vital', 'resp_rate___vital', 'spo2___vital', 'x_hr_rr___vital', 's_hr___vital', 's_rr___vital', 's_so2___vital', 'diastolic_blood_pressure___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'sodium___vital', 'wbc___vital', 'phosphorus___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'pco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital'] # 'systolic_blood_pressure___vital', 
output_var = ['y___pos']

# read datasets
train_df = pd.read_csv("./train_df.csv")
valid_df = pd.read_csv("./valid_df.csv")
whole_df = pd.concat([train_df, valid_df], axis=0)
whole_df.reset_index(drop=True,inplace=True)

# percentile of inputs
whole_df[input_vars] = whole_df[input_vars].rank(pct=True)

train_df = whole_df.loc[range(train_df.shape[0]),:].copy()
valid_df = whole_df.loc[range(train_df.shape[0], whole_df.shape[0]),:].copy()

# select modeling time window
train_df = train_df.loc[(train_df['__ep_relative_time']/60>=-24) & (train_df['__ep_relative_time']/60<=0) ,:]
valid_df = valid_df.loc[(valid_df['__ep_relative_time']/60>=-24) & (valid_df['__ep_relative_time']/60<=0) ,:]


# median imputation
train_df.fillna(train_df.median(), inplace=True)
valid_df.fillna(train_df.median(), inplace=True)

# combine to one dataframe
whole_df = pd.concat([train_df, valid_df], axis=0)

# reformat inputs to be 2d image and 1 output per image
X_whole = whole_df[input_vars].values
Y_whole = whole_df[output_var].values
X_whole = np.reshape(X_whole, (-1,25,31) )
Y_whole = np.reshape(Y_whole, (-1,25,1) )[:,0,:]
print(X_whole.shape)
print(Y_whole.shape)

# reformat inputs to be 2d image and 1 output per image
X_train = train_df[input_vars].values
Y_train = train_df[output_var].values
X_train = np.reshape(X_train, (-1,25,31) )
Y_train = np.reshape(Y_train, (-1,25,1) )[:,0,:]
print(X_train.shape)
print(Y_train.shape)

# reformat inputs to be 2d image and 1 output per image
X_valid = valid_df[input_vars].values
Y_valid = valid_df[output_var].values
X_valid = np.reshape(X_valid, (-1,25,31) )
Y_valid = np.reshape(Y_valid, (-1,25,1) )[:,0,:]
print(X_valid.shape)
print(Y_valid.shape)
# Out:
# (6557, 25, 31)
# (6557, 1)
# (5226, 25, 31)
# (5226, 1)
# (1331, 25, 31)
# (1331, 1)

# %% [markdown]
# ### sklearn -- aggregated Logistic Regression

# %%
# prepare column names
input_vars = ['txp', 'age', 'temp', 'heart_rate', 'resp_rate', 'spo2', 'x_hr_rr', 's_hr', 's_rr', 
              's_so2', 'dbp', 'glucose', 'bilirubin', 
              'potassium', 'albumin', 'calcium', 'sodium', 'wbc', 'phosphorus', 'creatinine', 'platelet',
              'alt', 'alp', 'ast', 'pco2', 'chloride', 'troponin', 'ptt', 'lactate', 'bun', 'magnesium']#'sbp', 

X_whole_2d = np.mean(X_whole, axis=1)
X_whole_2d = pd.DataFrame(X_whole_2d, columns=input_vars)
Y_whole_2d = Y_whole[:,0]

# add "fake patients" to the first 2 rows in X_whole_2d
pos_row = pd.DataFrame(np.mean(X_whole_2d.loc[Y_whole_2d==1,:], axis=0)).T
neg_row = pd.DataFrame(np.mean(X_whole_2d.loc[Y_whole_2d==0,:], axis=0)).T
X_whole_2d = pd.concat([pos_row, X_whole_2d],axis=0)
X_whole_2d = pd.concat([neg_row, X_whole_2d],axis=0)
X_whole_2d.reset_index(drop=True,inplace=True)

X_train_2d = np.mean(X_train, axis=1)
X_train_2d = pd.DataFrame(X_train_2d, columns=input_vars)
Y_train_2d = Y_train[:,0]

X_valid_2d = np.mean(X_valid, axis=1)
X_valid_2d = pd.DataFrame(X_valid_2d, columns=input_vars)
Y_valid_2d = Y_valid[:,0]

import shap
import sklearn

model = sklearn.linear_model.LogisticRegressionCV(cv=5, random_state=0, penalty="l2")
model.fit(X_train_2d, Y_train_2d)

explainer = shap.Explainer(model, X_whole_2d, feature_names=input_vars)
e = explainer(X_whole_2d)

# summarize the effects (in log odds scale) of all the features
shap.plots.beeswarm(e, max_display=31, plot_size=(6,10))
shap.plots.bar(e, max_display=31)

# %%
# init the JS visualization code
shap.initjs()
# positive 
ind = 0
shap.plots.force(e[ind])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iNNT0IYYQ32FADRLNDNML'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -2.3343980505304502, "outValue": -2.498048767566527, "link": "identity", "featureNames": ["txp", "age", "temp", "heart_rate", "resp_rate", "spo2", "x_hr_rr", "s_hr", "s_rr", "s_so2", "dbp", "glucose", "bilirubin", "potassium", "albumin", "calcium", "sodium", "wbc", "phosphorus", "creatinine", "platelet", "alt", "alp", "ast", "pco2", "chloride", "troponin", "ptt", "lactate", "bun", "magnesium"], "features": {"0": {"effect": -0.006368990090532054, "value": 0.4987410493581581}, "1": {"effect": -0.0013565253562400912, "value": 0.4980955586773326}, "2": {"effect": 0.07813002314179, "value": 0.46278302279911115}, "3": {"effect": -0.00275527157360977, "value": 0.5192219146865652}, "4": {"effect": 0.0008979683488464853, "value": 0.538398285729761}, "5": {"effect": -0.016885602857365647, "value": 0.5065228165479676}, "6": {"effect": 0.00680579902755709, "value": 0.48310029356830236}, "7": {"effect": -0.0019451421070862077, "value": 0.551280100749207}, "8": {"effect": -0.0035772914990445546, "value": 0.511179174503854}, "9": {"effect": 0.011335787773776088, "value": 0.5528188980495964}, "10": {"effect": -0.07480868119485681, "value": 0.5650378647731733}, "11": {"effect": 0.00982155494104512, "value": 0.505534895610884}, "12": {"effect": -0.0020293938584621026, "value": 0.47528070703609987}, "13": {"effect": -0.0073658551398613, "value": 0.5122023735415779}, "14": {"effect": -0.11216207724138395, "value": 0.5524949092185011}, "15": {"effect": 0.0021447217317297346, "value": 0.5570761786339605}, "16": {"effect": 0.0018077151599784822, "value": 0.4908981520257332}, "17": {"effect": -0.004524655128125299, "value": 0.5125112887560982}, "18": {"effect": 0.023469322250868525, "value": 0.5218831400095699}, "19": {"effect": 0.017000143010220202, "value": 0.5155474974161763}, "20": {"effect": -0.05056732325354427, "value": 0.5381611737682065}, "21": {"effect": -0.009362231830128699, "value": 0.49902476120241746}, "22": {"effect": -0.018736244950418264, "value": 0.49573507978512843}, "23": {"effect": 0.034476421012547345, "value": 0.4953358989725125}, "24": {"effect": 0.014001333689459553, "value": 0.5296973025047179}, "25": {"effect": -0.0028639259198421814, "value": 0.4575504529502209}, "26": {"effect": 0.00026869164225464074, "value": 0.4743459960490328}, "27": {"effect": -0.01819664233171575, "value": 0.4877364491431342}, "28": {"effect": -0.0016430169458733386, "value": 0.5290312884717944}, "29": {"effect": -0.03124434463189524, "value": 0.49006156227500064}, "30": {"effect": 0.0025830171438353273, "value": 0.5129410239103004}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iNNT0IYYQ32FADRLNDNML')
#   );
# </script>

# %%
# negative
ind = 1
shap.plots.force(e[ind])
# Out:
# <div id='iFL4JDAY8RBYDKZG4TKNY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -2.345472133296024, "outValue": -1.230063504119898, "link": "identity", "featureNames": ["txp", "age", "temp", "heart_rate", "resp_rate", "spo2", "x_hr_rr", "s_hr", "s_rr", "s_so2", "sbp", "dbp", "glucose", "bilirubin", "potassium", "albumin", "calcium", "sodium", "wbc", "phosphorus", "creatinine", "platelet", "alt", "alp", "ast", "pco2", "chloride", "troponin", "ptt", "lactate", "bun", "magnesium"], "features": {"0": {"effect": -0.0006712912884655869, "value": 0.5081616694298112}, "1": {"effect": -0.003833386131532496, "value": 0.5123422704187037}, "2": {"effect": 0.3443887048721596, "value": 0.5374372071356496}, "3": {"effect": 0.03618245123689533, "value": 0.541818267152742}, "4": {"effect": 0.0011452471298694779, "value": 0.5396891687392598}, "5": {"effect": -0.009045692091996675, "value": 0.5022927912101369}, "6": {"effect": 0.01667805344343617, "value": 0.476574318563405}, "7": {"effect": 0.004728110965867357, "value": 0.5303186141917601}, "8": {"effect": 0.0012922661810492485, "value": 0.4914396327473403}, "9": {"effect": 0.08473665785425785, "value": 0.5240156878314628}, "10": {"effect": 0.003402285108655854, "value": 0.5002196242053086}, "11": {"effect": 0.14036608715768792, "value": 0.47977414196739243}, "12": {"effect": 0.012704631431206146, "value": 0.5133985907294211}, "13": {"effect": 0.017941545785260735, "value": 0.5713866279931288}, "14": {"effect": 0.003534655660182072, "value": 0.4819805656468667}, "15": {"effect": 0.07080778705275752, "value": 0.42608228001936005}, "16": {"effect": -0.00046958003621596175, "value": 0.48957249968426875}, "17": {"effect": -0.002685199366885211, "value": 0.4760297237171703}, "18": {"effect": 0.0006836366320627292, "value": 0.48974494661302465}, "19": {"effect": 0.06717089395041084, "value": 0.474355075300649}, "20": {"effect": 0.01865323794830771, "value": 0.5135449161926935}, "21": {"effect": 0.0725914674447515, "value": 0.4319915432209127}, "22": {"effect": -0.0017348682406337472, "value": 0.5228262138785074}, "23": {"effect": 0.026693822890140006, "value": 0.5578819272175303}, "24": {"effect": 0.015419761396699296, "value": 0.5228624800272226}, "25": {"effect": 0.059069046359450685, "value": 0.4825411087375876}, "26": {"effect": -0.013542051632950445, "value": 0.46961441152703043}, "27": {"effect": 0.0010060425559395257, "value": 0.4795414782887675}, "28": {"effect": 0.011931296948448725, "value": 0.546130805822956}, "29": {"effect": -0.004978281136144079, "value": 0.5200987876016868}, "30": {"effect": 0.1311616884008455, "value": 0.5794410672138743}, "31": {"effect": 0.010079600694608575, "value": 0.5356539373962825}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iFL4JDAY8RBYDKZG4TKNY')
#   );
# </script>
