# %% [markdown]
# # Case 4
#
# In this case study, we deal with **every 15 minutes prediction**. We will use 3 types of deep learning models to forecast an ICU adult patient's blood culture test results.
# Input
#
# > * ICU adults' vital signs and lab results in minutes
#
# Output
#
# > * 3 categories of blood culture status -- positive / negative / no blood culture
# > * label : positive VS negative + no blood culture
#
# Classification strategy
# > * summarize/use a certain length of per-minute inputs to every 15 minutes record since admission
# > * train, test datasets split by subject

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import scipy

import FAIRStream

# %%
from random import randint
import matplotlib.pylab as plt 
import numpy as np
from tensorflow.keras.models import Sequential, Model

def get_feature_maps(model, layer_id, input_image):
    model_ = Model(inputs=[model.input], outputs=[model.layers[layer_id].output])
    return model_.predict(np.expand_dims(input_image, axis=0))[0,:,:,:].transpose((2,1,0))




def plot_features_map(input_image_list, 
                      cnn,
                      img_title_list=["Postive", "Control"],
                      layer_idx=[0,1,2,3,4,5]):
    
    nrow = len(layer_idx)
    ncol = len(input_image_list)
    
    fig, ax = plt.subplots(nrow+1, ncol, figsize=(20,20))
    
    for j in range(ncol):
        input_image = input_image_list[j]
        ax[0][j].imshow(input_image[:,:,0].transpose(1,0))
        ax[0][j].set_title(img_title_list[j])
        for i in range(nrow):
            feature_map = get_feature_maps(cnn, layer_idx[i], input_image)
            ax[i+1][j].imshow(feature_map[0,:,:])
            ax[i+1][j].set_title('layer {} - {}'.format(layer_idx[i], cnn.layers[layer_idx[i]].get_config()['name']))

    return

# %% [markdown]
# ## setup

# %%
# csv pool folder directory
csv_pool_path = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/csv_pool'
# current experiment working directory
work_dir = '/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case4'

# %%
# initiate a FAIRStream object instance for BSI project
bsi_stream = FAIRStream.FAIRStream(work_dir)
# take a look at dictionaries in engineer's hands
#bsi_stream.engineer.csv_source_dict
bsi_stream.engineer.variable_dict
# Out:
# Success: Querier has initiated a csv source dictionary in:/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case4/meta_data/csv_source_dict_demo.json
# Success: Querier has initiated a variable dictionary in:/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/case4/meta_data/variable_dict_demo.json
# Unable to read sql source dictionary. Use Querier.update_sql_source_dict() to build one.
# {'__uid': {'src_names': ['id', 'ID', 'subject_id', 'subject_id'],
#   'label': 'unique subject id for current study',
#   'unique_per_sbj': True},
#  '__time': {'src_names': ['tsa', 'tsa', 'timeMinutes', 'timeMinutes'],
#   'label': 'time since admission',
#   'unit': 'minute'},
#  '__anchor': {'src_names': ['True_positive', 'True positive'],
#   'label': 'anchor for an episode',
#   'unique_per_sbj': False,
#   'factor': {'levels': {'__neg_nbc': ['0', '0.0', 'nan'],
#     '__pos': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': '__neg_nbc'}}},
#  'y': {'output': True,
#   'src_names': ['True_positive', 'True positive'],
#   'label': 'Event outcome result',
#   'unique_per_sbj': False,
#   'factor': {'levels': {'neg_nbc': ['0', '0.0', 'nan'], 'pos': ['1', '1.0']},
#    'impute_per_sbj': {'nan_level': 'neg_nbc'}}},
#  'age': {'input': True,
#   'src_names': ['age', 'AGE'],
#   'label': 'age at admission',
#   'unique_per_sbj': True,
#   'numeric': {'scaler': 'none',
#    'unit': 'year',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 110},
#    'impute_per_sbj': {'forward': 0, 'backward': 0}}},
#  'gender': {'input': False,
#   'src_names': ['Sex', 'Sex'],
#   'label': 'subject gender',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'Male': ['male', 'Male', '0'],
#     'Female': ['female', 'Female', '1']},
#    'impute_per_sbj': {'nan_level': 'unknown'}}},
#  'race': {'input': False,
#   'src_names': ['Race', 'RACE'],
#   'label': 'subject race',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'Black': 1, 'White': 2},
#    'impute_per_sbj': {'nan_level': 'White'}}},
#  'ethnicity': {'input': False,
#   'src_names': ['ethnicity', 'Ethnicity'],
#   'label': 'subject ethnicity',
#   'unique_per_sbj': True,
#   'factor': {'levels': {'African American': ['aa', 'African american'],
#     'Asian': ['asian', 'Asian'],
#     'Histopian': ['hist', 'histopian', 'Histopian']},
#    'impute_per_sbj': {'nan_level': 'White'}}},
#  'temp': {'input': True,
#   'src_names': ['Temp', 'tempc'],
#   'label': 'subject body temperature',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'minmax',
#    'unit': 'celsius',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 5,
#     'value_max': 60},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'heart_rate': {'input': True,
#   'src_names': ['hr', 'heartrate'],
#   'label': 'subject heart rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'beats per minute',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 10,
#     'value_max': 200},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'systolic_blood_pressure': {'input': True,
#   'src_names': ['SBP', 'sysbp'],
#   'label': 'subject systolic blood pressure',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'mm Hg',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'diastolic_blood_pressure': {'input': True,
#   'src_names': ['DBP', 'diasbp'],
#   'label': 'subject diastolic blood pressure',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'unit': 'mm Hg',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100},
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'resp_rate': {'input': True,
#   'src_names': ['rr', 'resprate'],
#   'label': 'subject respiratory rate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 200},
#    'unit': 'mm Hg',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'spo2': {'input': False,
#   'src_names': [],
#   'label': 'SpO2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 79},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'glucose': {'input': True,
#   'src_names': ['GLUCOSE', 'Glucose'],
#   'label': 'Glucose',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 49,
#     'value_max': 460},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'bilirubin': {'input': True,
#   'src_names': ['TOTAL.BILIRUBIN', 'bilirubin'],
#   'label': 'Bilirubin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 50},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'potassium': {'input': True,
#   'src_names': ['POTASSIUM', 'Potassium'],
#   'label': 'Potassium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 2.4,
#     'value_max': 6.6},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'albumin': {'input': True,
#   'src_names': ['Albumin', 'ALBUMIN'],
#   'label': 'Albumin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 5},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'calcium': {'input': True,
#   'src_names': ['CALCIUM', 'Calcium'],
#   'label': 'Calcium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 6.1,
#     'value_max': 12},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'wbc': {'input': True,
#   'src_names': ['WHITE.BLOOD.CELL.COUNT', 'WBC'],
#   'label': 'WBC',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 33.85},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'creatinine': {'input': True,
#   'src_names': ['CREATININE', 'Creatinine'],
#   'label': 'Creatinine',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 10},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'platelet_count': {'input': True,
#   'src_names': ['PLATELET.COUNT', 'plateletcount'],
#   'label': 'PlateletCount',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1001},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'alt': {'input': True,
#   'src_names': ['ALT.GPT', 'ALT'],
#   'label': 'ALT',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1085},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'alp': {'input': True,
#   'src_names': ['ALKALINE.PHOSPHATASE', 'ALP'],
#   'label': 'ALP',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 800},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'ast': {'input': True,
#   'src_names': ['AST.GOT', 'AST'],
#   'label': 'AST',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 1203},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'paco2': {'input': True,
#   'src_names': ['PCO2', 'PaCO2'],
#   'label': 'PaCO2',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 100.5},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'chloride': {'input': True,
#   'src_names': ['CHLORIDE', 'Chloride'],
#   'label': 'Chloride',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 83,
#     'value_max': 132},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'troponin': {'input': True,
#   'src_names': ['TROPONIN.I', 'Troponin'],
#   'label': 'Troponin',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 23.5},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'ptt': {'input': True,
#   'src_names': ['PARTIAL.THROMBOPLASTIN.TIME', 'PTT'],
#   'label': 'partial_thromboplastin_time',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 140},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'lactate': {'input': True,
#   'src_names': ['Lactate', 'LACTIC.ACID'],
#   'label': 'Lactate',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 19.1},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'bun': {'input': True,
#   'src_names': ['BLOOD.UREA.NITROGEN', 'BUN'],
#   'label': 'BUN',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 143},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}},
#  'magnesium': {'input': True,
#   'src_names': ['MAGNESIUM', 'Magnesium'],
#   'label': 'Magnesium',
#   'unique_per_sbj': False,
#   'numeric': {'scaler': 'none',
#    'cutoff': {'quantile_min': 0.0001,
#     'quantile_max': 0.9999,
#     'value_min': 0,
#     'value_max': 3.4},
#    'unit': 'TODO',
#    'impute_per_sbj': {'forward': 1440, 'backward': 720}}}}

# %% [markdown]
# ## Define Episode

# %%
# define an episode (notice that the engineer now has new attributes)
bsi_stream.engineer.DefineEpisode(input_time_len=4*24*60, # using vital signs and labs 4 days prior to a culture 
                                  output_time_len=1, # predict one time unit into the future
                                  time_resolution=60, # aggregate minutely data to one row per hour 
                                  time_lag=0,  # no time lag between predictors and response
                                  anchor_gap=7*24*60) # the minimum distance between two episodes
# Out:
#
# Success! An episode is defined to
# --- use 5760 minute(s) long input variables
# --- predict 1 minute(s) response variables into the future
# --- lag 0 minute(s) between predictors and responses
# --- increase by every 60 minute(s)
# --- last at most 10080 minute(s) long
# Success! Engineer has updated attributes --- episode.

# %% [markdown]
# ## Build MVTS (multi-variable time series) data objects
# - train_df_imputed, valid_df_imputed and test_df_imputed are dataframes
# - train_tfds, valid_tfds and test_tfds are tensorflow datasets

# %%
# Build MVTS dataframe or tfds  (notice that the engineer now has new attributes)
bsi_stream.engineer.BuildMVTS(csv_pool_path, 
                              nsbj = 10, # number of subjects / patients to sample from the pool 
                              valid_frac = 0.2, # fraction of number of subjects in validation dataset
                              test_frac = 0.1, # fraction of number of subjects in left-out test dataset
                              batch_size = 64, # batch size (usually 32,64,128..)
                              impute_input='median', # imputation on predictors
                              impute_output='median' )# imputation on response (no need in BSI project)

# please see the end of console 
# --- Success! Engineer has updated attributes --- train_df_imputed, valid_df_imputed and test_df_imputed. 
# --- Success! Engineer has updated attributes --- train_tfds, valid_tfds and test_tfds.
# Out:
# Success!  10 out of 26093 subjects are sampled!
# --- fix upper boundary for age by 86.5606890257814
# --- fix lower boundary for age by 44.106662103582
# --- minmax scaling temp
# --- fix upper boundary for heart_rate by 134.494444444444
# --- fix lower boundary for heart_rate by 49.894444444444396
# --- fix upper boundary for systolic_blood_pressure by nan
# --- fix lower boundary for systolic_blood_pressure by nan
# --- fix upper boundary for diastolic_blood_pressure by nan
# --- fix lower boundary for diastolic_blood_pressure by nan
# --- fix upper boundary for resp_rate by 51.1123504399413
# --- fix lower boundary for resp_rate by 7.590054898910201
# --- fix upper boundary for glucose by nan
# --- fix lower boundary for glucose by nan
# --- fix upper boundary for bilirubin by nan
# --- fix lower boundary for bilirubin by nan
# --- fix upper boundary for potassium by nan
# --- fix lower boundary for potassium by nan
# --- fix upper boundary for albumin by nan
# --- fix lower boundary for albumin by nan
# --- fix upper boundary for calcium by nan
# --- fix lower boundary for calcium by nan
# --- fix upper boundary for wbc by nan
# --- fix lower boundary for wbc by nan
# --- fix upper boundary for creatinine by nan
# --- fix lower boundary for creatinine by nan
# --- fix upper boundary for platelet_count by nan
# --- fix lower boundary for platelet_count by nan
# --- fix upper boundary for alt by nan
# --- fix lower boundary for alt by nan
# --- fix upper boundary for alp by nan
# --- fix lower boundary for alp by nan
# --- fix upper boundary for ast by nan
# --- fix lower boundary for ast by nan
# --- fix upper boundary for paco2 by nan
# --- fix lower boundary for paco2 by nan
# --- fix upper boundary for chloride by nan
# --- fix lower boundary for chloride by nan
# --- fix upper boundary for troponin by nan
# --- fix lower boundary for troponin by nan
# --- fix upper boundary for ptt by nan
# --- fix lower boundary for ptt by nan
# --- fix upper boundary for lactate by nan
# --- fix lower boundary for lactate by nan
# --- fix upper boundary for bun by nan
# --- fix lower boundary for bun by nan
# --- fix upper boundary for magnesium by nan
# --- fix lower boundary for magnesium by nan
# --- fix upper boundary for age by 81.0
# --- fix lower boundary for age by 23.0
# --- minmax scaling temp
# --- fix upper boundary for heart_rate by nan
# --- fix lower boundary for heart_rate by nan
# --- fix upper boundary for systolic_blood_pressure by nan
# --- fix lower boundary for systolic_blood_pressure by nan
# --- fix upper boundary for diastolic_blood_pressure by nan
# --- fix lower boundary for diastolic_blood_pressure by nan
# --- fix upper boundary for resp_rate by nan
# --- fix lower boundary for resp_rate by nan
# --- fix upper boundary for glucose by 211.0
# --- fix lower boundary for glucose by 62.0
# --- fix upper boundary for bilirubin by 4.0
# --- fix lower boundary for bilirubin by 0.2
# --- fix upper boundary for potassium by 5.5
# --- fix lower boundary for potassium by 2.8
# --- fix upper boundary for albumin by 4.5
# --- fix lower boundary for albumin by 2.2
# --- fix upper boundary for calcium by nan
# --- fix lower boundary for calcium by nan
# --- fix upper boundary for wbc by 33.85
# --- fix lower boundary for wbc by 0.3
# --- fix upper boundary for creatinine by 10.0
# --- fix lower boundary for creatinine by 0.3
# --- fix upper boundary for platelet_count by nan
# --- fix lower boundary for platelet_count by nan
# --- fix upper boundary for alt by 253.0
# --- fix lower boundary for alt by 7.0
# --- fix upper boundary for alp by 648.0
# --- fix lower boundary for alp by 50.0
# --- fix upper boundary for ast by 484.0
# --- fix lower boundary for ast by 10.0
# --- fix upper boundary for paco2 by nan
# --- fix lower boundary for paco2 by nan
# --- fix upper boundary for chloride by 118.0
# --- fix lower boundary for chloride by 89.0
# --- fix upper boundary for troponin by nan
# --- fix lower boundary for troponin by nan
# --- fix upper boundary for ptt by 140.0
# --- fix lower boundary for ptt by 22.3
# --- fix upper boundary for lactate by nan
# --- fix lower boundary for lactate by nan
# --- fix upper boundary for bun by 92.0
# --- fix lower boundary for bun by 2.0
# --- fix upper boundary for magnesium by nan
# --- fix lower boundary for magnesium by nan
# --- fix upper boundary for age by 81.0
# --- fix lower boundary for age by 23.0
# --- prepare episodes for mimic_2100
# Success! Output/responce variable mean in current sample space  ---
# y___pos        0.0
# y___neg_nbc    1.0
# dtype: float64
# --- prepare episodes for mimic_59420
# Success! Output/responce variable mean in current sample space  ---
# y___pos        0.0
# y___neg_nbc    1.0
# dtype: float64
# --- prepare episodes for mimic_29501
# Success! Output/responce variable mean in current sample space  ---
# y___pos        0.0
# y___neg_nbc    1.0
# dtype: float64
# --- prepare episodes for mimic_45589
# Success! Output/responce variable mean in current sample space  ---
# y___pos        0.0
# y___neg_nbc    1.0
# dtype: float64
# --- prepare episodes for mimic_50913
# Success! Output/responce variable mean in current sample space  ---
# y___pos        0.0
# y___neg_nbc    1.0
# dtype: float64
# --- prepare episodes for uva_5451
# Success! Output/responce variable mean in current sample space  ---
# y___pos        0.0
# y___neg_nbc    1.0
# dtype: float64
# --- prepare episodes for mimic_50484
# Success! Output/responce variable mean in current sample space  ---
# y___pos        0.0
# y___neg_nbc    1.0
# dtype: float64
# --- prepare episodes for uva_3671
# Success! Output/responce variable mean in current sample space  ---
# y___pos        0.0
# y___neg_nbc    1.0
# dtype: float64
# --- prepare episodes for mimic_10278
# Success! Output/responce variable mean in current sample space  ---
# y___pos        0.0
# y___neg_nbc    1.0
# dtype: float64
# --- prepare episodes for mimic_29735
# Success! Output/responce variable mean in current sample space  ---
# y___pos        0.0
# y___neg_nbc    1.0
# dtype: float64
# Success! Engineer has updated attributes --- mvts_df, input_vars, output_vars.
# Success! Engineer has updated attributes --- train_df, valid_df and test_df.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-7f512142c464> in <module>
#       6                               batch_size = 64, # batch size (usually 32,64,128..)
#       7                               impute_input='median', # imputation on predictors
# ----> 8                               impute_output='median' )# imputation on response (no need in BSI project)
#       9
#      10 # please see the end of console
#
# ~/Documents/FAIRStream/FAIRStream/Classes/Engineer.py in BuildMVTS(self, csv_pool_dir, nsbj, frac, viz, viz_ts, stratify_by, valid_frac, test_frac, byepisode, batch_size, impute_input, impute_output, fill_value, dummy_na, topn_eps)
#     152         self.make_mvts_df_from_csv_pool(csv_pool_dir=csv_pool_dir, nsbj=nsbj, frac=frac, viz=viz, viz_ts=viz_ts, stratify_by=stratify_by, dummy_na=dummy_na, topn_eps=topn_eps)
#     153         self.split_df(mvts_df=self.mvts_df, valid_frac=valid_frac, test_frac=test_frac, byepisode=byepisode)
# --> 154         self.cohort_fillna(impute_input=impute_input, impute_output=impute_output, fill_value=fill_value, viz=viz)
#     155
#     156         if self.train_df_imputed is not None:
#
# ~/Documents/FAIRStream/FAIRStream/Classes/Engineer.py in cohort_fillna(self, impute_input, impute_output, fill_value, viz)
#     130     def cohort_fillna(self, impute_input=None, impute_output=None, fill_value=-333, viz=True):
#     131         if self.train_df is not None:
# --> 132             self.train_df_imputed = cohort_fillna(refer_df=self.train_df, df=self.train_df, vars=self.input_vars, method=impute_input, fill_value=fill_value, viz=viz)
#     133             self.train_df_imputed = cohort_fillna(refer_df=self.train_df, df=self.train_df_imputed, vars=self.output_vars, method=impute_output, fill_value=fill_value, viz=viz)
#     134
#
# ~/Documents/FAIRStream/FAIRStream/Functions/cohort_fillna.py in cohort_fillna(refer_df, df, vars, method, fill_value, viz)
#      32     imputer.fit(refer_df[vars])
#      33     df_imputed = df.copy()
# ---> 34     df_imputed[vars] = imputer.transform(df[vars])
#      35
#      36
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3467             self._setitem_frame(key, value)
#    3468         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3469             self._setitem_array(key, value)
#    3470         else:
#    3471             # set column
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3496                 indexer = self.loc._convert_to_indexer(key, axis=1)
#    3497                 self._check_setitem_copy()
# -> 3498                 self.loc._setitem_with_indexer((slice(None), indexer), value)
#    3499
#    3500     def _setitem_frame(self, key, value):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     525                     if len(labels) != value.shape[1]:
#     526                         raise ValueError(
# --> 527                             "Must have equal len keys and value "
#     528                             "when setting with an ndarray"
#     529                         )
#
# ValueError: Must have equal len keys and value when setting with an ndarray

# %% [markdown]
# ### print all the attributes of the engineer

# %%
bsi_stream.engineer.info()

# extract X, Y numpy array by engineer build-in function
X_train, Y_train, X_valid, Y_valid, X_test, Y_test = bsi_stream.engineer.ExtractXY()

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_valid = X_valid.reshape(X_valid.shape[0], X_valid.shape[1], X_valid.shape[2], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
X_train = X_train.astype('float32')
X_valid = X_valid.astype('float32')
X_test = X_test.astype('float32')

Y_train = Y_train.reshape(Y_train.shape[0], Y_train.shape[2])
Y_valid = Y_valid.reshape(Y_valid.shape[0], Y_valid.shape[2])
Y_test = Y_test.reshape(Y_test.shape[0], Y_test.shape[2])

X_all = np.concatenate((X_train, X_valid, X_test), axis=0)
Y_all = np.concatenate((Y_train, Y_valid, Y_test), axis=0)
# Out:
# ----------------------------- Engineer Attributes List ------------------------
#
# ['work_dir', 'meta_dir', 'variable_dict', 'csv_source_dict', 'sql_source_dict', 'input_vars', 'output_vars', 'episode', 'sample_info', 'mvts_df', 'mvts_tfds', 'train_df', 'valid_df', 'test_df', 'train_df_imputed', 'valid_df_imputed', 'test_df_imputed', 'train_tfds', 'valid_tfds', 'test_tfds']
#
# ------------------------------------- Inputs  ---------------------------------
#
# ['age___vital', 'age___lab', 'temp___vital', 'heart_rate___vital', 'systolic_blood_pressure___vital', 'diastolic_blood_pressure___vital', 'resp_rate___vital', 'glucose___vital', 'bilirubin___vital', 'potassium___vital', 'albumin___vital', 'calcium___vital', 'wbc___vital', 'creatinine___vital', 'platelet_count___vital', 'alt___vital', 'alp___vital', 'ast___vital', 'paco2___vital', 'chloride___vital', 'troponin___vital', 'ptt___vital', 'lactate___vital', 'bun___vital', 'magnesium___vital']
#
# ------------------------------------- Outputs ---------------------------------
#
# ['y___pos', 'y___neg_nbc']
#
# ------------------ train_tfds / valid_tfds / test_tfds batch shape --------------
#
# Inputs shape (batch size, time bins, variables): (64, 96, 25)
# Labels shape (batch size, time bins, variables): (64, 1, 2)
#
# ---------------------- train_df / train_df_imputed shape ----------------------
#
# (221742, 32)
#
# ---------------------- valid_df / valid_df_imputed shape ----------------------
#
# (70228, 32)
#
# ------------------------ test_df / test_df_imputed shape ----------------------
#
# (28615, 32)

# %% [markdown]
# ## --- Pre-modeling Interpretability (raw scale) ---

# %%
X_all = np.load("./X_all.npy")
Y_all = np.load("./Y_all.npy")
X_train = np.load("./X_train.npy")
Y_train = np.load("./Y_train.npy")
X_valid = np.load("./X_valid.npy")
Y_valid = np.load("./Y_valid.npy")
X_test = np.load("./X_test.npy")
Y_test = np.load("./Y_test.npy")

print("X_train shape", X_train.shape)
print("Y_train shape", Y_train.shape)
print("X_valid shape", X_valid.shape)
print("Y_valid shape", Y_valid.shape)
print("X_test shape", X_test.shape)
print("Y_test shape", Y_test.shape)
print("X_all shape", X_all.shape)
print("Y_all shape", Y_all.shape)
# Out:
# X_train shape (23508, 96, 25, 1)
# Y_train shape (23508, 2)
# X_valid shape (6357, 96, 25, 1)
# Y_valid shape (6357, 2)
# X_test shape (3455, 96, 25, 1)
# Y_test shape (3455, 2)
# X_all shape (33320, 96, 25, 1)
# Y_all shape (33320, 2)

# %% [markdown]
# ### 1. print a few episode as images

# %%
X_pos = X_all[Y_all[:,0]==1.0][:,:,:,0]
X_ctrl = X_all[Y_all[:,0]==0.0][:,:,:,0]

print(X_pos.shape)
print(X_ctrl.shape)

fig, ax = plt.subplots(1,10,figsize=(20,20))
axes = ax.flatten()
for i in range(10):
    axes[i].imshow(X_pos[i])
    axes[i].set_title('postive episode {}'.format(i))

fig, ax = plt.subplots(1,10,figsize=(20,20))
axes = ax.flatten()
for i in range(10):
    axes[i].imshow(X_ctrl[i])
    axes[i].set_title('control episode {}'.format(i))
# Out:
# (31496, 96, 25)
# (1824, 96, 25)

# %% [markdown]
# ### 2. Visualize Statistical Moments -- Positive VS Control Group

# %% [markdown]
# #### Statistic Moment 1 -- mean

# %%
X_pos_stat = X_pos.mean(axis=0).transpose((1,0))
X_ctrl_stat = X_ctrl.mean(axis=0).transpose((1,0))
X_all_stat = X_all.mean(axis=0)[:,:,0].transpose((1,0))

fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()
ax[0].imshow(X_pos_stat)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12));

ax[1].imshow(X_ctrl_stat)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12));

ax[2].imshow(X_all_stat)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12));

# %% [markdown]
# #### Statistic Moment 2 -- std

# %%
X_pos_stat = X_pos.std(axis=0).transpose((1,0))
X_ctrl_stat = X_ctrl.std(axis=0).transpose((1,0))
X_all_stat = X_all.std(axis=0)[:,:,0].transpose((1,0))

fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()
ax[0].imshow(X_pos_stat)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12));

ax[1].imshow(X_ctrl_stat)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12));

ax[2].imshow(X_all_stat)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12));

# %% [markdown]
# #### Statistic Moment 3 -- skewness

# %%
X_pos_stat = scipy.stats.skew(X_pos, axis=0).transpose((1,0))
X_ctrl_stat = scipy.stats.skew(X_ctrl, axis=0).transpose((1,0))
X_all_stat = scipy.stats.skew(X_all, axis=0)[:,:,0].transpose((1,0))

fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()
ax[0].imshow(X_pos_stat)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12));

ax[1].imshow(X_ctrl_stat)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12));

ax[2].imshow(X_all_stat)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12));

# %% [markdown]
# #### Statistic Moment 4 -- Kurtosis

# %%
X_pos_stat = scipy.stats.kurtosis(X_pos, axis=0).transpose((1,0))
X_ctrl_stat = scipy.stats.kurtosis(X_ctrl, axis=0).transpose((1,0))
X_all_stat = scipy.stats.kurtosis(X_all, axis=0)[:,:,0].transpose((1,0))

fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()
ax[0].imshow(X_pos_stat)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12));

ax[1].imshow(X_ctrl_stat)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12));

ax[2].imshow(X_all_stat)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12));

# %% [markdown]
# ## --- Modeling interpretation raw scale (CNN) ---

# %%
myMetrics = [
    keras.metrics.AUC(name='AUROC', curve='ROC', multi_label=True),
    keras.metrics.AUC(name='AUPRC', curve='PR', multi_label=True),
]

keras.backend.clear_session()
mdl = keras.models.Sequential([
    keras.layers.Conv2D(64, 
                        kernel_size=(3,3),
                        activation='relu', 
                        padding='same',
                        input_shape=list(X_train.shape)[1:4]),
    keras.layers.MaxPool2D(pool_size=(1,1)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(1, 
                        kernel_size=(3,3),
                        activation='relu', 
                        padding='same'),
    keras.layers.MaxPool2D(pool_size=(1,1)),
    keras.layers.BatchNormalization(),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
])
mdl.summary()
mdl.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
callback = EarlyStopping(monitor='val_loss', patience=5)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
keras.backend.set_value(mdl.optimizer.learning_rate, 1e-4)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 25, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 96, 25, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 96, 25, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 25, 1)         577
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 96, 25, 1)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 96, 25, 1)         4
# _________________________________________________________________
# flatten (Flatten)            (None, 2400)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                76832
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 78,375
# Trainable params: 78,245
# Non-trainable params: 130
# _________________________________________________________________
# Epoch 1/50
# 735/735 [==============================] - 110s 149ms/step - loss: 0.2045 - AUROC: 0.6973 - AUPRC: 0.6822 - val_loss: 0.3263 - val_AUROC: 0.7181 - val_AUPRC: 0.7365
# Epoch 2/50
# 735/735 [==============================] - 109s 148ms/step - loss: 0.1150 - AUROC: 0.8569 - AUPRC: 0.8470 - val_loss: 11.8587 - val_AUROC: 0.5020 - val_AUPRC: 0.5007
# Epoch 3/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.1120 - AUROC: 0.8513 - AUPRC: 0.8440 - val_loss: 0.0928 - val_AUROC: 0.9219 - val_AUPRC: 0.9146
# Epoch 4/50
# 735/735 [==============================] - 108s 146ms/step - loss: 0.0943 - AUROC: 0.8798 - AUPRC: 0.8736 - val_loss: 0.0872 - val_AUROC: 0.9043 - val_AUPRC: 0.8951
# Epoch 5/50
# 735/735 [==============================] - 107s 146ms/step - loss: 0.0883 - AUROC: 0.8938 - AUPRC: 0.8886 - val_loss: 7.1797 - val_AUROC: 0.5208 - val_AUPRC: 0.5047
# Epoch 6/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.0859 - AUROC: 0.9021 - AUPRC: 0.8846 - val_loss: 0.2159 - val_AUROC: 0.8242 - val_AUPRC: 0.8379
# Epoch 7/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.0892 - AUROC: 0.8934 - AUPRC: 0.8750 - val_loss: 0.1630 - val_AUROC: 0.8304 - val_AUPRC: 0.8444
# Epoch 8/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.0837 - AUROC: 0.8954 - AUPRC: 0.8833 - val_loss: 0.0898 - val_AUROC: 0.9011 - val_AUPRC: 0.8955
# Epoch 9/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.0748 - AUROC: 0.9072 - AUPRC: 0.9020 - val_loss: 0.1276 - val_AUROC: 0.8761 - val_AUPRC: 0.8808
# Epoch 1/50
# 735/735 [==============================] - 109s 149ms/step - loss: 0.0712 - AUROC: 0.9336 - AUPRC: 0.9152 - val_loss: 0.1241 - val_AUROC: 0.8782 - val_AUPRC: 0.8850
# Epoch 2/50
# 735/735 [==============================] - 108s 148ms/step - loss: 0.0640 - AUROC: 0.9379 - AUPRC: 0.9269 - val_loss: 0.1673 - val_AUROC: 0.8465 - val_AUPRC: 0.8595
# Epoch 3/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.0594 - AUROC: 0.9449 - AUPRC: 0.9327 - val_loss: 0.1565 - val_AUROC: 0.8577 - val_AUPRC: 0.8697
# Epoch 4/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.0531 - AUROC: 0.9537 - AUPRC: 0.9414 - val_loss: 0.2330 - val_AUROC: 0.8194 - val_AUPRC: 0.8344
# Epoch 5/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.0541 - AUROC: 0.9562 - AUPRC: 0.9416 - val_loss: 0.2478 - val_AUROC: 0.8111 - val_AUPRC: 0.8267
# Epoch 6/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.0515 - AUROC: 0.9577 - AUPRC: 0.9443 - val_loss: 0.0930 - val_AUROC: 0.8982 - val_AUPRC: 0.9063
# Epoch 7/50
# 735/735 [==============================] - 108s 148ms/step - loss: 0.0511 - AUROC: 0.9602 - AUPRC: 0.9449 - val_loss: 0.1595 - val_AUROC: 0.8583 - val_AUPRC: 0.8708
# Epoch 8/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.0488 - AUROC: 0.9634 - AUPRC: 0.9476 - val_loss: 0.0872 - val_AUROC: 0.9102 - val_AUPRC: 0.9157
# Epoch 9/50
# 735/735 [==============================] - 110s 149ms/step - loss: 0.0506 - AUROC: 0.9645 - AUPRC: 0.9457 - val_loss: 0.1617 - val_AUROC: 0.8666 - val_AUPRC: 0.8785
# Epoch 10/50
# 735/735 [==============================] - 109s 148ms/step - loss: 0.0476 - AUROC: 0.9675 - AUPRC: 0.9500 - val_loss: 0.1146 - val_AUROC: 0.8916 - val_AUPRC: 0.9016
# Epoch 11/50
# 735/735 [==============================] - 108s 148ms/step - loss: 0.0474 - AUROC: 0.9666 - AUPRC: 0.9503 - val_loss: 0.0657 - val_AUROC: 0.9569 - val_AUPRC: 0.9380
# Epoch 12/50
# 735/735 [==============================] - 109s 148ms/step - loss: 0.0461 - AUROC: 0.9685 - AUPRC: 0.9517 - val_loss: 0.0903 - val_AUROC: 0.9084 - val_AUPRC: 0.9153
# Epoch 13/50
# 735/735 [==============================] - 109s 148ms/step - loss: 0.0468 - AUROC: 0.9661 - AUPRC: 0.9503 - val_loss: 0.1523 - val_AUROC: 0.8735 - val_AUPRC: 0.8849
# Epoch 14/50
# 735/735 [==============================] - 109s 148ms/step - loss: 0.0455 - AUROC: 0.9695 - AUPRC: 0.9521 - val_loss: 0.1507 - val_AUROC: 0.8777 - val_AUPRC: 0.8888
# Epoch 15/50
# 735/735 [==============================] - 109s 149ms/step - loss: 0.0461 - AUROC: 0.9669 - AUPRC: 0.9524 - val_loss: 0.1343 - val_AUROC: 0.8819 - val_AUPRC: 0.8927
# Epoch 16/50
# 735/735 [==============================] - 112s 152ms/step - loss: 0.0452 - AUROC: 0.9668 - AUPRC: 0.9532 - val_loss: 0.0603 - val_AUROC: 0.9639 - val_AUPRC: 0.9395
# Epoch 17/50
# 735/735 [==============================] - 112s 152ms/step - loss: 0.0462 - AUROC: 0.9660 - AUPRC: 0.9508 - val_loss: 0.0787 - val_AUROC: 0.9209 - val_AUPRC: 0.9219
# Epoch 18/50
# 735/735 [==============================] - 109s 149ms/step - loss: 0.0461 - AUROC: 0.9690 - AUPRC: 0.9516 - val_loss: 0.1415 - val_AUROC: 0.8791 - val_AUPRC: 0.8899
# Epoch 19/50
# 735/735 [==============================] - 109s 148ms/step - loss: 0.0448 - AUROC: 0.9686 - AUPRC: 0.9533 - val_loss: 0.1143 - val_AUROC: 0.8901 - val_AUPRC: 0.9003
# Epoch 20/50
# 735/735 [==============================] - 108s 148ms/step - loss: 0.0446 - AUROC: 0.9714 - AUPRC: 0.9550 - val_loss: 0.0882 - val_AUROC: 0.9027 - val_AUPRC: 0.9111
# Epoch 21/50
# 735/735 [==============================] - 108s 147ms/step - loss: 0.0442 - AUROC: 0.9717 - AUPRC: 0.9545 - val_loss: 0.1139 - val_AUROC: 0.8887 - val_AUPRC: 0.8989

# %%
X_train_pos_img = X_train[Y_train[:,0]==1.0].mean(axis=0)
X_train_ctrl_img = X_train[Y_train[:,0]==0.0].mean(axis=0)

X_valid_pos_img = X_valid[Y_valid[:,0]==1.0].mean(axis=0)
X_valid_ctrl_img = X_valid[Y_valid[:,0]==0.0].mean(axis=0)

X_all_pos_img = X_all[Y_all[:,0]==1.0].mean(axis=0)
X_all_ctrl_img = X_all[Y_all[:,0]==0.0].mean(axis=0)

# %%
plot_features_map(input_image_list=[X_all_pos_img, X_all_ctrl_img],
                  img_title_list=["POS (all)", "CTRL (all)"],
                  layer_idx=[0,1,2,3], 
                  cnn=mdl)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d14032440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d1401cd40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d1406e8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d141d58c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d11cb7d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d127e3d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d127e3200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d141d58c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
plot_features_map(input_image_list=[X_train_pos_img, X_train_ctrl_img, 
                                    X_valid_pos_img, X_valid_ctrl_img],
                      img_title_list=["POS (train)", "CTRL (train)", 
                                      "POS (valid)", " CTRL (valid)"],
                      layer_idx=[0,1,2,3], 
                      cnn=mdl)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd7451320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d148bd710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc210a710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dda8197a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd6929c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8da2e5cc20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc44ffc20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd6929c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d15081c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dda50a9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd68f3dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd73bfb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd73bf560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd6929050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc461bb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d11ef0cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# ## --- Post-Modeling interpretation (raw scale + saliency map) ---

# %% [markdown]
# ## --- Pre-training Interpretability (standardized) ---

# %%
X_all = np.load("./X_all.npy")
Y_all = np.load("./Y_all.npy")
X_train = np.load("./X_train.npy")
Y_train = np.load("./Y_train.npy")
X_valid = np.load("./X_valid.npy")
Y_valid = np.load("./Y_valid.npy")
X_test = np.load("./X_test.npy")
Y_test = np.load("./Y_test.npy")

print("X_train shape", X_train.shape)
print("Y_train shape", Y_train.shape)
print("X_valid shape", X_valid.shape)
print("Y_valid shape", Y_valid.shape)
print("X_test shape", X_test.shape)
print("Y_test shape", Y_test.shape)
print("X_all shape", X_all.shape)
print("Y_all shape", Y_all.shape)

X_train = (X_train - X_all.mean(axis=0))/X_all.std(axis=0)
X_valid = (X_valid - X_all.mean(axis=0))/X_all.std(axis=0)
X_all = (X_all - X_all.mean(axis=0))/X_all.std(axis=0)

print("X_train shape", X_train.shape)
print("Y_train shape", Y_train.shape)
print("X_valid shape", X_valid.shape)
print("Y_valid shape", Y_valid.shape)
print("X_all shape", X_all.shape)
print("Y_all shape", Y_all.shape)
# Out:
# X_train shape (23508, 96, 25, 1)
# Y_train shape (23508, 2)
# X_valid shape (6357, 96, 25, 1)
# Y_valid shape (6357, 2)
# X_test shape (3455, 96, 25, 1)
# Y_test shape (3455, 2)
# X_all shape (33320, 96, 25, 1)
# Y_all shape (33320, 2)
# X_train shape (23508, 96, 25, 1)
# Y_train shape (23508, 2)
# X_valid shape (6357, 96, 25, 1)
# Y_valid shape (6357, 2)
# X_all shape (33320, 96, 25, 1)
# Y_all shape (33320, 2)

# %%
X_pos = X_all[Y_all[:,0]==1.0][:,:,:,0]
X_ctrl = X_all[Y_all[:,0]==0.0][:,:,:,0]
print(X_pos.shape)
print(X_ctrl.shape)

fig, ax = plt.subplots(1,10,figsize=(20,20))
axes = ax.flatten()
for i in range(10):
    axes[i].imshow(X_pos[i])
    axes[i].set_title('postive episode {}'.format(i))

fig, ax = plt.subplots(1,10,figsize=(20,20))
axes = ax.flatten()
for i in range(10):
    axes[i].imshow(X_ctrl[i])
    axes[i].set_title('control episode {}'.format(i))
# Out:
# (31496, 96, 25)
# (1824, 96, 25)

# %% [markdown]
# #### Statistic Moment 1 -- mean

# %%
X_pos_stat = X_pos.mean(axis=0).transpose((1,0))
X_ctrl_stat = X_ctrl.mean(axis=0).transpose((1,0))
X_all_stat = X_all.mean(axis=0)[:,:,0].transpose((1,0))

fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()
ax[0].imshow(X_pos_stat)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12));

ax[1].imshow(X_ctrl_stat)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12));

ax[2].imshow(X_all_stat)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12));

# %% [markdown]
# ### Statistic Moment 2 -- std

# %%
X_pos_stat = X_pos.std(axis=0).transpose((1,0))
X_ctrl_stat = X_ctrl.std(axis=0).transpose((1,0))
X_all_stat = X_all.std(axis=0)[:,:,0].transpose((1,0))

fig, axes = plt.subplots(3,1, figsize=(20,20))
ax = axes.flatten()
ax[0].imshow(X_pos_stat)
ax[0].set_title("Positive Episode")
ax[0].tick_params(axis='y', labelrotation=0)
ax[0].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[0].set_yticklabels(bsi_stream.engineer.input_vars);
ax[0].set_xticks(range(0,96,12))
ax[0].set_xticklabels(range(-96,0,12));

ax[1].imshow(X_ctrl_stat)
ax[1].set_title("Control Group Episode")
ax[1].tick_params(axis='y', labelrotation=0)
ax[1].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[1].set_yticklabels(bsi_stream.engineer.input_vars);
ax[1].set_xticks(range(0,96,12))
ax[1].set_xticklabels(range(-96,0,12));

ax[2].imshow(X_all_stat)
ax[2].set_title("Combined Episode")
ax[2].tick_params(axis='y', labelrotation=0)
ax[2].set_yticks(range(len(bsi_stream.engineer.input_vars)))
ax[2].set_yticklabels(bsi_stream.engineer.input_vars);
ax[2].set_xticks(range(0,96,12))
ax[2].set_xticklabels(range(-96,0,12));

# %% [markdown]
# #### Statistic Moment 3 -- skewness

# %% [markdown]
# #### Statistic Moment 4 -- Kurtosis

# %% [markdown]
# ## --- Modeling interpretation (standardized + CNN) ---

# %%
myMetrics = [
    keras.metrics.AUC(name='AUROC', curve='ROC', multi_label=True),
    keras.metrics.AUC(name='AUPRC', curve='PR', multi_label=True),
]

keras.backend.clear_session()
mdl = keras.models.Sequential([
    keras.layers.Conv2D(64, 
                        kernel_size=(3,3),
                        activation='relu', 
                        padding='same',
                        input_shape=list(X_train.shape)[1:4]),
    keras.layers.MaxPool2D(pool_size=(1,1)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(32, 
                        kernel_size=(3,3),
                        activation='relu', 
                        padding='same'),
    keras.layers.MaxPool2D(pool_size=(1,1)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(1, 
                        kernel_size=(3,3),
                        activation='relu', 
                        padding='same'),
    keras.layers.MaxPool2D(pool_size=(1,1)),
    keras.layers.BatchNormalization(),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(2, activation='softmax', name='visualized_layer')
])
mdl.summary()
mdl.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-3), metrics = myMetrics)
callback = EarlyStopping(monitor='val_loss', patience=5)
his = mdl.fit(X_train, Y_train, 
              epochs=50, 
              validation_data=(X_valid,Y_valid), callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 25, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 96, 25, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 96, 25, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 25, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 96, 25, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 96, 25, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 25, 1)         289
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 96, 25, 1)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 96, 25, 1)         4
# _________________________________________________________________
# flatten (Flatten)            (None, 2400)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                76832
# _________________________________________________________________
# visualized_layer (Dense)     (None, 2)                 66
# =================================================================
# Total params: 96,679
# Trainable params: 96,485
# Non-trainable params: 194
# _________________________________________________________________
# Epoch 1/50
# 735/735 [==============================] - 178s 241ms/step - loss: 0.0809 - AUROC: 0.9253 - AUPRC: 0.9210 - val_loss: 0.0533 - val_AUROC: 0.9644 - val_AUPRC: 0.9525
# Epoch 2/50
# 735/735 [==============================] - 179s 243ms/step - loss: 0.0432 - AUROC: 0.9692 - AUPRC: 0.9556 - val_loss: 0.0486 - val_AUROC: 0.9659 - val_AUPRC: 0.9523
# Epoch 3/50
# 457/735 [=================>............] - ETA: 1:04 - loss: 0.0346 - AUROC: 0.9774 - AUPRC: 0.9667

# %%
X_train_pos_img = X_train[Y_train[:,0]==1.0].mean(axis=0)
X_train_ctrl_img = X_train[Y_train[:,0]==0.0].mean(axis=0)

X_valid_pos_img = X_valid[Y_valid[:,0]==1.0].mean(axis=0)
X_valid_ctrl_img = X_valid[Y_valid[:,0]==0.0].mean(axis=0)

X_all_pos_img = X_all[Y_all[:,0]==1.0].mean(axis=0)
X_all_ctrl_img = X_all[Y_all[:,0]==0.0].mean(axis=0)

# %%
plot_features_map(input_image_list=[X_all_pos_img, X_all_ctrl_img],
                      img_title_list=["POS (all)", "CTRL (all)"],
                      layer_idx=[0,3,6], 
                      cnn=mdl)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dda5683b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dda8263b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8ddb16e440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dda6ae4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd622f710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd7c4dcb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd636bcb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dda81b3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
plot_features_map(input_image_list=[X_train_pos_img, X_train_ctrl_img, 
                                    X_valid_pos_img, X_valid_ctrl_img],
                      img_title_list=["POS (train)", "CTRL (train)", 
                                      "POS (valid)", " CTRL (valid)"],
                      layer_idx=[0,3,6], 
                      cnn=mdl
                 )
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd6a2cd40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc3b99200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc44e2290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc4365320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd5e80560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc44c7560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd5e80170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc44e2ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd7460680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc44e9680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc44e27a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dc3bd05f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd83c5b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dda5979e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dda597320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8dd5ead170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
from vis.visualization import visualize_saliency
from vis.utils import utils
from keras import activations

# %%
# Visualize
for index_to_visualize in indices_to_visualize:
    # Get input
    input_image = X_all[index_to_visualize]
    input_class = np.argmax(Y_all[index_to_visualize])
    # Matplotlib preparations
    fig, axes = plt.subplots(1, 2)
    # Generate visualization
    visualization = visualize_saliency(mdl, layer_index, filter_indices=input_class, seed_input=input_image)
    axes[0].imshow(input_image[..., 0]) 
    axes[0].set_title('Original image')
    axes[1].imshow(visualization)
    axes[1].set_title('Saliency map')
    fig.suptitle(f'MNIST target = {input_class}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-a2dbb84a0fb4> in <module>
#       7     fig, axes = plt.subplots(1, 2)
#       8     # Generate visualization
# ----> 9     visualization = visualize_saliency(mdl, layer_index, filter_indices=input_class, seed_input=input_image)
#      10     axes[0].imshow(input_image[..., 0])
#      11     axes[0].set_title('Original image')
#
# /opt/anaconda3/lib/python3.7/site-packages/vis/visualization/saliency.py in visualize_saliency(model, layer_idx, filter_indices, seed_input, backprop_modifier, grad_modifier)
#     123         (ActivationMaximization(model.layers[layer_idx], filter_indices), -1)
#     124     ]
# --> 125     return visualize_saliency_with_losses(model.input, losses, seed_input, grad_modifier)
#     126
#     127
#
# /opt/anaconda3/lib/python3.7/site-packages/vis/visualization/saliency.py in visualize_saliency_with_losses(input_tensor, losses, seed_input, grad_modifier)
#      70         weighted `losses`.
#      71     """
# ---> 72     opt = Optimizer(input_tensor, losses, norm_grads=False)
#      73     grads = opt.minimize(seed_input=seed_input, max_iter=1, grad_modifier=grad_modifier, verbose=False)[1]
#      74
#
# /opt/anaconda3/lib/python3.7/site-packages/vis/optimizer.py in __init__(self, input_tensor, losses, input_range, wrt_tensor, norm_grads)
#      50
#      51         # Compute gradient of overall with respect to `wrt` tensor.
# ---> 52         grads = K.gradients(overall_loss, self.wrt_tensor)[0]
#      53         if norm_grads:
#      54             grads = grads / (K.sqrt(K.mean(K.square(grads))) + K.epsilon())
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in gradients(loss, variables)
#    2513         A gradients tensor.
#    2514     """
# -> 2515     return tf.gradients(loss, variables, colocate_gradients_with_ops=True)
#    2516
#    2517
#
# TypeError: gradients_v2() got an unexpected keyword argument 'colocate_gradients_with_ops'

# %%
def plot_saliency(img_idx):
    grads = visualize_saliency(mdl,
                               "visualized_layer",
                               filter_indices=Y_all[img_idx][0], 
                               seed_input=X_all[img_idx], 
                               backprop_modifier=None,
                               grad_modifier="absolute")
    fig, ax = plt.subplots(1,2, figsize=(10,5))
    ax[0].imshow(X_all[img_idx])
    ax[0].set_title('original img id {}'.format(img_idx))
    ax[1].imshow(grads, cmap='jet')
    ax[1].set_title('saliency - predicted {}'.format(img_idx))

plot_saliency(img_idx = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-ad929224c957> in <module>
#      11     ax[1].set_title('saliency - predicted {}'.format(img_idx))
#      12
# ---> 13 plot_saliency(img_idx = 0)
#
# <ipython-input-66-ad929224c957> in plot_saliency(img_idx)
#       4                                filter_indices=Y_all[img_idx][0],
#       5                                seed_input=X_all[img_idx],
# ----> 6                                backprop_modifier=None)
#       7     fig, ax = plt.subplots(1,2, figsize=(10,5))
#       8     ax[0].imshow(X_all[img_idx])
#
# /opt/anaconda3/lib/python3.7/site-packages/vis/visualization/saliency.py in visualize_saliency(model, layer_idx, filter_indices, seed_input, backprop_modifier, grad_modifier)
#     121     # for increasing activations. Multiply with -1 so that positive gradients indicate increase instead.
#     122     losses = [
# --> 123         (ActivationMaximization(model.layers[layer_idx], filter_indices), -1)
#     124     ]
#     125     return visualize_saliency_with_losses(model.input, losses, seed_input, grad_modifier)
#
# TypeError: list indices must be integers or slices, not str
