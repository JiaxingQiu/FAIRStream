# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/Transplant/data/bsi_old_deidentified_final.csv", nrows=10)

# %%
for i, name in enumerate(df.columns):
    print(i, name)
# Out:
# 0 bid
# 1 hr
# 2 rr
# 3 so2
# 4 x.hr.rr
# 5 x.hr.so2
# 6 x.rr.so2
# 7 s.rr
# 8 s.so2
# 9 rsa
# 10 edrk
# 11 edr
# 12 x.hr.edr
# 13 mrr
# 14 srr
# 15 af
# 16 cosen
# 17 dfa
# 18 ds
# 19 lds
# 20 hem.s.1
# 21 hem.s
# 22 hem.m
# 23 int.s.amani
# 24 int.s
# 25 int.m
# 26 sep.s
# 27 sep.m
# 28 s.edrk
# 29 n.edrk
# 30 s.edr
# 31 pt.rr
# 32 s.pt.rr
# 33 s.hr
# 34 pdel
# 35 s.pdel
# 36 x.ptt.ptt
# 37 x.rri.ptt
# 38 te.rri.ptt
# 39 SODIUM
# 40 POTASSIUM
# 41 CHLORIDE
# 42 CO2
# 43 BLOOD.UREA.NITROGEN
# 44 CREATININE
# 45 GLUCOSE
# 46 CALCIUM
# 47 WHITE.BLOOD.CELL.COUNT
# 48 HEMOGLOBIN
# 49 HEMATOCRIT
# 50 PLATELET.COUNT
# 51 NEUTROPHILS.PERCENT
# 52 AST.GOT
# 53 ALT.GPT
# 54 TOTAL.PROTEIN
# 55 ALBUMIN
# 56 TOTAL.BILIRUBIN
# 57 ALKALINE.PHOSPHATASE
# 58 MAGNESIUM
# 59 PHOSPHORUS
# 60 OXYGEN.SATURATION
# 61 PARTIAL.THROMBOPLASTIN.TIME
# 62 PROTIME
# 63 PROTIME.INR
# 64 PH.ARTERIAL
# 65 PCO2
# 66 PO2
# 67 BICARBONATE
# 68 BASE.EXCESS
# 69 FIO2
# 70 TROPONIN.I
# 71 LACTIC.ACID
# 72 havelabs
# ...

# %%
df1 = pd.read_csv("/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/csv_pool/uva_1_vital.csv")
df2 = pd.read_csv("/Users/jiaxingqiu/Documents/CAMA_projects/BSI/code/projects/csv_pool/uva_1_lab.csv")

# %%
for i, name in enumerate(df2.columns):
    print(i, name)
# Out:
# 0 instance_id
# 1 sets_per_instance
# 2 growths_per_instance
# 3 pathogens_per_instance
# 4 possible_contaminants_per_instance
# 5 confirmed_contaminants_per_instance
# 6 set_results
# 7 Instance_Verdict
# 8 GP_isolate_n
# 9 GN_isolate_n
# 10 fungus_isolate_n
# 11 mycobacteria_isolate_n
# 12 all_isolate_n
# 13 GP
# 14 GN
# 15 fungus
# 16 mycobacteria
# 17 polymicrobial
# 18 Transplant Status
# 19 Confirmed Txp
# 20 SOT
# 21 HSCT
# 22 Transplant AdmissionDiff
# 23 tsa
# 24 ID
# 25 True_positive_n
# 26 True_positive

# %%
df2
# Out:
#    instance_id  sets_per_instance  growths_per_instance  \
# 0         9974                  2                     0
#
#    pathogens_per_instance  possible_contaminants_per_instance  \
# 0                       0                                   0
#
#    confirmed_contaminants_per_instance    set_results Instance_Verdict  \
# 0                                    0  c("NA", "NA")       No Growths
#
#    GP_isolate_n  GN_isolate_n  ...  polymicrobial  Transplant Status  \
# 0             0             0  ...              0                NaN
#
#    Confirmed Txp  SOT  HSCT  Transplant AdmissionDiff  tsa  ID  \
# 0            NaN    0     0                       NaN  215   1
#
#    True_positive_n  True_positive
# 0                0              0
#
# [1 rows x 27 columns]
